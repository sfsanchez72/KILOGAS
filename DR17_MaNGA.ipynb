# %%
# %matplotlib inline
import numpy as np
import pandas as pd
from pylab import *
import matplotlib
import plplot
from scipy import stats
#from io import StringIO
print(pd.__version__)
#AttributeError: 'Series' object has no attribute 'to_numpy'
import re

import math
import astropy as astro
import scipy.ndimage as spimage
from astropy.io import fits, ascii
from astropy.table import Table, join
from astropy.cosmology import WMAP9 as cosmo
import matplotlib as mpl
#from numpy import std as biweight_midvariance
import matplotlib.cm as cm

from scipy import optimize
from scipy.stats import gaussian_kde
from matplotlib import colors
import scipy.ndimage as ndimage
from collections import Counter
from matplotlib.legend import Legend
import matplotlib.patches as patches
from matplotlib import pyplot
#
#
#
import extinction


#
# seaborn
#%matplotlib inline
import numpy as np
import pandas as pd
from pylab import *
import matplotlib
import plplot
from scipy import stats
#from io import StringIO
print(pd.__version__)
#AttributeError: 'Series' object has no attribute 'to_numpy'
import re

import math
import astropy as astro
import scipy.ndimage as spimage
from astropy.io import fits, ascii
from astropy.table import Table, join
from astropy.cosmology import WMAP9 as cosmo
import matplotlib as mpl
#from numpy import std as biweight_midvariance
import matplotlib.cm as cm

from scipy import optimize
from scipy.stats import gaussian_kde
from matplotlib import colors
import scipy.ndimage as ndimage
from collections import Counter
from matplotlib.legend import Legend
import matplotlib.patches as patches
from matplotlib import pyplot
#
#
#
import extinction


#
# seaborn
#
import pandas.util.testing as tm
import seaborn as sns

#
# Jorge
#

from sel2dhist_xy import sel2dhist_xy


#
# 3D plots!
#
import numpy as np
import scipy.linalg
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt

#biweight_midvariance


import warnings
warnings.simplefilter("ignore")

#
# my_utils
#
from my_utils import *

#
#
#
from ndtest import *
from sklearn.decomposition import PCA

#
#
#
from scipy.optimize import leastsq, fmin
import matplotlib.animation as animation

#
# Carlos Color map
#
from cmaps_CLC import vel_map


import pandas.util.testing as tm
import seaborn as sns

#
# Jorge
#

from sel2dhist_xy import sel2dhist_xy


#
# 3D plots!
#
import numpy as np
import scipy.linalg
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt

#biweight_midvariance


import warnings
warnings.simplefilter("ignore")

#
# my_utils
#
from my_utils import *

#
#
#
from ndtest import *
from sklearn.decomposition import PCA

#
#
#
from scipy.optimize import leastsq, fmin
import matplotlib.animation as animation

#
# Carlos Color map
#
from cmaps_CLC import vel_map
# Out:
# 1.1.1
# 1.1.1
# <ipython-input-1-ae473d5281b2>:40: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
from matplotlib import rcParams as rc
rc.update({'font.size': 20,\
           'font.weight': 900,\
           'text.usetex': True,\
           'path.simplify'           :   True,\
           'xtick.labelsize' : 20,\
           'ytick.labelsize' : 20,\
#           'xtick.major.size' : 3.5,\
#           'ytick.major.size' : 3.5,\
           'axes.linewidth'  : 2.0,\
               # Increase the tick-mark lengths (defaults are 4 and 2)
           'xtick.major.size'        :   6,\
           'ytick.major.size'        :   6,\
           'xtick.minor.size'        :   3,\
           'ytick.minor.size'        :   3,\
           'xtick.major.width'       :   1,\
           'ytick.major.width'       :   1,\
           'lines.markeredgewidth'   :   1,\
           'legend.numpoints'        :   1,\
           'xtick.minor.width'       :   1,\
           'ytick.minor.width'       :   1,\
           'legend.frameon'          :   False,\
           'legend.handletextpad'    :   0.3,\
           'font.family'    :   'serif',\
           'mathtext.fontset'        :   'stix',\
           'axes.facecolor' : "w",\
           
          })

# %% [markdown]
# READING TABLES

# %%
#
# Reading get_proc_elines table!
# 
get_proc_elines="tables/get_proc_elines_MaNGA.clean.csv"
col_proc_elines=header_columns(get_proc_elines,2)
tab_pe=ascii.read(get_proc_elines, delimiter=',', guess=True, comment='\s*#', names=col_proc_elines,\
                      fill_values=[('BAD', np.nan)])
list_columns(tab_pe.columns)
# Out:
# MaNGA_name                          log_Mass_gas                        e_OH_Re_fit_dop                     ZH_T50
# nsa_redshift                        log_Mass_gas_Re                     alpha_OH_Re_fit_dop                 ZH_Re_T50
# nsa_u_absmag                        log_Mass_gas_Av_ssp_ZH              e_alpha_OH_Re_fit_dop               a_ZH_T50
# nsa_z_absmag                        log_Mass_gas_Av_ssp                 cc_r_OH_dop                         T60
# nsa_u_z_absmag                      log_Mass_gas_Av_gas_rad             sig_r_OH_dop                        ZH_T60
# nsa_mstar                           log_Mass_stars_sigma                NO_Re_fit_EPM09                     ZH_Re_T60
# nsa_inclination                     log_F_Ha                            e_NO_Re_fit_EPM09                   a_ZH_T60
# nsa_petro_th50                      log_F_Ha_cor                        alpha_NO_Re_fit_EPM09               T70
# nsa_sersic_ba                       log_L_Ha_cor                        e_alpha_NO_Re_fit_EPM09             ZH_T70
# nsa_sersic_n                        NH_Re_log                           cc_r_NO_EPM09                       ZH_Re_T70
# nsa_sersic_phi                      NO_Re_log                           sig_r_NO_EPM09                      a_ZH_T70
# nsa_sersic_th50                     sigma_cen_Ha                        NO_Re_fit_N2S2                      T801
# name                                e_sigma_cen_Ha                      e_NO_Re_fit_N2S2                    ZH_T80
# log_Mass_no_corr                    rat_vel_sigma                       alpha_NO_Re_fit_N2S2                ZH_Re_T80
# lSFR                                e_rat_vel_sigma                     e_alpha_NO_Re_fit_N2S2              a_ZH_T80
# OH_O3N2                             OH_Re_fit_pyqz                      cc_r_NO_N2S2                        T90
# e_OH_O3N2                           e_OH_Re_fit_pyqz                    sig_r_NO_N2S2                       ZH_T90
# a_ion_cen[3]                        alpha_OH_Re_fit_pyqz                OH_Re_fit_O3N2_EPM09                ZH_Re_T90
# frac_area_GAS                       e_alpha_OH_Re_fit_pyqz              e_OH_Re_fit_O3N2_EPM09              a_ZH_T90
# frac_area_SFR_pure                  cc_r_OH_pyqz                        alpha_OH_Re_fit_O3N2_EPM09          T95
# Av_w                                sig_r_OH_pyqz                       e_alpha_OH_Re_fit_O3N2_EPM09        ZH_T95
# OH_O3N2_Re                          OH_Re_mean_phot                     cc_r_OH_O3N2_EPM09                  ZH_Re_T95
# alpha_OH_O3N2_Re                    e_OH_Re_mean_phot                   sig_r_OH_O3N2_EPM09                 a_ZH_T95
# a_vel_Ha_cen_mean                   alpha_OH_Re_mean_phot               sigma_r_arcsec_SF                   T99
# a_vel_ssp_cen_mean                  e_alpha_OH_Re_mean_phot             sigma_r_arcsec_SF_arcsec            ZH_T99
# z_gas                               OH_ZH_LW_Re_fit                     Ha_flux_density_1sigma              ZH_Re_T99
# z_stars                             OH_ZH_LW_Re_fit_0_0.5Gyr            log_SFR_SF                          a_ZH_T99
# FoV                                 OH_ZH_LW_Re_fit_0.5_2Gyr            log_L_Ha_SF                         log_Mass_gas_Av_gas_OH
# nx                                  OH_ZH_LW_Re_fit_more_2Gyr           log_SFR_D_C                         log_Mass_gas_Av_ssp_OH
# ny                                  XC                                  log_L_Ha_D_C                        lSFR_NO_CEN
# Re_kpc                              YC                                  log_L_Ha_DF                         vel_ssp_2
# mag_g                               ZH_LW_Re_fit_0_2.0_Gyr              OH_O3N2_cen                         e_vel_ssp_2
# log_Mass_corr                       e_ZH_LW_Re_fit_0_2.0_Gyr            e_OH_O3N2_cen                       vel_Ha_2
# Av_ssp_stats[2]                     alpha_ZH_LW_Re_fit_0_2.0_Gyr        OH_N2_cen                           e_vel_Ha_2
# OH_O3N2_Re2                         e_alpha_ZH_LW_Re_fit_0_2.0_Gyr      e_OH_N2_cen                         vel_ssp_1
# e_OH_O3N2_Re2                       OH_ZH_LW_Re_fit_0_2Gyr              OH_ONS_cen                          e_vel_ssp_1
# error_Mass                          OH_ZH_MW_Re_fit                     e_OH_ONS_cen                        vel_Ha_1
# e_lSFR                              OH_ZH_MW_Re_fit_0_2Gyr              OH_R23_cen                          e_vel_Ha_1
# Age_LW_Re                           T50                                 e_OH_R23_cen                        log_SFR_ssp_100Myr
# e_Age_LW_Re                         T80                                 OH_pyqz_cen                         log_SFR_ssp_10Myr
# ZH_LW_Re                            OH_ZH_LW_Re_fit_t50                 e_OH_pyqz_cen                       vel_disp_Ha_cen
# e_ZH_LW_Re                          OH_ZH_LW_Re_fit_M_t50               OH_t2_cen                           vel_disp_ssp_cen
# Av_LW_Re                            OH_ZH_LW_Re_fit_t80                 e_OH_t2_cen                         vel_disp_Ha_1Re
# e_Av_LW_Re                          OH_ZH_LW_Re_fit_M_t80               OH_M08_cen                          vel_disp_ssp_1Re
# Av_gas_LW_Re                        OH_Re_mean                          e_OH_M08_cen                        vel_disp_Ha_1Re_mean
# e_Av_gas_LW_Re                      e_OH_Re_mean                        OH_T04_cen                          vel_disp_ssp_1Re_mean
# OH_Z_Re                             alpha_OH_Re_mean                    e_OH_T04_cen                        log_Mass_Re
# e_ZH_LW_Re1                         e_alpha_OH_Re_mean                  OH_dop_cen                          e_log_Mass_Re
# log_age_mean_LW                     OH_Re_fit_mean                      e_OH_dop_cen                        log_SFR_Re
# s_log_age_mean_LW                   e_OH_Re_fit_mean                    OH_O3N2_EPM09_cen                   e_log_SFR_Re
# log_ZH_mean_LW                      alpha_OH_Re_fit_mean                e_OH_O3N2_EPM09_cen                 KIN_Ha_1
# s_log_ZH_mean_LW                    e_alpha_OH_Re_fit_mean              log_OI_Ha_cen                       e_KIN_Ha_1
# Av_ssp_stats_mean                   cc_r_OH_mean                        e_log_OI_Ha_cen                     KIN_ssp_1
# Av_ssp_stats_stddev                 sig_r_OH_mean                       Ha_Hb_cen                           e_KIN_ssp_1
# Av_w1                               OH_Re_fit_t2                        e_Ha_Hb_cen                         KIN_Ha_05
# e_Av_w                              e_OH_Re_fit_t2                      log_NII_Ha_Re                       e_KIN_Ha_05
# OH_Re_fit_O3N2                      alpha_OH_Re_fit_t2                  e_log_NII_Ha_Re                     KIN_ssp_05
# e_OH_Re_fit_O3N2                    e_alpha_OH_Re_fit_t2                log_OIII_Hb_Re                      e_KIN_ssp_05
# alpha_OH_Re_fit_O3N2                cc_r_OH_t2                          e_log_OIII_Hb_Re                    log_U_P_Re_fit
# e_alpha_OH_Re_fit_O3N2              sig_r_OH_t2                         log_SII_Ha_Re                       e_log_U_P_Re_fit
# cc_r_OH_O3N2                        OH_ZH_LW_Re_fit_t90                 e_log_SII_Ha_Re                     alpha_log_U_P_Re_fit
# sig_r_OH_O3N2                       OH_ZH_LW_Re_fit_M_t90               log_OII_Hb_Re                       e_alpha_log_U_P_Re_fit
# OH_Re_fit_N2                        t90                                 e_log_OII_Hb_Re                     log_U_iter_Re_fit
# e_OH_Re_fit_N2                      t70                                 log_OI_Ha_Re                        e_log_U_iter_Re_fit
# alpha_OH_Re_fit_N2                  t60                                 e_log_OI_Ha_Re                      alpha_log_U_iter_Re_fit
# e_alpha_OH_Re_fit_N2                ZH_LW_Re_fit_M_t50                  EW_Ha_Re                            e_alpha_log_U_iter_Re_fit
# cc_r_OH_N2                          e_ZH_LW_Re_fit_M_t50                e_EW_Ha_Re                          log_U_pyqz_Re_fit
# sig_r_OH_N2                         alpha_ZH_LW_Re_fit_M_t50            Ha_Hb_Re                            e_log_U_pyqz_Re_fit
# OH_Re_fit_ONS                       e_alpha_ZH_LW_Re_fit_M_t50          e_Ha_Hb_Re                          alpha_log_U_pyqz_Re_fit
# e_OH_Re_fit_ONS                     cc_ZH_LW_Re_M_t50                   log_NII_Ha_ALL                      e_alpha_log_U_pyqz_Re_fit
# alpha_OH_Re_fit_ONS                 sig_ZH_LW_Re_M_t50                  e_log_NII_Ha_ALL                    OH_Re_fit_N2O2
# e_alpha_OH_Re_fit_ONS               ZH_LW_Re_fit_M_t60                  log_OIII_Hb_ALL                     e_OH_Re_fit_N2O2
# cc_r_OH_ONS                         e_ZH_LW_Re_fit_M_t60                e_log_OIII_Hb_ALL                   alpha_OH_Re_fit_N2O2
# sig_r_OH_ONS                        alpha_ZH_LW_Re_fit_M_t60            log_SII_Ha_ALL                      e_alpha_OH_Re_fit_N2O2
# OH_Re_fit_R23                       e_alpha_ZH_LW_Re_fit_M_t60          e_log_SII_Ha_ALL                    cc_r_OH_N2O2
# e_OH_Re_fit_R23                     cc_ZH_LW_Re_M_t60                   log_OII_Hb_ALL                      sig_r_OH_N2O2
# alpha_OH_Re_fit_R23                 sig_ZH_LW_Re_M_t60                  e_log_OII_Hb_ALL                    log_Mass_in_Re
# e_alpha_OH_Re_fit_R23               ZH_LW_Re_fit_M_t70                  log_OI_Ha_ALL                       ML_int
# cc_r_OH_R23                         e_ZH_LW_Re_fit_M_t70                e_log_OI_Ha_ALL                     ML_avg
# sig_r_OH_R23                        alpha_ZH_LW_Re_fit_M_t70            EW_Ha_ALL                           log_Mass_Re_derived
# stats_OH_Re_mean_mean               e_alpha_ZH_LW_Re_fit_M_t70          e_EW_Ha_ALL                         F_Ha_cen
# stats_OH_Re_mean_stddev             cc_ZH_LW_Re_M_t70                   Ha_Hb_ALL                           e_F_Ha_cen
# stats_a_OH_Re_mean_mean             sig_ZH_LW_Re_M_t70                  Ha_Hb_ALL1                          Re_kpc_Mass
# stats_a_OH_Re_mean_stddev           ZH_LW_Re_fit_M_t80                  OH_O3N2_Re1                         R50_kpc_V
# log_Mass                            e_ZH_LW_Re_fit_M_t80                e_OH_O3N2_Re                        e_R50_kpc_V
# log_SFR_ssp                         alpha_ZH_LW_Re_fit_M_t80            OH_N2_Re                            R50_kpc_Mass
# log_NII_Ha_cen_mean                 e_alpha_ZH_LW_Re_fit_M_t80          e_OH_N2_Re                          e_R50_kpc_Mass
# log_NII_Ha_cen_stddev               cc_ZH_LW_Re_M_t80                   OH_ONS_Re                           log_Mass_corr_in_R50_V
# log_OIII_Hb_cen_mean                sig_ZH_LW_Re_M_t80                  e_OH_ONS_Re                         e_log_Mass_corr_in_R50_V
# log_OIII_Hb_cen_stddev              ZH_LW_Re_fit_M_t90                  OH_R23_Re                           log_Mass_in_Re1
# log_SII_Ha_cen_mean                 e_ZH_LW_Re_fit_M_t90                e_OH_R23_Re                         rMgMs_zp
# log_SII_Ha_cen_stddev               alpha_ZH_LW_Re_fit_M_t90            OH_pyqz_Re                          rMgMs_e_zp
# log_OII_Hb_cen_mean                 e_alpha_ZH_LW_Re_fit_M_t90          e_OH_pyqz_Re                        rMgMs_alpha
# log_OII_Hb_cen_stddev               cc_ZH_LW_Re_M_t90                   OH_t2_Re                            rMgMs_e_alpha
# EW_Ha_cen_mean                      sig_ZH_LW_Re_M_t90                  e_OH_t2_Re                          rMgMs_cc
# EW_Ha_cen_stddev                    ZH_LW_Re_fit_t50                    OH_M08_Re                           rMgMs_sig
# stats_y_200_mean                    e_ZH_LW_Re_fit_t50                  e_OH_M08_Re                         rSFMS_zp
# stats_y_200_stddev                  alpha_ZH_LW_Re_fit_t50              OH_T04_Re                           rSFMS_e_zp
# stats_y_30_mean                     e_alpha_ZH_LW_Re_fit_t50            e_OH_T04_Re                         rSFMS_alpha
# stats_y_30_stddev                   cc_ZH_LW_Re_t50                     OH_dop_Re                           rSFMS_e_alpha
# stats_EW_Ha_mean                    sig_ZH_LW_Re_t50                    e_OH_dop_Re                         rSFMS_cc
# stats_EW_Ha_stddev                  ZH_LW_Re_fit_t60                    OH_O3N2_EPM09_Re                    rSFMS_sig
# ZH_LW_Re_fit                        e_ZH_LW_Re_fit_t60                  e_OH_O3N2_EPM09_Re                  rSK_zp
# e_ZH_LW_Re_fit                      alpha_ZH_LW_Re_fit_t60              OH_O3N2_ALL                         rSK_e_zp
# alpha_ZH_LW_Re_fit                  e_alpha_ZH_LW_Re_fit_t60            e_OH_O3N2_ALL                       rSK_alpha
# e_alpha_ZH_LW_Re_fit                cc_ZH_LW_Re_t60                     OH_N2_ALL                           rSK_e_alpha
# ZH_LW_lRe_fit                       sig_ZH_LW_Re_t60                    e_OH_N2_ALL                         rSK_cc
# e_ZH_LW_lRe_fit                     ZH_LW_Re_fit_t70                    OH_ONS_ALL                          rSK_sig
# alpha_ZH_LW_lRe_fit                 e_ZH_LW_Re_fit_t70                  e_OH_ONS_ALL                        log_Mass_gas_Av_EW_corr
# e_alpha_ZH_LW_lRe_fit               alpha_ZH_LW_Re_fit_t70              OH_R23_ALL                          log_Mass_gas_Av_gas_log_lin
# ZH_MW_Re_fit                        e_alpha_ZH_LW_Re_fit_t70            e_OH_R23_ALL                        log_Mass_gas_Av_ssp_log_lin
# e_ZH_MW_Re_fit                      cc_ZH_LW_Re_t70                     OH_pyqz_ALL                         log_Mass_gas_Av_gas_log_log
# alpha_ZH_MW_Re_fit                  sig_ZH_LW_Re_t70                    e_OH_pyqz_ALL                       OH_Re_fit_R
# e_alpha_ZH_MW_Re_fit                ZH_LW_Re_fit_t80                    OH_t2_ALL                           e_OH_Re_fit_R
# Age_LW_Re_fit                       e_ZH_LW_Re_fit_t80                  e_OH_t2_ALL                         alpha_OH_Re_fit_R
# e_Age_LW_Re_fit                     alpha_ZH_LW_Re_fit_t80              OH_M08_ALL                          e_alpha_OH_Re_fit_R
# alpha_Age_LW_Re_fit                 e_alpha_ZH_LW_Re_fit_t80            e_OH_M08_ALL                        cc_r_OH_R
# e_alpha_Age_LW_Re_fit               cc_ZH_LW_Re_t80                     OH_T04_ALL                          sig_r_OH_R
# Age_LW_lRe_fit                      sig_ZH_LW_Re_t80                    e_OH_T04_ALL                        OH_R_cen_mean
# e_Age_LW_lRe_fit                    ZH_LW_Re_fit_t90                    OH_dop_ALL                          OH_R_cen_error
# alpha_Age_LW_lRe_fit                e_ZH_LW_Re_fit_t90                  e_OH_dop_ALL                        OH_R_Re_mean
# e_alpha_Age_LW_lRe_fit              alpha_ZH_LW_Re_fit_t90              OH_O3N2_EPM09_ALL                   OH_R_Re_error
# Age_MW_Re_fit                       e_alpha_ZH_LW_Re_fit_t90            e_OH_O3N2_EPM09_ALL                 OH_R_ALL_mean
# e_Age_MW_Re_fit                     cc_ZH_LW_Re_t90                     Sigma_Mass_cen                      OH_R_ALL_error
# alpha_Age_MW_Re_fit                 sig_ZH_LW_Re_t90                    e_Sigma_Mass_cen                    OH_Re_fit_S
# e_alpha_Age_MW_Re_fit               OH_Re_fit_M08                       Sigma_Mass_Re                       e_OH_Re_fit_S
# ZH_LW_Re_fit_0_0.5_Gyr              e_OH_Re_fit_M08                     e_Sigma_Mass_Re                     alpha_OH_Re_fit_S
# e_ZH_LW_Re_fit_0_0.5_Gyr            alpha_OH_Re_fit_M08                 Sigma_Mass_ALL                      e_alpha_OH_Re_fit_S
# alpha_ZH_LW_Re_fit_0_0.5_Gyr        e_alpha_OH_Re_fit_M08               e_Sigma_Mass_ALL                    cc_r_OH_S
# e_alpha_ZH_LW_Re_fit_0_0.5_Gyr      cc_r_OH_M08                         OH_Re_fit_ON                        sig_r_OH_S
# ZH_LW_Re_fit_0.5_2.0_Gyr            sig_r_OH_M08                        e_OH_Re_fit_ON                      OH_S_cen_mean
# e_ZH_LW_Re_fit_0.5_2.0_Gyr          OH_Re_fit_T04                       alpha_OH_Re_fit_ON                  OH_S_cen_error
# alpha_ZH_LW_Re_fit_0.5_2.0_Gyr      e_OH_Re_fit_T04                     e_alpha_OH_Re_fit_ON                OH_S_Re_mean
# e_alpha_ZH_LW_Re_fit_0.5_2.0_Gyr    alpha_OH_Re_fit_T04                 cc_r_OH_ON                          OH_S_Re_error
# ZH_LW_Re_fit2.0_14.0_Gyr            e_alpha_OH_Re_fit_T04               sig_r_OH_ON                         OH_S_ALL_mean
# e_ZH_LW_Re_fit2.0_14.0_Gyr          cc_r_OH_T04                         OH_ON_Re                            OH_S_ALL_error
# alpha_ZH_LW_Re_fit2.0_14.0_Gyr      sig_r_OH_T04                        e_OH_ON_Re                          NH_Re_fit_R
# e_alpha_ZH_LW_Re_fit2.0_14.0_Gyr    NH_Re_fit_ONS                       OH_ON_cen                           e_NH_Re_fit_R
# Re_arc                              e_NH_Re_fit_ONS                     e_OH_ON_cen                         alpha_NH_Re_fit_R
# Re_kpc1                             alpha_NH_Re_fit_ONS                 OH_ON_ALL                           e_alpha_NH_Re_fit_R
# DL                                  e_alpha_NH_Re_fit_ONS               e_OH_ON_ALL                         cc_r_NH_R
# DA                                  cc_r_NH_ONS                         T30                                 sig_r_NH_R
# P.A.                                sig_r_NH_ONS                        ZH_T30                              NH_R_cen_mean
# Ellipticity                         NO_Re_fit_ONS                       ZH_Re_T30                           NH_R_cen_error
# Inclination                         e_NO_Re_fit_ONS                     a_ZH_T30                            NH_R_Re_mean
# sigma_cen                           alpha_NO_Re_fit_ONS                 T40                                 NH_R_Re_error
# e_sigma_cen                         e_alpha_NO_Re_fit_ONS               ZH_T40                              NH_R_ALL_mean
# lambda_Re                           cc_r_NO_ONS                         ZH_Re_T40                           NH_R_ALL_error
# e_lambda_Re                         sig_r_NO_ONS                        a_ZH_T40
# elip_ab                             OH_Re_fit_dop                       T501

# %%
#
# Reading Mag table
#
get_mag_cubes="tables/get_mag_cubes_v3_1_1_redshift.csv"
col_mag_cubes=header_columns_space(get_mag_cubes,2)
tab_mag=ascii.read(get_mag_cubes, delimiter=',', guess=True, comment='\s*#', names=col_mag_cubes,\
                      fill_values=[('BAD', np.nan)])
#print(tab_pe)
tab_mag.rename_column('name-obj', 'name')
list_columns(col_mag_cubes)
# Out:
# name-obj                   i_band_mag_error           Y_centroid                 SN_at_R50
# redshift                   i_band_abs_mag             Re                         error_SN_at_R50
# error_redshift             i_band_abs_mag_error       error_Re                   Re1
# u_band_mag                 B_band_mag                 mean_S/N_at_Re             error_Re1
# u_band_mag_error           B_band_mag_error           sigma_S/N_at_Re            B-V
# u_band_abs_mag             B_band_abs_mag             ellipticy                  error_B-V
# u_band_abs_mag_error       B_band_abs_mag_error       Pa                         B-R
# g_band_mag                 V_band_mag                 R50                        error_B-R
# g_band_mag_error           V_band_mag_error           error_R50                  log10_Mass/Msun_phot.
# g_band_abs_mag             V_band_abs_mag             R90                        error_Mass_phot.
# g_band_abs_mag_error       V_band_abs_mag_error       error_R90                  nRe
# r_band_mag                 R_band_mag                 C                          V-band_SB_at_Re
# r_band_mag_error           R_band_mag_error           e_C                        error_V-band_SB_at_Re
# r_band_abs_mag             R_band_abs_mag             SN_at_Re                   V-band_SB_at_R_50
# r_band_abs_mag_error       R_band_abs_mag_error       error_SN_at_Re             error_V-band_SB_at_R_50
# i_band_mag                 X_centroid                 SN_integrated

# %%
#
# Reading Indices at Re
#
get_ind_Re="tables/get_val_ind_Re_MaNGA.csv"
col_ind_Re=header_columns_space(get_ind_Re,2)
tab_ind_Re=ascii.read(get_ind_Re, delimiter=',', guess=True, comment='\s*#', names=col_ind_Re,\
                      fill_values=[('BAD', np.nan)])
#print(tab_ind_Re)
tab_ind_Re.rename_column('MaNGA_name', 'name')
list_columns(tab_ind_Re.columns)
# Out:
# name        Mgb         e_Fe5335    Hg
# Hd          e_Mgb       e4000       e_Hg
# e_Hd        Fe5270      e_e4000     SN
# Hb          e_Fe5270    Hdmod       e_SN
# e_Hb        Fe5335      e_Hdmod

# %%
#
# Reading Indices at Re
#
get_ind="tables/get_proc_indices_MaNGA.clean.csv"
col_ind=header_columns_space(get_ind,2)
tab_ind=ascii.read(get_ind, delimiter=',', guess=True, comment='\s*#', names=col_ind,\
                      fill_values=[('BAD', np.nan)])
#print(tab_ind_Re)
#tab_ind_Re.rename_column('MaNGA_name', 'name')
list_columns(tab_ind.columns)
# Out:
# MaNGA_name            e_D4000_fit           e_Hb_Re_fit           e_D4000_Re_fit
# nsa_redshift          slope_D4000           Hb_alpha_fit          D4000_alpha_fit
# nsa_u_absmag          e_slope_D4000         e_Hb_alpha_fit        e_D4000_alpha_fit
# nsa_z_absmag          D4000_OH_fit          Mgb_Re_fit            Hdmod_Re_fit
# nsa_u_z_absmag        e_D4000_fit1          e_Mgb_Re_fit          e_Hdmod_Re_fit
# nsa_mstar             slope_D4000_OH        Mgb_alpha_fit         Hdmod_alpha_fit
# nsa_inclination       e_slope_D4000_OH      e_Mgb_alpha_fit       e_Hdmod_alpha_fit
# nsa_petro_th50        Sgas_OH_fit           Fe5270_Re_fit         Hg_Re_fit
# nsa_sersic_ba         e_Sgas_fit            e_Fe5270_Re_fit       e_Hg_Re_fit
# nsa_sersic_n          slope_Sgas_OH         Fe5270_alpha_fit      Hg_alpha_fit
# nsa_sersic_phi        e_slope_Sgas          e_Fe5270_alpha_fit    e_Hg_alpha_fit
# nsa_sersic_th50       Hd_Re_fit             Fe5335_Re_fit         SN_Re_fit
# name                  e_Hd_Re_fit           e_Fe5335_Re_fit       e_SN_Re_fit
# D4000                 Hd_alpha_fit          Fe5335_alpha_fit      SN_alpha_fit
# e_D4000               e_Hd_alpha_fit        e_Fe5335_alpha_fit    e_SN_alpha_fit
# D4000_Re_fit          Hb_Re_fit             D4000_Re_fit1

# %%
#
# Reading Indices at Re
#
get_Re="tables/get_val_Re_MaNGA.csv"
col_Re=header_columns_space(get_Re,2)
tab_val_Re=ascii.read(get_Re, delimiter=',', guess=True, comment='\s*#', names=col_Re,\
                      fill_values=[('BAD', np.nan)])
#print(tab_ind_Re)
tab_val_Re.rename_column('MaNGA_name', 'name')
list_columns(tab_val_Re.columns)
# Out:
# name                    e_Age_LW                e_disp_Ha               e_ML
# Sigma_Mass_stars        Age_MW                  vel_Ha                  Sigma_SFR_ssp
# e_Sigma_Mass_stars      e_Age_MW                e_vel_Ha                e_Sigma_SFR_ssp
# Sigma_SFR               OH_t2                   vel_ssp                 Sigma_Mass_gas_rad
# e_Sigma_SFR             e_OH_t2                 e_vel_ssp               e_Sigma_Mass_gas_rad
# Sigma_Mass_gas          OH_O3N2                 SK_ssp                  Lambda
# e_Sigma_Mass_gas        e_OH_O3N2               e_SK_ssp                e_Lambda
# Sigma_Mass_gas_ssp      Av_gas                  SK_Ha                   OH_ONS
# e_Sigma_Mass_gas_ssp    e_Av_gas                e_SK_Ha                 e_OH_ONS
# ZH_LW                   Av_ssp                  KIN_ssp                 NO_ONS
# e_ZH_LW                 e_Av_ssp                e_KIN_ssp               e_NO_ONS
# ZH_MW                   disp_ssp                KIN_Ha                  NO_N2S2
# e_ZH_MW                 e_disp_ssp              e_KIN_Ha                e_NO_N2S2
# Age_LW                  disp_Ha                 ML

# %%
#
# Reading Indices at Re
#
get_in_Re="tables/get_val_within_Re_MaNGA.csv"
col_in_Re=header_columns_space(get_in_Re,2)
tab_val_in_Re=ascii.read(get_in_Re, delimiter=',', guess=True, comment='\s*#', names=col_in_Re,\
                      fill_values=[('BAD', np.nan)])
list_col_names=tab_val_in_Re.columns.copy()
for col_name in list_col_names:
    new_col_name="in_"+col_name
    tab_val_in_Re.rename_column(col_name, new_col_name)
#print(tab_ind_Re)
tab_val_in_Re.rename_column('in_MaNGA_name', 'name')
list_columns(tab_val_in_Re.columns)
# Out:
# name                       in_e_Age_LW                in_e_disp_Ha               in_e_ML
# in_Sigma_Mass_stars        in_Age_MW                  in_vel_Ha                  in_Sigma_SFR_ssp
# in_e_Sigma_Mass_stars      in_e_Age_MW                in_e_vel_Ha                in_e_Sigma_SFR_ssp
# in_Sigma_SFR               in_OH_t2                   in_vel_ssp                 in_Sigma_Mass_gas_rad
# in_e_Sigma_SFR             in_e_OH_t2                 in_e_vel_ssp               in_e_Sigma_Mass_gas_rad
# in_Sigma_Mass_gas          in_OH_O3N2                 in_SK_ssp                  in_Lambda
# in_e_Sigma_Mass_gas        in_e_OH_O3N2               in_e_SK_ssp                in_e_Lambda
# in_Sigma_Mass_gas_ssp      in_Av_gas                  in_SK_Ha                   in_OH_ONS
# in_e_Sigma_Mass_gas_ssp    in_e_Av_gas                in_e_SK_Ha                 in_e_OH_ONS
# in_ZH_LW                   in_Av_ssp                  in_KIN_ssp                 in_NO_ONS
# in_e_ZH_LW                 in_e_Av_ssp                in_e_KIN_ssp               in_e_NO_ONS
# in_ZH_MW                   in_disp_ssp                in_KIN_Ha                  in_NO_N2S2
# in_e_ZH_MW                 in_e_disp_ssp              in_e_KIN_Ha                in_e_NO_N2S2
# in_Age_LW                  in_disp_Ha                 in_ML

# %%
#
# Reading flux_elines_table
#
get_p_fe="tables/get_proc_flux_elines_MaNGA.clean.csv"
col_p_fe=header_columns_space(get_p_fe,2)
tab_fe=ascii.read(get_p_fe, delimiter=',', guess=True, comment='\s*#', names=col_p_fe,\
                      fill_values=[('BAD', np.nan)])
print(len(tab_fe))
list_columns(tab_fe.columns)


#tab_mag.rename_column('name-obj', 'name')
# Out:
# 10154
# MaNGA_name                          e_flux_HI3889.05_alpha_fit          e_flux_[OIII]5006.84_alpha_fit      e_flux_Halpha6562.85_alpha_fit
# nsa_redshift                        flux_HeI3964.73_Re_fit              flux_HeI5015.68_Re_fit              flux_[NII]6583.45_Re_fit
# nsa_u_absmag                        e_flux_HeI3964.73_Re_fit            e_flux_HeI5015.68_Re_fit            e_flux_[NII]6583.45_Re_fit
# nsa_z_absmag                        flux_HeI3964.73_alpha_fit           flux_HeI5015.68_alpha_fit           flux_[NII]6583.45_alpha_fit
# nsa_u_z_absmag                      e_flux_HeI3964.73_alpha_fit         e_flux_HeI5015.68_alpha_fit         e_flux_[NII]6583.45_alpha_fit
# nsa_mstar                           flux_[NeIII]3967.46_Re_fit          flux_[NI]5197.9_Re_fit              flux_[SII]6716.44_Re_fit
# nsa_inclination                     e_flux_[NeIII]3967.46_Re_fit        e_flux_[NI]5197.9_Re_fit            e_flux_[SII]6716.44_Re_fit
# nsa_petro_th50                      flux_[NeIII]3967.46_alpha_fit       flux_[NI]5197.9_alpha_fit           flux_[SII]6716.44_alpha_fit
# nsa_sersic_ba                       e_flux_[NeIII]3967.46_alpha_fit     e_flux_[NI]5197.9_alpha_fit         e_flux_[SII]6716.44_alpha_fit
# nsa_sersic_n                        flux_CaII3968.47_Re_fit             flux_[NI]5200.26_Re_fit             flux_[SII]6730.82_Re_fit
# nsa_sersic_phi                      e_flux_CaII3968.47_Re_fit           e_flux_[NI]5200.26_Re_fit           e_flux_[SII]6730.82_Re_fit
# nsa_sersic_th50                     flux_CaII3968.47_alpha_fit          flux_[NI]5200.26_alpha_fit          flux_[SII]6730.82_alpha_fit
# name                                e_flux_CaII3968.47_alpha_fit        e_flux_[NI]5200.26_alpha_fit        e_flux_[SII]6730.82_alpha_fit
# flux_[OII]3726.03_Re_fit            flux_Hepsilon3970.07_Re_fit         flux_HeI5876.0_Re_fit               flux_[ArIII]7135.8_Re_fit
# e_flux_[OII]3726.03_Re_fit          e_flux_Hepsilon3970.07_Re_fit       e_flux_HeI5876.0_Re_fit             e_flux_[ArIII]7135.8_Re_fit
# flux_[OII]3726.03_alpha_fit         flux_Hepsilon3970.07_alpha_fit      flux_HeI5876.0_alpha_fit            flux_[ArIII]7135.8_alpha_fit
# e_flux_[OII]3726.03_alpha_fit       e_flux_Hepsilon3970.07_alpha_fit    e_flux_HeI5876.0_alpha_fit          e_flux_[ArIII]7135.8_alpha_fit
# flux_[OII]3728.82_Re_fit            flux_Hdelta4101.77_Re_fit           flux_NaI5889.95_Re_fit              flux_HI9014.91_Re_fit
# e_flux_[OII]3728.82_Re_fit          e_flux_Hdelta4101.77_Re_fit         e_flux_NaI5889.95_Re_fit            e_flux_HI9014.91_Re_fit
# flux_[OII]3728.82_alpha_fit         flux_Hdelta4101.77_alpha_fit        flux_NaI5889.95_alpha_fit           flux_HI9014.91_alpha_fit
# e_flux_[OII]3728.82_alpha_fit       e_flux_Hdelta4101.77_alpha_fit      e_flux_NaI5889.95_alpha_fit         e_flux_HI9014.91_alpha_fit
# flux_HI3734.37_Re_fit               flux_Hgamma4340.49_Re_fit           flux_NaI5895.92_Re_fit              flux_[SIII]9069.0_Re_fit
# e_flux_HI3734.37_Re_fit             e_flux_Hgamma4340.49_Re_fit         e_flux_NaI5895.92_Re_fit            e_flux_[SIII]9069.0_Re_fit
# flux_HI3734.37_alpha_fit            flux_Hgamma4340.49_alpha_fit        flux_NaI5895.92_alpha_fit           flux_[SIII]9069.0_alpha_fit
# e_flux_HI3734.37_alpha_fit          e_flux_Hgamma4340.49_alpha_fit      e_flux_NaI5895.92_alpha_fit         e_flux_[SIII]9069.0_alpha_fit
# flux_HI3797.9_Re_fit                flux_Hbeta4861.36_Re_fit            flux_[OI]6300.3_Re_fit              flux_[FeII]9470.93_Re_fit
# e_flux_HI3797.9_Re_fit              e_flux_Hbeta4861.36_Re_fit          e_flux_[OI]6300.3_Re_fit            e_flux_[FeII]9470.93_Re_fit
# flux_HI3797.9_alpha_fit             flux_Hbeta4861.36_alpha_fit         flux_[OI]6300.3_alpha_fit           flux_[FeII]9470.93_alpha_fit
# e_flux_HI3797.9_alpha_fit           e_flux_Hbeta4861.36_alpha_fit       e_flux_[OI]6300.3_alpha_fit         e_flux_[FeII]9470.93_alpha_fit
# flux_HeI3888.65_Re_fit              flux_[OIII]4958.91_Re_fit           flux_[NII]6548.05_Re_fit            flux_[SIII]9531.1_Re_fit
# e_flux_HeI3888.65_Re_fit            e_flux_[OIII]4958.91_Re_fit         e_flux_[NII]6548.05_Re_fit          e_flux_[SIII]9531.1_Re_fit
# flux_HeI3888.65_alpha_fit           flux_[OIII]4958.91_alpha_fit        flux_[NII]6548.05_alpha_fit         flux_[SIII]9531.1_alpha_fit
# e_flux_HeI3888.65_alpha_fit         e_flux_[OIII]4958.91_alpha_fit      e_flux_[NII]6548.05_alpha_fit       e_flux_[SIII]9531.1_alpha_fit
# flux_HI3889.05_Re_fit               flux_[OIII]5006.84_Re_fit           flux_Halpha6562.85_Re_fit
# e_flux_HI3889.05_Re_fit             e_flux_[OIII]5006.84_Re_fit         e_flux_Halpha6562.85_Re_fit
# flux_HI3889.05_alpha_fit            flux_[OIII]5006.84_alpha_fit        flux_Halpha6562.85_alpha_fit

# %%
#
# Reading flux_elines_table
#
get_p_fe_org="tables/get_proc_flux_elines_org_MaNGA.clean.csv"
col_p_fe_org=header_columns_space(get_p_fe_org,2)
tab_fe_org=ascii.read(get_p_fe_org, delimiter=',', guess=True, comment='\s*#', names=col_p_fe_org,\
                      fill_values=[('BAD', np.nan)])
#print(tab_pe)
#tab_mag.rename_column('name-obj', 'name')
#list_columns(col_p_fe_org)
print(len(tab_fe_org))
list_columns(tab_fe_org.columns)


#tab_mag.rename_column('name-obj', 'name')
# Out:
# 10156
# MaNGA_name                           EW_[SII]4076_Re_fit                  e_disp_[OIII]4958_Re_fit             l_flux_[SIII]6312_Ha_alpha_fit
# nsa_redshift                         e_EW_[SII]4076_Re_fit                disp_[OIII]4958_alpha_fit            e_l_flux_[SIII]6312_Ha_alpha_fit
# nsa_u_absmag                         EW_[SII]4076_alpha_fit               e_disp_[OIII]4958_alpha_fit          l_flux_SiII6347_Ha_Re_fit
# nsa_z_absmag                         e_EW_[SII]4076_alpha_fit             disp_Hb4861_Re_fit                   e_l_flux_SiII6347_Ha_Re_fit
# nsa_u_z_absmag                       EW_Hd4101_Re_fit                     e_disp_Hb4861_Re_fit                 l_flux_SiII6347_Ha_alpha_fit
# nsa_mstar                            e_EW_Hd4101_Re_fit                   disp_Hb4861_alpha_fit                e_l_flux_SiII6347_Ha_alpha_fit
# nsa_inclination                      EW_Hd4101_alpha_fit                  e_disp_Hb4861_alpha_fit              l_flux_[OI]6363_Ha_Re_fit
# nsa_petro_th50                       e_EW_Hd4101_alpha_fit                disp_[FeII]4889_Re_fit               e_l_flux_[OI]6363_Ha_Re_fit
# nsa_sersic_ba                        EW_[FeII]4276_Re_fit                 e_disp_[FeII]4889_Re_fit             l_flux_[OI]6363_Ha_alpha_fit
# nsa_sersic_n                         e_EW_[FeII]4276_Re_fit               disp_[FeII]4889_alpha_fit            e_l_flux_[OI]6363_Ha_alpha_fit
# nsa_sersic_phi                       EW_[FeII]4276_alpha_fit              e_disp_[FeII]4889_alpha_fit          l_flux_Ha6562_Ha_Re_fit
# nsa_sersic_th50                      e_EW_[FeII]4276_alpha_fit            disp_[FeII]4905_Re_fit               e_l_flux_Ha6562_Ha_Re_fit
# name                                 EW_[FeII]4287_Re_fit                 e_disp_[FeII]4905_Re_fit             l_flux_Ha6562_Ha_alpha_fit
# flux_[OII]3727_Re_fit                e_EW_[FeII]4287_Re_fit               disp_[FeII]4905_alpha_fit            e_l_flux_Ha6562_Ha_alpha_fit
# e_flux_[OII]3727_Re_fit              EW_[FeII]4287_alpha_fit              e_disp_[FeII]4905_alpha_fit          l_flux_[NII]6583_Ha_Re_fit
# flux_[OII]3727_alpha_fit             e_EW_[FeII]4287_alpha_fit            disp_[FeII]5111_Re_fit               e_l_flux_[NII]6583_Ha_Re_fit
# e_flux_[OII]3727_alpha_fit           EW_[FeII]4319_Re_fit                 e_disp_[FeII]5111_Re_fit             l_flux_[NII]6583_Ha_alpha_fit
# flux_H123750_Re_fit                  e_EW_[FeII]4319_Re_fit               disp_[FeII]5111_alpha_fit            e_l_flux_[NII]6583_Ha_alpha_fit
# e_flux_H123750_Re_fit                EW_[FeII]4319_alpha_fit              e_disp_[FeII]5111_alpha_fit          l_flux_[NII]6548_Ha_Re_fit
# flux_H123750_alpha_fit               e_EW_[FeII]4319_alpha_fit            disp_[FeII]5158_Re_fit               e_l_flux_[NII]6548_Ha_Re_fit
# e_flux_H123750_alpha_fit             EW_Hg4340_Re_fit                     e_disp_[FeII]5158_Re_fit             l_flux_[NII]6548_Ha_alpha_fit
# flux_H113771_Re_fit                  e_EW_Hg4340_Re_fit                   disp_[FeII]5158_alpha_fit            e_l_flux_[NII]6548_Ha_alpha_fit
# e_flux_H113771_Re_fit                EW_Hg4340_alpha_fit                  e_disp_[FeII]5158_alpha_fit          l_flux_HeI6677_Ha_Re_fit
# flux_H113771_alpha_fit               e_EW_Hg4340_alpha_fit                disp_[NI]5199_Re_fit                 e_l_flux_HeI6677_Ha_Re_fit
# e_flux_H113771_alpha_fit             EW_[OIII]4363_Re_fit                 e_disp_[NI]5199_Re_fit               l_flux_HeI6677_Ha_alpha_fit
# flux_H103798_Re_fit                  e_EW_[OIII]4363_Re_fit               disp_[NI]5199_alpha_fit              e_l_flux_HeI6677_Ha_alpha_fit
# e_flux_H103798_Re_fit                EW_[OIII]4363_alpha_fit              e_disp_[NI]5199_alpha_fit            l_flux_[SII]6716_Ha_Re_fit
# flux_H103798_alpha_fit               e_EW_[OIII]4363_alpha_fit            disp_[FeII]5261_Re_fit               e_l_flux_[SII]6716_Ha_Re_fit
# e_flux_H103798_alpha_fit             EW_[FeII]4413_Re_fit                 e_disp_[FeII]5261_Re_fit             l_flux_[SII]6716_Ha_alpha_fit
# flux_HeI3819_Re_fit                  e_EW_[FeII]4413_Re_fit               disp_[FeII]5261_alpha_fit            e_l_flux_[SII]6716_Ha_alpha_fit
# e_flux_HeI3819_Re_fit                EW_[FeII]4413_alpha_fit              e_disp_[FeII]5261_alpha_fit          l_flux_[SII]6730_Ha_Re_fit
# flux_HeI3819_alpha_fit               e_EW_[FeII]4413_alpha_fit            disp_[ClIII]5517_Re_fit              e_l_flux_[SII]6730_Ha_Re_fit
# e_flux_HeI3819_alpha_fit             EW_[FeII]4416_Re_fit                 e_disp_[ClIII]5517_Re_fit            l_flux_[SII]6730_Ha_alpha_fit
# flux_H93835_Re_fit                   e_EW_[FeII]4416_Re_fit               disp_[ClIII]5517_alpha_fit           e_l_flux_[SII]6730_Ha_alpha_fit
# e_flux_H93835_Re_fit                 EW_[FeII]4416_alpha_fit              e_disp_[ClIII]5517_alpha_fit         l_flux_[ArIII]7136_Ha_Re_fit
# flux_H93835_alpha_fit                e_EW_[FeII]4416_alpha_fit            disp_[ClIII]5537_Re_fit              e_l_flux_[ArIII]7136_Ha_Re_fit
# e_flux_H93835_alpha_fit              EW_HeI4471_Re_fit                    e_disp_[ClIII]5537_Re_fit            l_flux_[ArIII]7136_Ha_alpha_fit
# flux_[NeIII]3869_Re_fit              e_EW_HeI4471_Re_fit                  disp_[ClIII]5537_alpha_fit           e_l_flux_[ArIII]7136_Ha_alpha_fit
# e_flux_[NeIII]3869_Re_fit            EW_HeI4471_alpha_fit                 e_disp_[ClIII]5537_alpha_fit         l_flux_[OII]7325_Ha_Re_fit
# flux_[NeIII]3869_alpha_fit           e_EW_HeI4471_alpha_fit               disp_OI5554_Re_fit                   e_l_flux_[OII]7325_Ha_Re_fit
# e_flux_[NeIII]3869_alpha_fit         EW_[FeIII]4657_Re_fit                e_disp_OI5554_Re_fit                 l_flux_[OII]7325_Ha_alpha_fit
# flux_H83889_Re_fit                   e_EW_[FeIII]4657_Re_fit              disp_OI5554_alpha_fit                e_l_flux_[OII]7325_Ha_alpha_fit
# e_flux_H83889_Re_fit                 EW_[FeIII]4657_alpha_fit             e_disp_OI5554_alpha_fit              l_flux_[ArIII]7751_Ha_Re_fit
# flux_H83889_alpha_fit                e_EW_[FeIII]4657_alpha_fit           disp_[OI]5577_Re_fit                 e_l_flux_[ArIII]7751_Ha_Re_fit
# e_flux_H83889_alpha_fit              EW_HeII4686_Re_fit                   e_disp_[OI]5577_Re_fit               l_flux_[ArIII]7751_Ha_alpha_fit
# flux_[NeIII]3967_Re_fit              e_EW_HeII4686_Re_fit                 disp_[OI]5577_alpha_fit              e_l_flux_[ArIII]7751_Ha_alpha_fit
# e_flux_[NeIII]3967_Re_fit            EW_HeII4686_alpha_fit                e_disp_[OI]5577_alpha_fit            l_flux_[SIII]9068_Ha_Re_fit
# flux_[NeIII]3967_alpha_fit           e_EW_HeII4686_alpha_fit              disp_[NII]5754_Re_fit                e_l_flux_[SIII]9068_Ha_Re_fit
# e_flux_[NeIII]3967_alpha_fit         EW_HeI4712_Re_fit                    e_disp_[NII]5754_Re_fit              l_flux_[SIII]9068_Ha_alpha_fit
# flux_He3970_Re_fit                   e_EW_HeI4712_Re_fit                  disp_[NII]5754_alpha_fit             e_l_flux_[SIII]9068_Ha_alpha_fit
# e_flux_He3970_Re_fit                 EW_HeI4712_alpha_fit                 e_disp_[NII]5754_alpha_fit           l_flux_[SIII]9530_Ha_Re_fit
# flux_He3970_alpha_fit                e_EW_HeI4712_alpha_fit               disp_HeI5875_Re_fit                  e_l_flux_[SIII]9530_Ha_Re_fit
# e_flux_He3970_alpha_fit              EW_HeI4922_Re_fit                    e_disp_HeI5875_Re_fit                l_flux_[SIII]9530_Ha_alpha_fit
# flux_HeI4026_Re_fit                  e_EW_HeI4922_Re_fit                  disp_HeI5875_alpha_fit               e_l_flux_[SIII]9530_Ha_alpha_fit
# e_flux_HeI4026_Re_fit                EW_HeI4922_alpha_fit                 e_disp_HeI5875_alpha_fit             l_flux0_Ha_Re_fit
# flux_HeI4026_alpha_fit               e_EW_HeI4922_alpha_fit               disp_[OI]6300_Re_fit                 e_l_flux0_Ha_Re_fit
# e_flux_HeI4026_alpha_fit             EW_[OIII]5006_Re_fit                 e_disp_[OI]6300_Re_fit               l_flux0_Ha_alpha_fit
# flux_[SII]4069_Re_fit                e_EW_[OIII]5006_Re_fit               disp_[OI]6300_alpha_fit              e_l_flux0_Ha_alpha_fit
# e_flux_[SII]4069_Re_fit              EW_[OIII]5006_alpha_fit              e_disp_[OI]6300_alpha_fit            l_flux_[OII]3727_Hb_Re_fit
# flux_[SII]4069_alpha_fit             e_EW_[OIII]5006_alpha_fit            disp_[SIII]6312_Re_fit               e_l_flux_[OII]3727_Hb_Re_fit
# e_flux_[SII]4069_alpha_fit           EW_[OIII]4958_Re_fit                 e_disp_[SIII]6312_Re_fit             l_flux_[OII]3727_Hb_alpha_fit
# flux_[SII]4076_Re_fit                e_EW_[OIII]4958_Re_fit               disp_[SIII]6312_alpha_fit            e_l_flux_[OII]3727_Hb_alpha_fit
# e_flux_[SII]4076_Re_fit              EW_[OIII]4958_alpha_fit              e_disp_[SIII]6312_alpha_fit          l_flux_H123750_Hb_Re_fit
# flux_[SII]4076_alpha_fit             e_EW_[OIII]4958_alpha_fit            disp_SiII6347_Re_fit                 e_l_flux_H123750_Hb_Re_fit
# e_flux_[SII]4076_alpha_fit           EW_Hb4861_Re_fit                     e_disp_SiII6347_Re_fit               l_flux_H123750_Hb_alpha_fit
# flux_Hd4101_Re_fit                   e_EW_Hb4861_Re_fit                   disp_SiII6347_alpha_fit              e_l_flux_H123750_Hb_alpha_fit
# e_flux_Hd4101_Re_fit                 EW_Hb4861_alpha_fit                  e_disp_SiII6347_alpha_fit            l_flux_H113771_Hb_Re_fit
# flux_Hd4101_alpha_fit                e_EW_Hb4861_alpha_fit                disp_[OI]6363_Re_fit                 e_l_flux_H113771_Hb_Re_fit
# e_flux_Hd4101_alpha_fit              EW_[FeII]4889_Re_fit                 e_disp_[OI]6363_Re_fit               l_flux_H113771_Hb_alpha_fit
# flux_[FeII]4276_Re_fit               e_EW_[FeII]4889_Re_fit               disp_[OI]6363_alpha_fit              e_l_flux_H113771_Hb_alpha_fit
# e_flux_[FeII]4276_Re_fit             EW_[FeII]4889_alpha_fit              e_disp_[OI]6363_alpha_fit            l_flux_H103798_Hb_Re_fit
# flux_[FeII]4276_alpha_fit            e_EW_[FeII]4889_alpha_fit            disp_Ha6562_Re_fit                   e_l_flux_H103798_Hb_Re_fit
# e_flux_[FeII]4276_alpha_fit          EW_[FeII]4905_Re_fit                 e_disp_Ha6562_Re_fit                 l_flux_H103798_Hb_alpha_fit
# flux_[FeII]4287_Re_fit               e_EW_[FeII]4905_Re_fit               disp_Ha6562_alpha_fit                e_l_flux_H103798_Hb_alpha_fit
# e_flux_[FeII]4287_Re_fit             EW_[FeII]4905_alpha_fit              e_disp_Ha6562_alpha_fit              l_flux_HeI3819_Hb_Re_fit
# flux_[FeII]4287_alpha_fit            e_EW_[FeII]4905_alpha_fit            disp_[NII]6583_Re_fit                e_l_flux_HeI3819_Hb_Re_fit
# e_flux_[FeII]4287_alpha_fit          EW_[FeII]5111_Re_fit                 e_disp_[NII]6583_Re_fit              l_flux_HeI3819_Hb_alpha_fit
# flux_[FeII]4319_Re_fit               e_EW_[FeII]5111_Re_fit               disp_[NII]6583_alpha_fit             e_l_flux_HeI3819_Hb_alpha_fit
# e_flux_[FeII]4319_Re_fit             EW_[FeII]5111_alpha_fit              e_disp_[NII]6583_alpha_fit           l_flux_H93835_Hb_Re_fit
# flux_[FeII]4319_alpha_fit            e_EW_[FeII]5111_alpha_fit            disp_[NII]6548_Re_fit                e_l_flux_H93835_Hb_Re_fit
# e_flux_[FeII]4319_alpha_fit          EW_[FeII]5158_Re_fit                 e_disp_[NII]6548_Re_fit              l_flux_H93835_Hb_alpha_fit
# flux_Hg4340_Re_fit                   e_EW_[FeII]5158_Re_fit               disp_[NII]6548_alpha_fit             e_l_flux_H93835_Hb_alpha_fit
# e_flux_Hg4340_Re_fit                 EW_[FeII]5158_alpha_fit              e_disp_[NII]6548_alpha_fit           l_flux_[NeIII]3869_Hb_Re_fit
# flux_Hg4340_alpha_fit                e_EW_[FeII]5158_alpha_fit            disp_HeI6677_Re_fit                  e_l_flux_[NeIII]3869_Hb_Re_fit
# e_flux_Hg4340_alpha_fit              EW_[NI]5199_Re_fit                   e_disp_HeI6677_Re_fit                l_flux_[NeIII]3869_Hb_alpha_fit
# flux_[OIII]4363_Re_fit               e_EW_[NI]5199_Re_fit                 disp_HeI6677_alpha_fit               e_l_flux_[NeIII]3869_Hb_alpha_fit
# e_flux_[OIII]4363_Re_fit             EW_[NI]5199_alpha_fit                e_disp_HeI6677_alpha_fit             l_flux_H83889_Hb_Re_fit
# flux_[OIII]4363_alpha_fit            e_EW_[NI]5199_alpha_fit              disp_[SII]6716_Re_fit                e_l_flux_H83889_Hb_Re_fit
# e_flux_[OIII]4363_alpha_fit          EW_[FeII]5261_Re_fit                 e_disp_[SII]6716_Re_fit              l_flux_H83889_Hb_alpha_fit
# flux_[FeII]4413_Re_fit               e_EW_[FeII]5261_Re_fit               disp_[SII]6716_alpha_fit             e_l_flux_H83889_Hb_alpha_fit
# e_flux_[FeII]4413_Re_fit             EW_[FeII]5261_alpha_fit              e_disp_[SII]6716_alpha_fit           l_flux_[NeIII]3967_Hb_Re_fit
# flux_[FeII]4413_alpha_fit            e_EW_[FeII]5261_alpha_fit            disp_[SII]6730_Re_fit                e_l_flux_[NeIII]3967_Hb_Re_fit
# e_flux_[FeII]4413_alpha_fit          EW_[ClIII]5517_Re_fit                e_disp_[SII]6730_Re_fit              l_flux_[NeIII]3967_Hb_alpha_fit
# flux_[FeII]4416_Re_fit               e_EW_[ClIII]5517_Re_fit              disp_[SII]6730_alpha_fit             e_l_flux_[NeIII]3967_Hb_alpha_fit
# e_flux_[FeII]4416_Re_fit             EW_[ClIII]5517_alpha_fit             e_disp_[SII]6730_alpha_fit           l_flux_He3970_Hb_Re_fit
# flux_[FeII]4416_alpha_fit            e_EW_[ClIII]5517_alpha_fit           disp_[ArIII]7136_Re_fit              e_l_flux_He3970_Hb_Re_fit
# e_flux_[FeII]4416_alpha_fit          EW_[ClIII]5537_Re_fit                e_disp_[ArIII]7136_Re_fit            l_flux_He3970_Hb_alpha_fit
# flux_HeI4471_Re_fit                  e_EW_[ClIII]5537_Re_fit              disp_[ArIII]7136_alpha_fit           e_l_flux_He3970_Hb_alpha_fit
# e_flux_HeI4471_Re_fit                EW_[ClIII]5537_alpha_fit             e_disp_[ArIII]7136_alpha_fit         l_flux_HeI4026_Hb_Re_fit
# flux_HeI4471_alpha_fit               e_EW_[ClIII]5537_alpha_fit           disp_[OII]7325_Re_fit                e_l_flux_HeI4026_Hb_Re_fit
# e_flux_HeI4471_alpha_fit             EW_OI5554_Re_fit                     e_disp_[OII]7325_Re_fit              l_flux_HeI4026_Hb_alpha_fit
# flux_[FeIII]4657_Re_fit              e_EW_OI5554_Re_fit                   disp_[OII]7325_alpha_fit             e_l_flux_HeI4026_Hb_alpha_fit
# e_flux_[FeIII]4657_Re_fit            EW_OI5554_alpha_fit                  e_disp_[OII]7325_alpha_fit           l_flux_[SII]4069_Hb_Re_fit
# flux_[FeIII]4657_alpha_fit           e_EW_OI5554_alpha_fit                disp_[ArIII]7751_Re_fit              e_l_flux_[SII]4069_Hb_Re_fit
# e_flux_[FeIII]4657_alpha_fit         EW_[OI]5577_Re_fit                   e_disp_[ArIII]7751_Re_fit            l_flux_[SII]4069_Hb_alpha_fit
# flux_HeII4686_Re_fit                 e_EW_[OI]5577_Re_fit                 disp_[ArIII]7751_alpha_fit           e_l_flux_[SII]4069_Hb_alpha_fit
# e_flux_HeII4686_Re_fit               EW_[OI]5577_alpha_fit                e_disp_[ArIII]7751_alpha_fit         l_flux_[SII]4076_Hb_Re_fit
# flux_HeII4686_alpha_fit              e_EW_[OI]5577_alpha_fit              disp_[SIII]9068_Re_fit               e_l_flux_[SII]4076_Hb_Re_fit
# e_flux_HeII4686_alpha_fit            EW_[NII]5754_Re_fit                  e_disp_[SIII]9068_Re_fit             l_flux_[SII]4076_Hb_alpha_fit
# flux_HeI4712_Re_fit                  e_EW_[NII]5754_Re_fit                disp_[SIII]9068_alpha_fit            e_l_flux_[SII]4076_Hb_alpha_fit
# e_flux_HeI4712_Re_fit                EW_[NII]5754_alpha_fit               e_disp_[SIII]9068_alpha_fit          l_flux_Hd4101_Hb_Re_fit
# flux_HeI4712_alpha_fit               e_EW_[NII]5754_alpha_fit             disp_[SIII]9530_Re_fit               e_l_flux_Hd4101_Hb_Re_fit
# e_flux_HeI4712_alpha_fit             EW_HeI5875_Re_fit                    e_disp_[SIII]9530_Re_fit             l_flux_Hd4101_Hb_alpha_fit
# flux_HeI4922_Re_fit                  e_EW_HeI5875_Re_fit                  disp_[SIII]9530_alpha_fit            e_l_flux_Hd4101_Hb_alpha_fit
# e_flux_HeI4922_Re_fit                EW_HeI5875_alpha_fit                 e_disp_[SIII]9530_alpha_fit          l_flux_[FeII]4276_Hb_Re_fit
# flux_HeI4922_alpha_fit               e_EW_HeI5875_alpha_fit               disp0_Re_fit                         e_l_flux_[FeII]4276_Hb_Re_fit
# e_flux_HeI4922_alpha_fit             EW_[OI]6300_Re_fit                   e_disp0_Re_fit                       l_flux_[FeII]4276_Hb_alpha_fit
# flux_[OIII]5006_Re_fit               e_EW_[OI]6300_Re_fit                 disp0_alpha_fit                      e_l_flux_[FeII]4276_Hb_alpha_fit
# e_flux_[OIII]5006_Re_fit             EW_[OI]6300_alpha_fit                e_disp0_alpha_fit                    l_flux_[FeII]4287_Hb_Re_fit
# flux_[OIII]5006_alpha_fit            e_EW_[OI]6300_alpha_fit              l_flux_[OII]3727_Ha_Re_fit           e_l_flux_[FeII]4287_Hb_Re_fit
# e_flux_[OIII]5006_alpha_fit          EW_[SIII]6312_Re_fit                 e_l_flux_[OII]3727_Ha_Re_fit         l_flux_[FeII]4287_Hb_alpha_fit
# flux_[OIII]4958_Re_fit               e_EW_[SIII]6312_Re_fit               l_flux_[OII]3727_Ha_alpha_fit        e_l_flux_[FeII]4287_Hb_alpha_fit
# e_flux_[OIII]4958_Re_fit             EW_[SIII]6312_alpha_fit              e_l_flux_[OII]3727_Ha_alpha_fit      l_flux_[FeII]4319_Hb_Re_fit
# flux_[OIII]4958_alpha_fit            e_EW_[SIII]6312_alpha_fit            l_flux_H123750_Ha_Re_fit             e_l_flux_[FeII]4319_Hb_Re_fit
# e_flux_[OIII]4958_alpha_fit          EW_SiII6347_Re_fit                   e_l_flux_H123750_Ha_Re_fit           l_flux_[FeII]4319_Hb_alpha_fit
# flux_Hb4861_Re_fit                   e_EW_SiII6347_Re_fit                 l_flux_H123750_Ha_alpha_fit          e_l_flux_[FeII]4319_Hb_alpha_fit
# e_flux_Hb4861_Re_fit                 EW_SiII6347_alpha_fit                e_l_flux_H123750_Ha_alpha_fit        l_flux_Hg4340_Hb_Re_fit
# flux_Hb4861_alpha_fit                e_EW_SiII6347_alpha_fit              l_flux_H113771_Ha_Re_fit             e_l_flux_Hg4340_Hb_Re_fit
# e_flux_Hb4861_alpha_fit              EW_[OI]6363_Re_fit                   e_l_flux_H113771_Ha_Re_fit           l_flux_Hg4340_Hb_alpha_fit
# flux_[FeII]4889_Re_fit               e_EW_[OI]6363_Re_fit                 l_flux_H113771_Ha_alpha_fit          e_l_flux_Hg4340_Hb_alpha_fit
# e_flux_[FeII]4889_Re_fit             EW_[OI]6363_alpha_fit                e_l_flux_H113771_Ha_alpha_fit        l_flux_[OIII]4363_Hb_Re_fit
# flux_[FeII]4889_alpha_fit            e_EW_[OI]6363_alpha_fit              l_flux_H103798_Ha_Re_fit             e_l_flux_[OIII]4363_Hb_Re_fit
# e_flux_[FeII]4889_alpha_fit          EW_Ha6562_Re_fit                     e_l_flux_H103798_Ha_Re_fit           l_flux_[OIII]4363_Hb_alpha_fit
# flux_[FeII]4905_Re_fit               e_EW_Ha6562_Re_fit                   l_flux_H103798_Ha_alpha_fit          e_l_flux_[OIII]4363_Hb_alpha_fit
# e_flux_[FeII]4905_Re_fit             EW_Ha6562_alpha_fit                  e_l_flux_H103798_Ha_alpha_fit        l_flux_[FeII]4413_Hb_Re_fit
# flux_[FeII]4905_alpha_fit            e_EW_Ha6562_alpha_fit                l_flux_HeI3819_Ha_Re_fit             e_l_flux_[FeII]4413_Hb_Re_fit
# e_flux_[FeII]4905_alpha_fit          EW_[NII]6583_Re_fit                  e_l_flux_HeI3819_Ha_Re_fit           l_flux_[FeII]4413_Hb_alpha_fit
# flux_[FeII]5111_Re_fit               e_EW_[NII]6583_Re_fit                l_flux_HeI3819_Ha_alpha_fit          e_l_flux_[FeII]4413_Hb_alpha_fit
# e_flux_[FeII]5111_Re_fit             EW_[NII]6583_alpha_fit               e_l_flux_HeI3819_Ha_alpha_fit        l_flux_[FeII]4416_Hb_Re_fit
# flux_[FeII]5111_alpha_fit            e_EW_[NII]6583_alpha_fit             l_flux_H93835_Ha_Re_fit              e_l_flux_[FeII]4416_Hb_Re_fit
# e_flux_[FeII]5111_alpha_fit          EW_[NII]6548_Re_fit                  e_l_flux_H93835_Ha_Re_fit            l_flux_[FeII]4416_Hb_alpha_fit
# flux_[FeII]5158_Re_fit               e_EW_[NII]6548_Re_fit                l_flux_H93835_Ha_alpha_fit           e_l_flux_[FeII]4416_Hb_alpha_fit
# e_flux_[FeII]5158_Re_fit             EW_[NII]6548_alpha_fit               e_l_flux_H93835_Ha_alpha_fit         l_flux_HeI4471_Hb_Re_fit
# flux_[FeII]5158_alpha_fit            e_EW_[NII]6548_alpha_fit             l_flux_[NeIII]3869_Ha_Re_fit         e_l_flux_HeI4471_Hb_Re_fit
# e_flux_[FeII]5158_alpha_fit          EW_HeI6677_Re_fit                    e_l_flux_[NeIII]3869_Ha_Re_fit       l_flux_HeI4471_Hb_alpha_fit
# flux_[NI]5199_Re_fit                 e_EW_HeI6677_Re_fit                  l_flux_[NeIII]3869_Ha_alpha_fit      e_l_flux_HeI4471_Hb_alpha_fit
# e_flux_[NI]5199_Re_fit               EW_HeI6677_alpha_fit                 e_l_flux_[NeIII]3869_Ha_alpha_fit    l_flux_[FeIII]4657_Hb_Re_fit
# flux_[NI]5199_alpha_fit              e_EW_HeI6677_alpha_fit               l_flux_H83889_Ha_Re_fit              e_l_flux_[FeIII]4657_Hb_Re_fit
# e_flux_[NI]5199_alpha_fit            EW_[SII]6716_Re_fit                  e_l_flux_H83889_Ha_Re_fit            l_flux_[FeIII]4657_Hb_alpha_fit
# flux_[FeII]5261_Re_fit               e_EW_[SII]6716_Re_fit                l_flux_H83889_Ha_alpha_fit           e_l_flux_[FeIII]4657_Hb_alpha_fit
# e_flux_[FeII]5261_Re_fit             EW_[SII]6716_alpha_fit               e_l_flux_H83889_Ha_alpha_fit         l_flux_HeII4686_Hb_Re_fit
# flux_[FeII]5261_alpha_fit            e_EW_[SII]6716_alpha_fit             l_flux_[NeIII]3967_Ha_Re_fit         e_l_flux_HeII4686_Hb_Re_fit
# e_flux_[FeII]5261_alpha_fit          EW_[SII]6730_Re_fit                  e_l_flux_[NeIII]3967_Ha_Re_fit       l_flux_HeII4686_Hb_alpha_fit
# flux_[ClIII]5517_Re_fit              e_EW_[SII]6730_Re_fit                l_flux_[NeIII]3967_Ha_alpha_fit      e_l_flux_HeII4686_Hb_alpha_fit
# e_flux_[ClIII]5517_Re_fit            EW_[SII]6730_alpha_fit               e_l_flux_[NeIII]3967_Ha_alpha_fit    l_flux_HeI4712_Hb_Re_fit
# flux_[ClIII]5517_alpha_fit           e_EW_[SII]6730_alpha_fit             l_flux_He3970_Ha_Re_fit              e_l_flux_HeI4712_Hb_Re_fit
# e_flux_[ClIII]5517_alpha_fit         EW_[ArIII]7136_Re_fit                e_l_flux_He3970_Ha_Re_fit            l_flux_HeI4712_Hb_alpha_fit
# flux_[ClIII]5537_Re_fit              e_EW_[ArIII]7136_Re_fit              l_flux_He3970_Ha_alpha_fit           e_l_flux_HeI4712_Hb_alpha_fit
# e_flux_[ClIII]5537_Re_fit            EW_[ArIII]7136_alpha_fit             e_l_flux_He3970_Ha_alpha_fit         l_flux_HeI4922_Hb_Re_fit
# flux_[ClIII]5537_alpha_fit           e_EW_[ArIII]7136_alpha_fit           l_flux_HeI4026_Ha_Re_fit             e_l_flux_HeI4922_Hb_Re_fit
# e_flux_[ClIII]5537_alpha_fit         EW_[OII]7325_Re_fit                  e_l_flux_HeI4026_Ha_Re_fit           l_flux_HeI4922_Hb_alpha_fit
# flux_OI5554_Re_fit                   e_EW_[OII]7325_Re_fit                l_flux_HeI4026_Ha_alpha_fit          e_l_flux_HeI4922_Hb_alpha_fit
# e_flux_OI5554_Re_fit                 EW_[OII]7325_alpha_fit               e_l_flux_HeI4026_Ha_alpha_fit        l_flux_[OIII]5006_Hb_Re_fit
# flux_OI5554_alpha_fit                e_EW_[OII]7325_alpha_fit             l_flux_[SII]4069_Ha_Re_fit           e_l_flux_[OIII]5006_Hb_Re_fit
# e_flux_OI5554_alpha_fit              EW_[ArIII]7751_Re_fit                e_l_flux_[SII]4069_Ha_Re_fit         l_flux_[OIII]5006_Hb_alpha_fit
# flux_[OI]5577_Re_fit                 e_EW_[ArIII]7751_Re_fit              l_flux_[SII]4069_Ha_alpha_fit        e_l_flux_[OIII]5006_Hb_alpha_fit
# e_flux_[OI]5577_Re_fit               EW_[ArIII]7751_alpha_fit             e_l_flux_[SII]4069_Ha_alpha_fit      l_flux_[OIII]4958_Hb_Re_fit
# flux_[OI]5577_alpha_fit              e_EW_[ArIII]7751_alpha_fit           l_flux_[SII]4076_Ha_Re_fit           e_l_flux_[OIII]4958_Hb_Re_fit
# e_flux_[OI]5577_alpha_fit            EW_[SIII]9068_Re_fit                 e_l_flux_[SII]4076_Ha_Re_fit         l_flux_[OIII]4958_Hb_alpha_fit
# flux_[NII]5754_Re_fit                e_EW_[SIII]9068_Re_fit               l_flux_[SII]4076_Ha_alpha_fit        e_l_flux_[OIII]4958_Hb_alpha_fit
# e_flux_[NII]5754_Re_fit              EW_[SIII]9068_alpha_fit              e_l_flux_[SII]4076_Ha_alpha_fit      l_flux_Hb4861_Hb_Re_fit
# flux_[NII]5754_alpha_fit             e_EW_[SIII]9068_alpha_fit            l_flux_Hd4101_Ha_Re_fit              e_l_flux_Hb4861_Hb_Re_fit
# e_flux_[NII]5754_alpha_fit           EW_[SIII]9530_Re_fit                 e_l_flux_Hd4101_Ha_Re_fit            l_flux_Hb4861_Hb_alpha_fit
# flux_HeI5875_Re_fit                  e_EW_[SIII]9530_Re_fit               l_flux_Hd4101_Ha_alpha_fit           e_l_flux_Hb4861_Hb_alpha_fit
# e_flux_HeI5875_Re_fit                EW_[SIII]9530_alpha_fit              e_l_flux_Hd4101_Ha_alpha_fit         l_flux_[FeII]4889_Hb_Re_fit
# flux_HeI5875_alpha_fit               e_EW_[SIII]9530_alpha_fit            l_flux_[FeII]4276_Ha_Re_fit          e_l_flux_[FeII]4889_Hb_Re_fit
# e_flux_HeI5875_alpha_fit             EW0_Re_fit                           e_l_flux_[FeII]4276_Ha_Re_fit        l_flux_[FeII]4889_Hb_alpha_fit
# flux_[OI]6300_Re_fit                 e_EW0_Re_fit                         l_flux_[FeII]4276_Ha_alpha_fit       e_l_flux_[FeII]4889_Hb_alpha_fit
# e_flux_[OI]6300_Re_fit               EW0_alpha_fit                        e_l_flux_[FeII]4276_Ha_alpha_fit     l_flux_[FeII]4905_Hb_Re_fit
# flux_[OI]6300_alpha_fit              e_EW0_alpha_fit                      l_flux_[FeII]4287_Ha_Re_fit          e_l_flux_[FeII]4905_Hb_Re_fit
# e_flux_[OI]6300_alpha_fit            disp_[OII]3727_Re_fit                e_l_flux_[FeII]4287_Ha_Re_fit        l_flux_[FeII]4905_Hb_alpha_fit
# flux_[SIII]6312_Re_fit               e_disp_[OII]3727_Re_fit              l_flux_[FeII]4287_Ha_alpha_fit       e_l_flux_[FeII]4905_Hb_alpha_fit
# e_flux_[SIII]6312_Re_fit             disp_[OII]3727_alpha_fit             e_l_flux_[FeII]4287_Ha_alpha_fit     l_flux_[FeII]5111_Hb_Re_fit
# flux_[SIII]6312_alpha_fit            e_disp_[OII]3727_alpha_fit           l_flux_[FeII]4319_Ha_Re_fit          e_l_flux_[FeII]5111_Hb_Re_fit
# e_flux_[SIII]6312_alpha_fit          disp_H123750_Re_fit                  e_l_flux_[FeII]4319_Ha_Re_fit        l_flux_[FeII]5111_Hb_alpha_fit
# flux_SiII6347_Re_fit                 e_disp_H123750_Re_fit                l_flux_[FeII]4319_Ha_alpha_fit       e_l_flux_[FeII]5111_Hb_alpha_fit
# e_flux_SiII6347_Re_fit               disp_H123750_alpha_fit               e_l_flux_[FeII]4319_Ha_alpha_fit     l_flux_[FeII]5158_Hb_Re_fit
# flux_SiII6347_alpha_fit              e_disp_H123750_alpha_fit             l_flux_Hg4340_Ha_Re_fit              e_l_flux_[FeII]5158_Hb_Re_fit
# e_flux_SiII6347_alpha_fit            disp_H113771_Re_fit                  e_l_flux_Hg4340_Ha_Re_fit            l_flux_[FeII]5158_Hb_alpha_fit
# flux_[OI]6363_Re_fit                 e_disp_H113771_Re_fit                l_flux_Hg4340_Ha_alpha_fit           e_l_flux_[FeII]5158_Hb_alpha_fit
# e_flux_[OI]6363_Re_fit               disp_H113771_alpha_fit               e_l_flux_Hg4340_Ha_alpha_fit         l_flux_[NI]5199_Hb_Re_fit
# flux_[OI]6363_alpha_fit              e_disp_H113771_alpha_fit             l_flux_[OIII]4363_Ha_Re_fit          e_l_flux_[NI]5199_Hb_Re_fit
# e_flux_[OI]6363_alpha_fit            disp_H103798_Re_fit                  e_l_flux_[OIII]4363_Ha_Re_fit        l_flux_[NI]5199_Hb_alpha_fit
# flux_Ha6562_Re_fit                   e_disp_H103798_Re_fit                l_flux_[OIII]4363_Ha_alpha_fit       e_l_flux_[NI]5199_Hb_alpha_fit
# e_flux_Ha6562_Re_fit                 disp_H103798_alpha_fit               e_l_flux_[OIII]4363_Ha_alpha_fit     l_flux_[FeII]5261_Hb_Re_fit
# flux_Ha6562_alpha_fit                e_disp_H103798_alpha_fit             l_flux_[FeII]4413_Ha_Re_fit          e_l_flux_[FeII]5261_Hb_Re_fit
# e_flux_Ha6562_alpha_fit              disp_HeI3819_Re_fit                  e_l_flux_[FeII]4413_Ha_Re_fit        l_flux_[FeII]5261_Hb_alpha_fit
# flux_[NII]6583_Re_fit                e_disp_HeI3819_Re_fit                l_flux_[FeII]4413_Ha_alpha_fit       e_l_flux_[FeII]5261_Hb_alpha_fit
# e_flux_[NII]6583_Re_fit              disp_HeI3819_alpha_fit               e_l_flux_[FeII]4413_Ha_alpha_fit     l_flux_[ClIII]5517_Hb_Re_fit
# flux_[NII]6583_alpha_fit             e_disp_HeI3819_alpha_fit             l_flux_[FeII]4416_Ha_Re_fit          e_l_flux_[ClIII]5517_Hb_Re_fit
# e_flux_[NII]6583_alpha_fit           disp_H93835_Re_fit                   e_l_flux_[FeII]4416_Ha_Re_fit        l_flux_[ClIII]5517_Hb_alpha_fit
# flux_[NII]6548_Re_fit                e_disp_H93835_Re_fit                 l_flux_[FeII]4416_Ha_alpha_fit       e_l_flux_[ClIII]5517_Hb_alpha_fit
# e_flux_[NII]6548_Re_fit              disp_H93835_alpha_fit                e_l_flux_[FeII]4416_Ha_alpha_fit     l_flux_[ClIII]5537_Hb_Re_fit
# flux_[NII]6548_alpha_fit             e_disp_H93835_alpha_fit              l_flux_HeI4471_Ha_Re_fit             e_l_flux_[ClIII]5537_Hb_Re_fit
# e_flux_[NII]6548_alpha_fit           disp_[NeIII]3869_Re_fit              e_l_flux_HeI4471_Ha_Re_fit           l_flux_[ClIII]5537_Hb_alpha_fit
# flux_HeI6677_Re_fit                  e_disp_[NeIII]3869_Re_fit            l_flux_HeI4471_Ha_alpha_fit          e_l_flux_[ClIII]5537_Hb_alpha_fit
# e_flux_HeI6677_Re_fit                disp_[NeIII]3869_alpha_fit           e_l_flux_HeI4471_Ha_alpha_fit        l_flux_OI5554_Hb_Re_fit
# flux_HeI6677_alpha_fit               e_disp_[NeIII]3869_alpha_fit         l_flux_[FeIII]4657_Ha_Re_fit         e_l_flux_OI5554_Hb_Re_fit
# e_flux_HeI6677_alpha_fit             disp_H83889_Re_fit                   e_l_flux_[FeIII]4657_Ha_Re_fit       l_flux_OI5554_Hb_alpha_fit
# flux_[SII]6716_Re_fit                e_disp_H83889_Re_fit                 l_flux_[FeIII]4657_Ha_alpha_fit      e_l_flux_OI5554_Hb_alpha_fit
# e_flux_[SII]6716_Re_fit              disp_H83889_alpha_fit                e_l_flux_[FeIII]4657_Ha_alpha_fit    l_flux_[OI]5577_Hb_Re_fit
# flux_[SII]6716_alpha_fit             e_disp_H83889_alpha_fit              l_flux_HeII4686_Ha_Re_fit            e_l_flux_[OI]5577_Hb_Re_fit
# e_flux_[SII]6716_alpha_fit           disp_[NeIII]3967_Re_fit              e_l_flux_HeII4686_Ha_Re_fit          l_flux_[OI]5577_Hb_alpha_fit
# flux_[SII]6730_Re_fit                e_disp_[NeIII]3967_Re_fit            l_flux_HeII4686_Ha_alpha_fit         e_l_flux_[OI]5577_Hb_alpha_fit
# e_flux_[SII]6730_Re_fit              disp_[NeIII]3967_alpha_fit           e_l_flux_HeII4686_Ha_alpha_fit       l_flux_[NII]5754_Hb_Re_fit
# flux_[SII]6730_alpha_fit             e_disp_[NeIII]3967_alpha_fit         l_flux_HeI4712_Ha_Re_fit             e_l_flux_[NII]5754_Hb_Re_fit
# e_flux_[SII]6730_alpha_fit           disp_He3970_Re_fit                   e_l_flux_HeI4712_Ha_Re_fit           l_flux_[NII]5754_Hb_alpha_fit
# flux_[ArIII]7136_Re_fit              e_disp_He3970_Re_fit                 l_flux_HeI4712_Ha_alpha_fit          e_l_flux_[NII]5754_Hb_alpha_fit
# e_flux_[ArIII]7136_Re_fit            disp_He3970_alpha_fit                e_l_flux_HeI4712_Ha_alpha_fit        l_flux_HeI5875_Hb_Re_fit
# flux_[ArIII]7136_alpha_fit           e_disp_He3970_alpha_fit              l_flux_HeI4922_Ha_Re_fit             e_l_flux_HeI5875_Hb_Re_fit
# e_flux_[ArIII]7136_alpha_fit         disp_HeI4026_Re_fit                  e_l_flux_HeI4922_Ha_Re_fit           l_flux_HeI5875_Hb_alpha_fit
# flux_[OII]7325_Re_fit                e_disp_HeI4026_Re_fit                l_flux_HeI4922_Ha_alpha_fit          e_l_flux_HeI5875_Hb_alpha_fit
# e_flux_[OII]7325_Re_fit              disp_HeI4026_alpha_fit               e_l_flux_HeI4922_Ha_alpha_fit        l_flux_[OI]6300_Hb_Re_fit
# flux_[OII]7325_alpha_fit             e_disp_HeI4026_alpha_fit             l_flux_[OIII]5006_Ha_Re_fit          e_l_flux_[OI]6300_Hb_Re_fit
# e_flux_[OII]7325_alpha_fit           disp_[SII]4069_Re_fit                e_l_flux_[OIII]5006_Ha_Re_fit        l_flux_[OI]6300_Hb_alpha_fit
# flux_[ArIII]7751_Re_fit              e_disp_[SII]4069_Re_fit              l_flux_[OIII]5006_Ha_alpha_fit       e_l_flux_[OI]6300_Hb_alpha_fit
# e_flux_[ArIII]7751_Re_fit            disp_[SII]4069_alpha_fit             e_l_flux_[OIII]5006_Ha_alpha_fit     l_flux_[SIII]6312_Hb_Re_fit
# flux_[ArIII]7751_alpha_fit           e_disp_[SII]4069_alpha_fit           l_flux_[OIII]4958_Ha_Re_fit          e_l_flux_[SIII]6312_Hb_Re_fit
# e_flux_[ArIII]7751_alpha_fit         disp_[SII]4076_Re_fit                e_l_flux_[OIII]4958_Ha_Re_fit        l_flux_[SIII]6312_Hb_alpha_fit
# flux_[SIII]9068_Re_fit               e_disp_[SII]4076_Re_fit              l_flux_[OIII]4958_Ha_alpha_fit       e_l_flux_[SIII]6312_Hb_alpha_fit
# e_flux_[SIII]9068_Re_fit             disp_[SII]4076_alpha_fit             e_l_flux_[OIII]4958_Ha_alpha_fit     l_flux_SiII6347_Hb_Re_fit
# flux_[SIII]9068_alpha_fit            e_disp_[SII]4076_alpha_fit           l_flux_Hb4861_Ha_Re_fit              e_l_flux_SiII6347_Hb_Re_fit
# e_flux_[SIII]9068_alpha_fit          disp_Hd4101_Re_fit                   e_l_flux_Hb4861_Ha_Re_fit            l_flux_SiII6347_Hb_alpha_fit
# flux_[SIII]9530_Re_fit               e_disp_Hd4101_Re_fit                 l_flux_Hb4861_Ha_alpha_fit           e_l_flux_SiII6347_Hb_alpha_fit
# e_flux_[SIII]9530_Re_fit             disp_Hd4101_alpha_fit                e_l_flux_Hb4861_Ha_alpha_fit         l_flux_[OI]6363_Hb_Re_fit
# flux_[SIII]9530_alpha_fit            e_disp_Hd4101_alpha_fit              l_flux_[FeII]4889_Ha_Re_fit          e_l_flux_[OI]6363_Hb_Re_fit
# e_flux_[SIII]9530_alpha_fit          disp_[FeII]4276_Re_fit               e_l_flux_[FeII]4889_Ha_Re_fit        l_flux_[OI]6363_Hb_alpha_fit
# flux0_Re_fit                         e_disp_[FeII]4276_Re_fit             l_flux_[FeII]4889_Ha_alpha_fit       e_l_flux_[OI]6363_Hb_alpha_fit
# e_flux0_Re_fit                       disp_[FeII]4276_alpha_fit            e_l_flux_[FeII]4889_Ha_alpha_fit     l_flux_Ha6562_Hb_Re_fit
# flux0_alpha_fit                      e_disp_[FeII]4276_alpha_fit          l_flux_[FeII]4905_Ha_Re_fit          e_l_flux_Ha6562_Hb_Re_fit
# e_flux0_alpha_fit                    disp_[FeII]4287_Re_fit               e_l_flux_[FeII]4905_Ha_Re_fit        l_flux_Ha6562_Hb_alpha_fit
# EW_[OII]3727_Re_fit                  e_disp_[FeII]4287_Re_fit             l_flux_[FeII]4905_Ha_alpha_fit       e_l_flux_Ha6562_Hb_alpha_fit
# e_EW_[OII]3727_Re_fit                disp_[FeII]4287_alpha_fit            e_l_flux_[FeII]4905_Ha_alpha_fit     l_flux_[NII]6583_Hb_Re_fit
# EW_[OII]3727_alpha_fit               e_disp_[FeII]4287_alpha_fit          l_flux_[FeII]5111_Ha_Re_fit          e_l_flux_[NII]6583_Hb_Re_fit
# e_EW_[OII]3727_alpha_fit             disp_[FeII]4319_Re_fit               e_l_flux_[FeII]5111_Ha_Re_fit        l_flux_[NII]6583_Hb_alpha_fit
# EW_H123750_Re_fit                    e_disp_[FeII]4319_Re_fit             l_flux_[FeII]5111_Ha_alpha_fit       e_l_flux_[NII]6583_Hb_alpha_fit
# e_EW_H123750_Re_fit                  disp_[FeII]4319_alpha_fit            e_l_flux_[FeII]5111_Ha_alpha_fit     l_flux_[NII]6548_Hb_Re_fit
# EW_H123750_alpha_fit                 e_disp_[FeII]4319_alpha_fit          l_flux_[FeII]5158_Ha_Re_fit          e_l_flux_[NII]6548_Hb_Re_fit
# e_EW_H123750_alpha_fit               disp_Hg4340_Re_fit                   e_l_flux_[FeII]5158_Ha_Re_fit        l_flux_[NII]6548_Hb_alpha_fit
# EW_H113771_Re_fit                    e_disp_Hg4340_Re_fit                 l_flux_[FeII]5158_Ha_alpha_fit       e_l_flux_[NII]6548_Hb_alpha_fit
# e_EW_H113771_Re_fit                  disp_Hg4340_alpha_fit                e_l_flux_[FeII]5158_Ha_alpha_fit     l_flux_HeI6677_Hb_Re_fit
# EW_H113771_alpha_fit                 e_disp_Hg4340_alpha_fit              l_flux_[NI]5199_Ha_Re_fit            e_l_flux_HeI6677_Hb_Re_fit
# e_EW_H113771_alpha_fit               disp_[OIII]4363_Re_fit               e_l_flux_[NI]5199_Ha_Re_fit          l_flux_HeI6677_Hb_alpha_fit
# EW_H103798_Re_fit                    e_disp_[OIII]4363_Re_fit             l_flux_[NI]5199_Ha_alpha_fit         e_l_flux_HeI6677_Hb_alpha_fit
# e_EW_H103798_Re_fit                  disp_[OIII]4363_alpha_fit            e_l_flux_[NI]5199_Ha_alpha_fit       l_flux_[SII]6716_Hb_Re_fit
# EW_H103798_alpha_fit                 e_disp_[OIII]4363_alpha_fit          l_flux_[FeII]5261_Ha_Re_fit          e_l_flux_[SII]6716_Hb_Re_fit
# e_EW_H103798_alpha_fit               disp_[FeII]4413_Re_fit               e_l_flux_[FeII]5261_Ha_Re_fit        l_flux_[SII]6716_Hb_alpha_fit
# EW_HeI3819_Re_fit                    e_disp_[FeII]4413_Re_fit             l_flux_[FeII]5261_Ha_alpha_fit       e_l_flux_[SII]6716_Hb_alpha_fit
# e_EW_HeI3819_Re_fit                  disp_[FeII]4413_alpha_fit            e_l_flux_[FeII]5261_Ha_alpha_fit     l_flux_[SII]6730_Hb_Re_fit
# EW_HeI3819_alpha_fit                 e_disp_[FeII]4413_alpha_fit          l_flux_[ClIII]5517_Ha_Re_fit         e_l_flux_[SII]6730_Hb_Re_fit
# e_EW_HeI3819_alpha_fit               disp_[FeII]4416_Re_fit               e_l_flux_[ClIII]5517_Ha_Re_fit       l_flux_[SII]6730_Hb_alpha_fit
# EW_H93835_Re_fit                     e_disp_[FeII]4416_Re_fit             l_flux_[ClIII]5517_Ha_alpha_fit      e_l_flux_[SII]6730_Hb_alpha_fit
# e_EW_H93835_Re_fit                   disp_[FeII]4416_alpha_fit            e_l_flux_[ClIII]5517_Ha_alpha_fit    l_flux_[ArIII]7136_Hb_Re_fit
# EW_H93835_alpha_fit                  e_disp_[FeII]4416_alpha_fit          l_flux_[ClIII]5537_Ha_Re_fit         e_l_flux_[ArIII]7136_Hb_Re_fit
# e_EW_H93835_alpha_fit                disp_HeI4471_Re_fit                  e_l_flux_[ClIII]5537_Ha_Re_fit       l_flux_[ArIII]7136_Hb_alpha_fit
# EW_[NeIII]3869_Re_fit                e_disp_HeI4471_Re_fit                l_flux_[ClIII]5537_Ha_alpha_fit      e_l_flux_[ArIII]7136_Hb_alpha_fit
# e_EW_[NeIII]3869_Re_fit              disp_HeI4471_alpha_fit               e_l_flux_[ClIII]5537_Ha_alpha_fit    l_flux_[OII]7325_Hb_Re_fit
# EW_[NeIII]3869_alpha_fit             e_disp_HeI4471_alpha_fit             l_flux_OI5554_Ha_Re_fit              e_l_flux_[OII]7325_Hb_Re_fit
# e_EW_[NeIII]3869_alpha_fit           disp_[FeIII]4657_Re_fit              e_l_flux_OI5554_Ha_Re_fit            l_flux_[OII]7325_Hb_alpha_fit
# EW_H83889_Re_fit                     e_disp_[FeIII]4657_Re_fit            l_flux_OI5554_Ha_alpha_fit           e_l_flux_[OII]7325_Hb_alpha_fit
# e_EW_H83889_Re_fit                   disp_[FeIII]4657_alpha_fit           e_l_flux_OI5554_Ha_alpha_fit         l_flux_[ArIII]7751_Hb_Re_fit
# EW_H83889_alpha_fit                  e_disp_[FeIII]4657_alpha_fit         l_flux_[OI]5577_Ha_Re_fit            e_l_flux_[ArIII]7751_Hb_Re_fit
# e_EW_H83889_alpha_fit                disp_HeII4686_Re_fit                 e_l_flux_[OI]5577_Ha_Re_fit          l_flux_[ArIII]7751_Hb_alpha_fit
# EW_[NeIII]3967_Re_fit                e_disp_HeII4686_Re_fit               l_flux_[OI]5577_Ha_alpha_fit         e_l_flux_[ArIII]7751_Hb_alpha_fit
# e_EW_[NeIII]3967_Re_fit              disp_HeII4686_alpha_fit              e_l_flux_[OI]5577_Ha_alpha_fit       l_flux_[SIII]9068_Hb_Re_fit
# EW_[NeIII]3967_alpha_fit             e_disp_HeII4686_alpha_fit            l_flux_[NII]5754_Ha_Re_fit           e_l_flux_[SIII]9068_Hb_Re_fit
# e_EW_[NeIII]3967_alpha_fit           disp_HeI4712_Re_fit                  e_l_flux_[NII]5754_Ha_Re_fit         l_flux_[SIII]9068_Hb_alpha_fit
# EW_He3970_Re_fit                     e_disp_HeI4712_Re_fit                l_flux_[NII]5754_Ha_alpha_fit        e_l_flux_[SIII]9068_Hb_alpha_fit
# e_EW_He3970_Re_fit                   disp_HeI4712_alpha_fit               e_l_flux_[NII]5754_Ha_alpha_fit      l_flux_[SIII]9530_Hb_Re_fit
# EW_He3970_alpha_fit                  e_disp_HeI4712_alpha_fit             l_flux_HeI5875_Ha_Re_fit             e_l_flux_[SIII]9530_Hb_Re_fit
# e_EW_He3970_alpha_fit                disp_HeI4922_Re_fit                  e_l_flux_HeI5875_Ha_Re_fit           l_flux_[SIII]9530_Hb_alpha_fit
# EW_HeI4026_Re_fit                    e_disp_HeI4922_Re_fit                l_flux_HeI5875_Ha_alpha_fit          e_l_flux_[SIII]9530_Hb_alpha_fit
# e_EW_HeI4026_Re_fit                  disp_HeI4922_alpha_fit               e_l_flux_HeI5875_Ha_alpha_fit        l_flux0_Hb_Re_fit
# EW_HeI4026_alpha_fit                 e_disp_HeI4922_alpha_fit             l_flux_[OI]6300_Ha_Re_fit            e_l_flux0_Hb_Re_fit
# e_EW_HeI4026_alpha_fit               disp_[OIII]5006_Re_fit               e_l_flux_[OI]6300_Ha_Re_fit          l_flux0_Hb_alpha_fit
# EW_[SII]4069_Re_fit                  e_disp_[OIII]5006_Re_fit             l_flux_[OI]6300_Ha_alpha_fit         e_l_flux0_Hb_alpha_fit
# e_EW_[SII]4069_Re_fit                disp_[OIII]5006_alpha_fit            e_l_flux_[OI]6300_Ha_alpha_fit
# EW_[SII]4069_alpha_fit               e_disp_[OIII]5006_alpha_fit          l_flux_[SIII]6312_Ha_Re_fit
# e_EW_[SII]4069_alpha_fit             disp_[OIII]4958_Re_fit               e_l_flux_[SIII]6312_Ha_Re_fit

# %%
#
# Reading flux_elines_table
#
get_p_OH="tables/get_proc_OH_MaNGA.clean.csv"
col_p_OH=header_columns_space(get_p_OH,2)
tab_OH=ascii.read(get_p_OH, delimiter=',', guess=True, comment='\s*#', names=col_p_OH,\
                      fill_values=[('BAD', np.nan)])
#print(tab_pe)
#tab_mag.rename_column('name-obj', 'name')
#list_columns(col_p_fe_org)
print(len(tab_OH))
list_columns(tab_OH.columns)


#tab_mag.rename_column('name-obj', 'name')
# Out:
# 10243
# MaNGA_name                      e_OH_Pet04_O3N2_alpha_fit       e_OH_Cur20_R2_alpha_fit         e_U_Dors_O32_alpha_fit
# nsa_redshift                    OH_Kew02_N2O2_Re_fit            OH_Cur20_N2_Re_fit              U_Dors_S_Re_fit
# nsa_u_absmag                    e_OH_Kew02_N2O2_Re_fit          e_OH_Cur20_N2_Re_fit            e_U_Dors_S_Re_fit
# nsa_z_absmag                    OH_Kew02_N2O2_alpha_fit         OH_Cur20_N2_alpha_fit           U_Dors_S_alpha_fit
# nsa_u_z_absmag                  e_OH_Kew02_N2O2_alpha_fit       e_OH_Cur20_N2_alpha_fit         e_U_Dors_S_alpha_fit
# nsa_mstar                       OH_Pil10_ONS_Re_fit             OH_Cur20_R23_Re_fit             U_Mor16_O23_fs_Re_fit
# nsa_inclination                 e_OH_Pil10_ONS_Re_fit           e_OH_Cur20_R23_Re_fit           e_U_Mor16_O23_fs_Re_fit
# nsa_petro_th50                  OH_Pil10_ONS_alpha_fit          OH_Cur20_R23_alpha_fit          U_Mor16_O23_fs_alpha_fit
# nsa_sersic_ba                   e_OH_Pil10_ONS_alpha_fit        e_OH_Cur20_R23_alpha_fit        e_U_Mor16_O23_fs_alpha_fit
# nsa_sersic_n                    OH_Pil10_ON_Re_fit              OH_Cur20_O3N2_Re_fit            U_Mor16_O23_ts_Re_fit
# nsa_sersic_phi                  e_OH_Pil10_ON_Re_fit            e_OH_Cur20_O3N2_Re_fit          e_U_Mor16_O23_ts_Re_fit
# nsa_sersic_th50                 OH_Pil10_ON_alpha_fit           OH_Cur20_O3N2_alpha_fit         U_Mor16_O23_ts_alpha_fit
# name                            e_OH_Pil10_ON_alpha_fit         e_OH_Cur20_O3N2_alpha_fit       e_U_Mor16_O23_ts_alpha_fit
# OH_Mar13_N2_Re_fit              OH_Pil11_NS_Re_fit              OH_Cur20_O3S2_Re_fit            NH_Pil16_R_Re_fit
# e_OH_Mar13_N2_Re_fit            e_OH_Pil11_NS_Re_fit            e_OH_Cur20_O3S2_Re_fit          e_NH_Pil16_R_Re_fit
# OH_Mar13_N2_alpha_fit           OH_Pil11_NS_alpha_fit           OH_Cur20_O3S2_alpha_fit         NH_Pil16_R_alpha_fit
# e_OH_Mar13_N2_alpha_fit         e_OH_Pil11_NS_alpha_fit         e_OH_Cur20_O3S2_alpha_fit       e_NH_Pil16_R_alpha_fit
# OH_Mar13_O3N2_Re_fit            OH_Cur20_RS32_Re_fit            OH_KK04_Re_fit                  NO_Pil16_R_Re_fit
# e_OH_Mar13_O3N2_Re_fit          e_OH_Cur20_RS32_Re_fit          e_OH_KK04_Re_fit                e_NO_Pil16_R_Re_fit
# OH_Mar13_O3N2_alpha_fit         OH_Cur20_RS32_alpha_fit         OH_KK04_alpha_fit               NO_Pil16_R_alpha_fit
# e_OH_Mar13_O3N2_alpha_fit       e_OH_Cur20_RS32_alpha_fit       e_OH_KK04_alpha_fit             e_NO_Pil16_R_alpha_fit
# OH_T04_Re_fit                   OH_Cur20_R3_Re_fit              OH_Pil16_R_Re_fit               NO_Pil16_Ho_R_Re_fit
# e_OH_T04_Re_fit                 e_OH_Cur20_R3_Re_fit            e_OH_Pil16_R_Re_fit             e_NO_Pil16_Ho_R_Re_fit
# OH_T04_alpha_fit                OH_Cur20_R3_alpha_fit           OH_Pil16_R_alpha_fit            NO_Pil16_Ho_R_alpha_fit
# e_OH_T04_alpha_fit              e_OH_Cur20_R3_alpha_fit         e_OH_Pil16_R_alpha_fit          e_NO_Pil16_Ho_R_alpha_fit
# OH_Pet04_N2_lin_Re_fit          OH_Cur20_O3O2_Re_fit            OH_Pil16_S_Re_fit               NO_Pil16_N2_R2_Re_fit
# e_OH_Pet04_N2_lin_Re_fit        e_OH_Cur20_O3O2_Re_fit          e_OH_Pil16_S_Re_fit             e_NO_Pil16_N2_R2_Re_fit
# OH_Pet04_N2_lin_alpha_fit       OH_Cur20_O3O2_alpha_fit         OH_Pil16_S_alpha_fit            NO_Pil16_N2_R2_alpha_fit
# e_OH_Pet04_N2_lin_alpha_fit     e_OH_Cur20_O3O2_alpha_fit       e_OH_Pil16_S_alpha_fit          e_NO_Pil16_N2_R2_alpha_fit
# OH_Pet04_N2_poly_Re_fit         OH_Cur20_S2_Re_fit              OH_Ho_Re_fit                    Ne_Oster_S_Re_fit
# e_OH_Pet04_N2_poly_Re_fit       e_OH_Cur20_S2_Re_fit            e_OH_Ho_Re_fit                  e_Ne_Oster_S_Re_fit
# OH_Pet04_N2_poly_alpha_fit      OH_Cur20_S2_alpha_fit           OH_Ho_alpha_fit                 Ne_Oster_S_alpha_fit
# e_OH_Pet04_N2_poly_alpha_fit    e_OH_Cur20_S2_alpha_fit         e_OH_Ho_alpha_fit               e_Ne_Oster_S_alpha_fit
# OH_Pet04_O3N2_Re_fit            OH_Cur20_R2_Re_fit              U_Dors_O32_Re_fit
# e_OH_Pet04_O3N2_Re_fit          e_OH_Cur20_R2_Re_fit            e_U_Dors_O32_Re_fit
# OH_Pet04_O3N2_alpha_fit         OH_Cur20_R2_alpha_fit           U_Dors_O32_alpha_fit

# %%
#
# Reading morphological table
#
#morph={'-2':'CD','-1':'E','0':'S0','1':'Sa','2':'Sab','3':'Sb','4':'Sbc','5':'Sc','6':'Scd',\
#       '7':'Sd','8':'Sdm','9':'Sm','10':'Irr'}
morph={-2:'CD',-1:'E',0:'S0',1:'Sa',2:'Sab',3:'Sb',4:'Sbc',5:'Sc',6:'Scd',\
       7:'Sd',8:'Sdm',9:'Sm',10:'Irr'}
morph_file="tables/manga-morphall-v3_1_1.fits"
tab_morph = Table.read(morph_file, format='fits')
tab_morph.rename_column('index', 'name')
tab_morph.rename_column('nsa_sersic_n', 'nsa_sersic_n_morph')
list_columns(tab_morph.columns)
print(morph)
# Out:
# name                  r-i                   P(Sab)                P(Sm)
# nsa_sersic_n_morph    i-z                   P(Sb)                 P(Irr)
# log_Mass_corr         C (R50/R90)           P(Sbc)                best type_n
# rat_vel_sigma         P(CD)                 P(Sc)                 best type
# Ellipticity           P(E)                  P(Scd)
# u-g                   P(S0)                 P(Sd)
# g-r                   P(Sa)                 P(Sdm)
# {-2: 'CD', -1: 'E', 0: 'S0', 1: 'Sa', 2: 'Sab', 3: 'Sb', 4: 'Sbc', 5: 'Sc', 6: 'Scd', 7: 'Sd', 8: 'Sdm', 9: 'Sm', 10: 'Irr'}

# %%
drpall='tables/drpall-v3_1_1.fits'
tab_dr = Table.read(drpall, format='fits')
tab_dr['name']=tab_dr['plateifu']
for indx,val in enumerate(tab_dr['name']):
    tab_dr['name'][indx]='manga-'+tab_dr['name'][indx]
list_columns(tab_dr.columns)
print(tab_dr['name'])
# Out:
# plate                    cartid                   manga_tileid             nsa_nsaid
# ifudsgn                  designid                 nsa_iauname              nsa_nsaid_v1b
# plateifu                 cenra                    ifudesignsize            nsa_z
# mangaid                  cendec                   ifutargetsize            nsa_zdist
# versdrp2                 airmsmin                 ifudesignwrongsize       nsa_sersic_absmag
# versdrp3                 airmsmed                 z                        nsa_elpetro_absmag
# verscore                 airmsmax                 zmin                     nsa_elpetro_amivar
# versutil                 seemin                   zmax                     nsa_sersic_mass
# versprim                 seemed                   szmin                    nsa_elpetro_mass
# platetyp                 seemax                   szmax                    nsa_elpetro_ba
# srvymode                 transmin                 ezmin                    nsa_elpetro_phi
# objra                    transmed                 ezmax                    nsa_extinction
# objdec                   transmax                 probs                    nsa_elpetro_th50_r
# ifuglon                  mjdmin                   pweight                  nsa_petro_th50
# ifuglat                  mjdmed                   psweight                 nsa_petro_flux
# ifura                    mjdmax                   psrweight                nsa_petro_flux_ivar
# ifudec                   gfwhm                    sweight                  nsa_elpetro_flux
# ebvgal                   rfwhm                    srweight                 nsa_elpetro_flux_ivar
# nexp                     ifwhm                    eweight                  nsa_sersic_ba
# exptime                  zfwhm                    esweight                 nsa_sersic_n
# drp3qual                 mngtarg1                 esrweight                nsa_sersic_phi
# bluesn2                  mngtarg2                 nsa_field                nsa_sersic_th50
# redsn2                   mngtarg3                 nsa_run                  nsa_sersic_flux
# harname                  catidnum                 nsa_camcol               nsa_sersic_flux_ivar
# frlplug                  plttarg                  nsa_version              name
#        name
# -----------------
# manga-10001-12701
# manga-10001-12702
# manga-10001-12703
# manga-10001-12704
# manga-10001-12705
#  manga-10001-1901
#  manga-10001-1902
#  manga-10001-3701
#  manga-10001-3702
#  manga-10001-3703
#               ...
#   manga-9894-1902
#   manga-9894-3701
#   manga-9894-3702
#   manga-9894-3703
#   manga-9894-3704
#   manga-9894-6101
#   manga-9894-6102
#   manga-9894-6103
#   manga-9894-6104
#   manga-9894-9101
#   manga-9894-9102
# Length = 11273 rows

# %%
vol_file="tables/MaNGA_MPL11_Volume_C.fits"
tab_vol = Table.read(vol_file, format='fits')
tab_vol['name']=tab_vol['plateifu']
for indx,val in enumerate(tab_vol['name']):
    name_now='manga-'+tab_vol['name'][indx]
    name_now=name_now.replace(" ","")
    tab_vol['name'][indx]=name_now
    

print(tab_vol['name'],tab_vol['Vmax_w'])
list_columns(tab_vol.columns)
# Out:
#        name
# -----------------
# manga-10001-12701
# manga-10001-12702
# manga-10001-12703
# manga-10001-12704
# manga-10001-12705
#  manga-10001-1901
#  manga-10001-1902
#  manga-10001-3701
#  manga-10001-3702
#  manga-10001-3703
#               ...
#  manga-9894-12705
#   manga-9894-1902
#   manga-9894-3701
#   manga-9894-3703
#   manga-9894-3704
#   manga-9894-6101
#   manga-9894-6102
#   manga-9894-6103
#   manga-9894-6104
#   manga-9894-9101
#   manga-9894-9102
# Length = 9341 rows    Vmax_w
# -----------
#  4.2211e-06
#  3.7132e-06
# 1.93554e-06
# 1.68639e-06
# 1.93554e-06
# 8.71277e-06
#   7.905e-06
# 6.45567e-07
#  5.6706e-06
# 2.38905e-06
#         ...
# 7.56699e-06
# 1.13259e-05
# 4.09177e-06
#  2.7185e-06
# 7.29204e-07
# 1.66874e-06
# 1.26995e-05
# 1.26995e-05
# 2.05023e-06
#  8.6621e-08
# 8.28911e-06
# Length = 9341 rows
# plate        mangaid      logMs_nsa    Num_w
# ifudsgn      nsa_nsaid    z_obs_nsa    name
# plateifu     nsaid        Vmax_w

# %%
#
# Joininig all tables
#
tab_mag['u-i']=tab_mag['u_band_mag']-tab_mag['i_band_mag']
tab_all=join(tab_pe,tab_mag,keys=['name'],join_type='left')
print("get_proc and get_mag joint")
tab_all=join(tab_all,tab_morph,keys=['name'],join_type='left')
print("... morph added")
tab_all=join(tab_all,tab_dr,keys=['name'],join_type='left')
print("... DR added")
tab_fe.remove_columns(['MaNGA_name','nsa_petro_th50', 'nsa_sersic_ba', 'nsa_sersic_n',\
                       'nsa_sersic_phi','nsa_sersic_th50'])
tab_all=join(tab_all,tab_fe,keys=['name'],join_type='left')
print("... flux_elines_long added")
tab_fe_org.remove_columns(['MaNGA_name','nsa_petro_th50', 'nsa_sersic_ba', 'nsa_sersic_n',\
                           'nsa_sersic_phi','nsa_sersic_th50'])
tab_all=join(tab_all,tab_fe_org,keys=['name'],join_type='left')
print("... flux_elines org added")
tab_OH.remove_columns(['MaNGA_name','nsa_petro_th50', 'nsa_sersic_ba', 'nsa_sersic_n',\
                       'nsa_sersic_phi','nsa_sersic_th50','nsa_redshift', 'nsa_u_absmag',\
                       'nsa_z_absmag', 'nsa_u_z_absmag', 'nsa_mstar', 'nsa_inclination'])
tab_all=join(tab_all,tab_OH,keys=['name'],join_type='left')
print("... OH added")
tab_all=join(tab_all,tab_ind_Re,keys=['name'],join_type='left')
print("... Indices at Re added")
tab_ind.remove_columns(['MaNGA_name','nsa_petro_th50', 'nsa_sersic_ba', 'nsa_sersic_n',\
                       'nsa_sersic_phi','nsa_sersic_th50','nsa_redshift', 'nsa_u_absmag',\
                       'nsa_z_absmag', 'nsa_u_z_absmag', 'nsa_mstar', 'nsa_inclination'])
tab_all=join(tab_all,tab_ind,keys=['name'],join_type='left')
print("... Indices fitted added")
tab_all=join(tab_all,tab_val_Re,keys=['name'],join_type='left')
print("... Values at Re added")
tab_all=join(tab_all,tab_val_in_Re,keys=['name'],join_type='left')
print("... Values in Re added")
tab_all=join(tab_all,tab_vol,keys=['name'],join_type='right')    
print("... Values of volume added")
#tab_all([data[n].filled(np.nan) for n in data.colnames])
# Out:
# get_proc and get_mag joint
# ... morph added
# ... DR added
# ... flux_elines_long added
# ... flux_elines org added
# ... OH added
# ... Indices at Re added
# ... Indices fitted added
# ... Values at Re added
# ... Values in Re added
# ... Values of volume added

# %%
#
# Create hypertable FITS
#Pipe3D_HDU = pyfits.PrimaryHDU()
hdu_pe = fits.BinTableHDU(tab_pe)
hdu_fe = fits.BinTableHDU(tab_fe)
hdu_OH = fits.BinTableHDU(tab_OH)
hdu_ind = fits.BinTableHDU(tab_ind)
hdu_val_Re = fits.BinTableHDU(tab_val_Re)
hdu_mag = fits.BinTableHDU(tab_mag)
hdu_morph = fits.BinTableHDU(tab_morph)
hdu_vol = fits.BinTableHDU(tab_vol)

hdr = fits.Header()
hdr['AUTHOR'] = 'dwin Hubble'
hdr['COMMENT'] = "Here's some commentary about this FITS file."
#>>> empty_primary = fits.PrimaryHDU(header=hdr)

#hdu_list =fits.HDUList()

#hdu_mag = fits.BinTableHDU(tab_mag)


#hdu_list = fits.HDUList()
#hdu_list.append(hdu_pe)

#hdulist=fits.HDUList([primhdu])
#hdu_pe.writeto('test.fits')
#primhdu = fits.PrimaryHDU(data=hdu_pe.data,header=hdu_pe.header)

#hdu_list.writeto('test.fits',overwrite=True)
#print(hdu_pe)

# %%
print(tab_all['Vmax_w'])
#for name in tab_vol['name']:
#    print("|"+name+"|")
#    print(name)
#    print(tab_vol['name'][tab_vol['name']==name])
#tab_all_vol=join(tab_all,tab_vol,keys=['name'],join_type='right')    
#print("... Values of volume added")
#print(tab_all_vol['Vmax_w'])
# Out:
#    Vmax_w
# -----------
#  4.2211e-06
#  3.7132e-06
# 1.93554e-06
# 1.68639e-06
# 1.93554e-06
# 8.71277e-06
#   7.905e-06
# 6.45567e-07
#  5.6706e-06
# 2.38905e-06
#         ...
# 7.56699e-06
# 1.13259e-05
# 4.09177e-06
#  2.7185e-06
# 7.29204e-07
# 1.66874e-06
# 1.26995e-05
# 1.26995e-05
# 2.05023e-06
#  8.6621e-08
# 8.28911e-06
# Length = 9348 rows

# %%
list_columns(tab_all.columns,5)
# Out:
# MaNGA_name                           a_ZH_T99                             flux_H83889_Re_fit                   disp_[SII]4076_Re_fit                l_flux_Hg4340_Hb_Re_fit
# nsa_redshift_1                       log_Mass_gas_Av_gas_OH               e_flux_H83889_Re_fit                 e_disp_[SII]4076_Re_fit              e_l_flux_Hg4340_Hb_Re_fit
# nsa_u_absmag_1                       log_Mass_gas_Av_ssp_OH               flux_H83889_alpha_fit                disp_[SII]4076_alpha_fit             l_flux_Hg4340_Hb_alpha_fit
# nsa_z_absmag_1                       lSFR_NO_CEN                          e_flux_H83889_alpha_fit              e_disp_[SII]4076_alpha_fit           e_l_flux_Hg4340_Hb_alpha_fit
# nsa_u_z_absmag_1                     vel_ssp_2                            flux_[NeIII]3967_Re_fit              disp_Hd4101_Re_fit                   l_flux_[OIII]4363_Hb_Re_fit
# nsa_mstar_1                          e_vel_ssp_2                          e_flux_[NeIII]3967_Re_fit            e_disp_Hd4101_Re_fit                 e_l_flux_[OIII]4363_Hb_Re_fit
# nsa_inclination_1                    vel_Ha_2                             flux_[NeIII]3967_alpha_fit           disp_Hd4101_alpha_fit                l_flux_[OIII]4363_Hb_alpha_fit
# nsa_petro_th50_1                     e_vel_Ha_2                           e_flux_[NeIII]3967_alpha_fit         e_disp_Hd4101_alpha_fit              e_l_flux_[OIII]4363_Hb_alpha_fit
# nsa_sersic_ba_1                      vel_ssp_1                            flux_He3970_Re_fit                   disp_[FeII]4276_Re_fit               l_flux_[FeII]4413_Hb_Re_fit
# nsa_sersic_n_1                       e_vel_ssp_1                          e_flux_He3970_Re_fit                 e_disp_[FeII]4276_Re_fit             e_l_flux_[FeII]4413_Hb_Re_fit
# nsa_sersic_phi_1                     vel_Ha_1                             flux_He3970_alpha_fit                disp_[FeII]4276_alpha_fit            l_flux_[FeII]4413_Hb_alpha_fit
# nsa_sersic_th50_1                    e_vel_Ha_1                           e_flux_He3970_alpha_fit              e_disp_[FeII]4276_alpha_fit          e_l_flux_[FeII]4413_Hb_alpha_fit
# name                                 log_SFR_ssp_100Myr                   flux_HeI4026_Re_fit                  disp_[FeII]4287_Re_fit               l_flux_[FeII]4416_Hb_Re_fit
# log_Mass_no_corr                     log_SFR_ssp_10Myr                    e_flux_HeI4026_Re_fit                e_disp_[FeII]4287_Re_fit             e_l_flux_[FeII]4416_Hb_Re_fit
# lSFR                                 vel_disp_Ha_cen                      flux_HeI4026_alpha_fit               disp_[FeII]4287_alpha_fit            l_flux_[FeII]4416_Hb_alpha_fit
# OH_O3N2_1                            vel_disp_ssp_cen                     e_flux_HeI4026_alpha_fit             e_disp_[FeII]4287_alpha_fit          e_l_flux_[FeII]4416_Hb_alpha_fit
# e_OH_O3N2_1                          vel_disp_Ha_1Re                      flux_[SII]4069_Re_fit                disp_[FeII]4319_Re_fit               l_flux_HeI4471_Hb_Re_fit
# a_ion_cen[3]                         vel_disp_ssp_1Re                     e_flux_[SII]4069_Re_fit              e_disp_[FeII]4319_Re_fit             e_l_flux_HeI4471_Hb_Re_fit
# frac_area_GAS                        vel_disp_Ha_1Re_mean                 flux_[SII]4069_alpha_fit             disp_[FeII]4319_alpha_fit            l_flux_HeI4471_Hb_alpha_fit
# frac_area_SFR_pure                   vel_disp_ssp_1Re_mean                e_flux_[SII]4069_alpha_fit           e_disp_[FeII]4319_alpha_fit          e_l_flux_HeI4471_Hb_alpha_fit
# Av_w                                 log_Mass_Re                          flux_[SII]4076_Re_fit                disp_Hg4340_Re_fit                   l_flux_[FeIII]4657_Hb_Re_fit
# OH_O3N2_Re                           e_log_Mass_Re                        e_flux_[SII]4076_Re_fit              e_disp_Hg4340_Re_fit                 e_l_flux_[FeIII]4657_Hb_Re_fit
# alpha_OH_O3N2_Re                     log_SFR_Re                           flux_[SII]4076_alpha_fit             disp_Hg4340_alpha_fit                l_flux_[FeIII]4657_Hb_alpha_fit
# a_vel_Ha_cen_mean                    e_log_SFR_Re                         e_flux_[SII]4076_alpha_fit           e_disp_Hg4340_alpha_fit              e_l_flux_[FeIII]4657_Hb_alpha_fit
# a_vel_ssp_cen_mean                   KIN_Ha_1                             flux_Hd4101_Re_fit                   disp_[OIII]4363_Re_fit               l_flux_HeII4686_Hb_Re_fit
# z_gas                                e_KIN_Ha_1                           e_flux_Hd4101_Re_fit                 e_disp_[OIII]4363_Re_fit             e_l_flux_HeII4686_Hb_Re_fit
# z_stars                              KIN_ssp_1                            flux_Hd4101_alpha_fit                disp_[OIII]4363_alpha_fit            l_flux_HeII4686_Hb_alpha_fit
# FoV                                  e_KIN_ssp_1                          e_flux_Hd4101_alpha_fit              e_disp_[OIII]4363_alpha_fit          e_l_flux_HeII4686_Hb_alpha_fit
# nx                                   KIN_Ha_05                            flux_[FeII]4276_Re_fit               disp_[FeII]4413_Re_fit               l_flux_HeI4712_Hb_Re_fit
# ny                                   e_KIN_Ha_05                          e_flux_[FeII]4276_Re_fit             e_disp_[FeII]4413_Re_fit             e_l_flux_HeI4712_Hb_Re_fit
# Re_kpc                               KIN_ssp_05                           flux_[FeII]4276_alpha_fit            disp_[FeII]4413_alpha_fit            l_flux_HeI4712_Hb_alpha_fit
# mag_g                                e_KIN_ssp_05                         e_flux_[FeII]4276_alpha_fit          e_disp_[FeII]4413_alpha_fit          e_l_flux_HeI4712_Hb_alpha_fit
# log_Mass_corr_1                      log_U_P_Re_fit                       flux_[FeII]4287_Re_fit               disp_[FeII]4416_Re_fit               l_flux_HeI4922_Hb_Re_fit
# Av_ssp_stats[2]                      e_log_U_P_Re_fit                     e_flux_[FeII]4287_Re_fit             e_disp_[FeII]4416_Re_fit             e_l_flux_HeI4922_Hb_Re_fit
# OH_O3N2_Re2                          alpha_log_U_P_Re_fit                 flux_[FeII]4287_alpha_fit            disp_[FeII]4416_alpha_fit            l_flux_HeI4922_Hb_alpha_fit
# e_OH_O3N2_Re2                        e_alpha_log_U_P_Re_fit               e_flux_[FeII]4287_alpha_fit          e_disp_[FeII]4416_alpha_fit          e_l_flux_HeI4922_Hb_alpha_fit
# error_Mass                           log_U_iter_Re_fit                    flux_[FeII]4319_Re_fit               disp_HeI4471_Re_fit                  l_flux_[OIII]5006_Hb_Re_fit
# e_lSFR                               e_log_U_iter_Re_fit                  e_flux_[FeII]4319_Re_fit             e_disp_HeI4471_Re_fit                e_l_flux_[OIII]5006_Hb_Re_fit
# Age_LW_Re                            alpha_log_U_iter_Re_fit              flux_[FeII]4319_alpha_fit            disp_HeI4471_alpha_fit               l_flux_[OIII]5006_Hb_alpha_fit
# e_Age_LW_Re                          e_alpha_log_U_iter_Re_fit            e_flux_[FeII]4319_alpha_fit          e_disp_HeI4471_alpha_fit             e_l_flux_[OIII]5006_Hb_alpha_fit
# ZH_LW_Re                             log_U_pyqz_Re_fit                    flux_Hg4340_Re_fit                   disp_[FeIII]4657_Re_fit              l_flux_[OIII]4958_Hb_Re_fit
# e_ZH_LW_Re                           e_log_U_pyqz_Re_fit                  e_flux_Hg4340_Re_fit                 e_disp_[FeIII]4657_Re_fit            e_l_flux_[OIII]4958_Hb_Re_fit
# Av_LW_Re                             alpha_log_U_pyqz_Re_fit              flux_Hg4340_alpha_fit                disp_[FeIII]4657_alpha_fit           l_flux_[OIII]4958_Hb_alpha_fit
# e_Av_LW_Re                           e_alpha_log_U_pyqz_Re_fit            e_flux_Hg4340_alpha_fit              e_disp_[FeIII]4657_alpha_fit         e_l_flux_[OIII]4958_Hb_alpha_fit
# Av_gas_LW_Re                         OH_Re_fit_N2O2                       flux_[OIII]4363_Re_fit               disp_HeII4686_Re_fit                 l_flux_Hb4861_Hb_Re_fit
# e_Av_gas_LW_Re                       e_OH_Re_fit_N2O2                     e_flux_[OIII]4363_Re_fit             e_disp_HeII4686_Re_fit               e_l_flux_Hb4861_Hb_Re_fit
# OH_Z_Re                              alpha_OH_Re_fit_N2O2                 flux_[OIII]4363_alpha_fit            disp_HeII4686_alpha_fit              l_flux_Hb4861_Hb_alpha_fit
# e_ZH_LW_Re1                          e_alpha_OH_Re_fit_N2O2               e_flux_[OIII]4363_alpha_fit          e_disp_HeII4686_alpha_fit            e_l_flux_Hb4861_Hb_alpha_fit
# log_age_mean_LW                      cc_r_OH_N2O2                         flux_[FeII]4413_Re_fit               disp_HeI4712_Re_fit                  l_flux_[FeII]4889_Hb_Re_fit
# s_log_age_mean_LW                    sig_r_OH_N2O2                        e_flux_[FeII]4413_Re_fit             e_disp_HeI4712_Re_fit                e_l_flux_[FeII]4889_Hb_Re_fit
# log_ZH_mean_LW                       log_Mass_in_Re                       flux_[FeII]4413_alpha_fit            disp_HeI4712_alpha_fit               l_flux_[FeII]4889_Hb_alpha_fit
# s_log_ZH_mean_LW                     ML_int                               e_flux_[FeII]4413_alpha_fit          e_disp_HeI4712_alpha_fit             e_l_flux_[FeII]4889_Hb_alpha_fit
# Av_ssp_stats_mean                    ML_avg                               flux_[FeII]4416_Re_fit               disp_HeI4922_Re_fit                  l_flux_[FeII]4905_Hb_Re_fit
# Av_ssp_stats_stddev                  log_Mass_Re_derived                  e_flux_[FeII]4416_Re_fit             e_disp_HeI4922_Re_fit                e_l_flux_[FeII]4905_Hb_Re_fit
# Av_w1                                F_Ha_cen                             flux_[FeII]4416_alpha_fit            disp_HeI4922_alpha_fit               l_flux_[FeII]4905_Hb_alpha_fit
# e_Av_w                               e_F_Ha_cen                           e_flux_[FeII]4416_alpha_fit          e_disp_HeI4922_alpha_fit             e_l_flux_[FeII]4905_Hb_alpha_fit
# OH_Re_fit_O3N2                       Re_kpc_Mass                          flux_HeI4471_Re_fit                  disp_[OIII]5006_Re_fit               l_flux_[FeII]5111_Hb_Re_fit
# e_OH_Re_fit_O3N2                     R50_kpc_V                            e_flux_HeI4471_Re_fit                e_disp_[OIII]5006_Re_fit             e_l_flux_[FeII]5111_Hb_Re_fit
# alpha_OH_Re_fit_O3N2                 e_R50_kpc_V                          flux_HeI4471_alpha_fit               disp_[OIII]5006_alpha_fit            l_flux_[FeII]5111_Hb_alpha_fit
# e_alpha_OH_Re_fit_O3N2               R50_kpc_Mass                         e_flux_HeI4471_alpha_fit             e_disp_[OIII]5006_alpha_fit          e_l_flux_[FeII]5111_Hb_alpha_fit
# cc_r_OH_O3N2                         e_R50_kpc_Mass                       flux_[FeIII]4657_Re_fit              disp_[OIII]4958_Re_fit               l_flux_[FeII]5158_Hb_Re_fit
# sig_r_OH_O3N2                        log_Mass_corr_in_R50_V               e_flux_[FeIII]4657_Re_fit            e_disp_[OIII]4958_Re_fit             e_l_flux_[FeII]5158_Hb_Re_fit
# OH_Re_fit_N2                         e_log_Mass_corr_in_R50_V             flux_[FeIII]4657_alpha_fit           disp_[OIII]4958_alpha_fit            l_flux_[FeII]5158_Hb_alpha_fit
# e_OH_Re_fit_N2                       log_Mass_in_Re1                      e_flux_[FeIII]4657_alpha_fit         e_disp_[OIII]4958_alpha_fit          e_l_flux_[FeII]5158_Hb_alpha_fit
# alpha_OH_Re_fit_N2                   rMgMs_zp                             flux_HeII4686_Re_fit                 disp_Hb4861_Re_fit                   l_flux_[NI]5199_Hb_Re_fit
# e_alpha_OH_Re_fit_N2                 rMgMs_e_zp                           e_flux_HeII4686_Re_fit               e_disp_Hb4861_Re_fit                 e_l_flux_[NI]5199_Hb_Re_fit
# cc_r_OH_N2                           rMgMs_alpha                          flux_HeII4686_alpha_fit              disp_Hb4861_alpha_fit                l_flux_[NI]5199_Hb_alpha_fit
# sig_r_OH_N2                          rMgMs_e_alpha                        e_flux_HeII4686_alpha_fit            e_disp_Hb4861_alpha_fit              e_l_flux_[NI]5199_Hb_alpha_fit
# OH_Re_fit_ONS                        rMgMs_cc                             flux_HeI4712_Re_fit                  disp_[FeII]4889_Re_fit               l_flux_[FeII]5261_Hb_Re_fit
# e_OH_Re_fit_ONS                      rMgMs_sig                            e_flux_HeI4712_Re_fit                e_disp_[FeII]4889_Re_fit             e_l_flux_[FeII]5261_Hb_Re_fit
# alpha_OH_Re_fit_ONS                  rSFMS_zp                             flux_HeI4712_alpha_fit               disp_[FeII]4889_alpha_fit            l_flux_[FeII]5261_Hb_alpha_fit
# e_alpha_OH_Re_fit_ONS                rSFMS_e_zp                           e_flux_HeI4712_alpha_fit             e_disp_[FeII]4889_alpha_fit          e_l_flux_[FeII]5261_Hb_alpha_fit
# cc_r_OH_ONS                          rSFMS_alpha                          flux_HeI4922_Re_fit                  disp_[FeII]4905_Re_fit               l_flux_[ClIII]5517_Hb_Re_fit
# sig_r_OH_ONS                         rSFMS_e_alpha                        e_flux_HeI4922_Re_fit                e_disp_[FeII]4905_Re_fit             e_l_flux_[ClIII]5517_Hb_Re_fit
# OH_Re_fit_R23                        rSFMS_cc                             flux_HeI4922_alpha_fit               disp_[FeII]4905_alpha_fit            l_flux_[ClIII]5517_Hb_alpha_fit
# e_OH_Re_fit_R23                      rSFMS_sig                            e_flux_HeI4922_alpha_fit             e_disp_[FeII]4905_alpha_fit          e_l_flux_[ClIII]5517_Hb_alpha_fit
# alpha_OH_Re_fit_R23                  rSK_zp                               flux_[OIII]5006_Re_fit               disp_[FeII]5111_Re_fit               l_flux_[ClIII]5537_Hb_Re_fit
# e_alpha_OH_Re_fit_R23                rSK_e_zp                             e_flux_[OIII]5006_Re_fit             e_disp_[FeII]5111_Re_fit             e_l_flux_[ClIII]5537_Hb_Re_fit
# cc_r_OH_R23                          rSK_alpha                            flux_[OIII]5006_alpha_fit            disp_[FeII]5111_alpha_fit            l_flux_[ClIII]5537_Hb_alpha_fit
# sig_r_OH_R23                         rSK_e_alpha                          e_flux_[OIII]5006_alpha_fit          e_disp_[FeII]5111_alpha_fit          e_l_flux_[ClIII]5537_Hb_alpha_fit
# stats_OH_Re_mean_mean                rSK_cc                               flux_[OIII]4958_Re_fit               disp_[FeII]5158_Re_fit               l_flux_OI5554_Hb_Re_fit
# stats_OH_Re_mean_stddev              rSK_sig                              e_flux_[OIII]4958_Re_fit             e_disp_[FeII]5158_Re_fit             e_l_flux_OI5554_Hb_Re_fit
# stats_a_OH_Re_mean_mean              log_Mass_gas_Av_EW_corr              flux_[OIII]4958_alpha_fit            disp_[FeII]5158_alpha_fit            l_flux_OI5554_Hb_alpha_fit
# stats_a_OH_Re_mean_stddev            log_Mass_gas_Av_gas_log_lin          e_flux_[OIII]4958_alpha_fit          e_disp_[FeII]5158_alpha_fit          e_l_flux_OI5554_Hb_alpha_fit
# log_Mass                             log_Mass_gas_Av_ssp_log_lin          flux_Hb4861_Re_fit                   disp_[NI]5199_Re_fit                 l_flux_[OI]5577_Hb_Re_fit
# log_SFR_ssp                          log_Mass_gas_Av_gas_log_log          e_flux_Hb4861_Re_fit                 e_disp_[NI]5199_Re_fit               e_l_flux_[OI]5577_Hb_Re_fit
# log_NII_Ha_cen_mean                  OH_Re_fit_R                          flux_Hb4861_alpha_fit                disp_[NI]5199_alpha_fit              l_flux_[OI]5577_Hb_alpha_fit
# log_NII_Ha_cen_stddev                e_OH_Re_fit_R                        e_flux_Hb4861_alpha_fit              e_disp_[NI]5199_alpha_fit            e_l_flux_[OI]5577_Hb_alpha_fit
# log_OIII_Hb_cen_mean                 alpha_OH_Re_fit_R                    flux_[FeII]4889_Re_fit               disp_[FeII]5261_Re_fit               l_flux_[NII]5754_Hb_Re_fit
# log_OIII_Hb_cen_stddev               e_alpha_OH_Re_fit_R                  e_flux_[FeII]4889_Re_fit             e_disp_[FeII]5261_Re_fit             e_l_flux_[NII]5754_Hb_Re_fit
# log_SII_Ha_cen_mean                  cc_r_OH_R                            flux_[FeII]4889_alpha_fit            disp_[FeII]5261_alpha_fit            l_flux_[NII]5754_Hb_alpha_fit
# log_SII_Ha_cen_stddev                sig_r_OH_R                           e_flux_[FeII]4889_alpha_fit          e_disp_[FeII]5261_alpha_fit          e_l_flux_[NII]5754_Hb_alpha_fit
# log_OII_Hb_cen_mean                  OH_R_cen_mean                        flux_[FeII]4905_Re_fit               disp_[ClIII]5517_Re_fit              l_flux_HeI5875_Hb_Re_fit
# log_OII_Hb_cen_stddev                OH_R_cen_error                       e_flux_[FeII]4905_Re_fit             e_disp_[ClIII]5517_Re_fit            e_l_flux_HeI5875_Hb_Re_fit
# EW_Ha_cen_mean                       OH_R_Re_mean                         flux_[FeII]4905_alpha_fit            disp_[ClIII]5517_alpha_fit           l_flux_HeI5875_Hb_alpha_fit
# EW_Ha_cen_stddev                     OH_R_Re_error                        e_flux_[FeII]4905_alpha_fit          e_disp_[ClIII]5517_alpha_fit         e_l_flux_HeI5875_Hb_alpha_fit
# stats_y_200_mean                     OH_R_ALL_mean                        flux_[FeII]5111_Re_fit               disp_[ClIII]5537_Re_fit              l_flux_[OI]6300_Hb_Re_fit
# stats_y_200_stddev                   OH_R_ALL_error                       e_flux_[FeII]5111_Re_fit             e_disp_[ClIII]5537_Re_fit            e_l_flux_[OI]6300_Hb_Re_fit
# stats_y_30_mean                      OH_Re_fit_S                          flux_[FeII]5111_alpha_fit            disp_[ClIII]5537_alpha_fit           l_flux_[OI]6300_Hb_alpha_fit
# stats_y_30_stddev                    e_OH_Re_fit_S                        e_flux_[FeII]5111_alpha_fit          e_disp_[ClIII]5537_alpha_fit         e_l_flux_[OI]6300_Hb_alpha_fit
# stats_EW_Ha_mean                     alpha_OH_Re_fit_S                    flux_[FeII]5158_Re_fit               disp_OI5554_Re_fit                   l_flux_[SIII]6312_Hb_Re_fit
# stats_EW_Ha_stddev                   e_alpha_OH_Re_fit_S                  e_flux_[FeII]5158_Re_fit             e_disp_OI5554_Re_fit                 e_l_flux_[SIII]6312_Hb_Re_fit
# ZH_LW_Re_fit                         cc_r_OH_S                            flux_[FeII]5158_alpha_fit            disp_OI5554_alpha_fit                l_flux_[SIII]6312_Hb_alpha_fit
# e_ZH_LW_Re_fit                       sig_r_OH_S                           e_flux_[FeII]5158_alpha_fit          e_disp_OI5554_alpha_fit              e_l_flux_[SIII]6312_Hb_alpha_fit
# alpha_ZH_LW_Re_fit                   OH_S_cen_mean                        flux_[NI]5199_Re_fit                 disp_[OI]5577_Re_fit                 l_flux_SiII6347_Hb_Re_fit
# e_alpha_ZH_LW_Re_fit                 OH_S_cen_error                       e_flux_[NI]5199_Re_fit               e_disp_[OI]5577_Re_fit               e_l_flux_SiII6347_Hb_Re_fit
# ZH_LW_lRe_fit                        OH_S_Re_mean                         flux_[NI]5199_alpha_fit              disp_[OI]5577_alpha_fit              l_flux_SiII6347_Hb_alpha_fit
# e_ZH_LW_lRe_fit                      OH_S_Re_error                        e_flux_[NI]5199_alpha_fit            e_disp_[OI]5577_alpha_fit            e_l_flux_SiII6347_Hb_alpha_fit
# alpha_ZH_LW_lRe_fit                  OH_S_ALL_mean                        flux_[FeII]5261_Re_fit               disp_[NII]5754_Re_fit                l_flux_[OI]6363_Hb_Re_fit
# e_alpha_ZH_LW_lRe_fit                OH_S_ALL_error                       e_flux_[FeII]5261_Re_fit             e_disp_[NII]5754_Re_fit              e_l_flux_[OI]6363_Hb_Re_fit
# ZH_MW_Re_fit                         NH_Re_fit_R                          flux_[FeII]5261_alpha_fit            disp_[NII]5754_alpha_fit             l_flux_[OI]6363_Hb_alpha_fit
# e_ZH_MW_Re_fit                       e_NH_Re_fit_R                        e_flux_[FeII]5261_alpha_fit          e_disp_[NII]5754_alpha_fit           e_l_flux_[OI]6363_Hb_alpha_fit
# alpha_ZH_MW_Re_fit                   alpha_NH_Re_fit_R                    flux_[ClIII]5517_Re_fit              disp_HeI5875_Re_fit                  l_flux_Ha6562_Hb_Re_fit
# e_alpha_ZH_MW_Re_fit                 e_alpha_NH_Re_fit_R                  e_flux_[ClIII]5517_Re_fit            e_disp_HeI5875_Re_fit                e_l_flux_Ha6562_Hb_Re_fit
# Age_LW_Re_fit                        cc_r_NH_R                            flux_[ClIII]5517_alpha_fit           disp_HeI5875_alpha_fit               l_flux_Ha6562_Hb_alpha_fit
# e_Age_LW_Re_fit                      sig_r_NH_R                           e_flux_[ClIII]5517_alpha_fit         e_disp_HeI5875_alpha_fit             e_l_flux_Ha6562_Hb_alpha_fit
# alpha_Age_LW_Re_fit                  NH_R_cen_mean                        flux_[ClIII]5537_Re_fit              disp_[OI]6300_Re_fit                 l_flux_[NII]6583_Hb_Re_fit
# e_alpha_Age_LW_Re_fit                NH_R_cen_error                       e_flux_[ClIII]5537_Re_fit            e_disp_[OI]6300_Re_fit               e_l_flux_[NII]6583_Hb_Re_fit
# Age_LW_lRe_fit                       NH_R_Re_mean                         flux_[ClIII]5537_alpha_fit           disp_[OI]6300_alpha_fit              l_flux_[NII]6583_Hb_alpha_fit
# e_Age_LW_lRe_fit                     NH_R_Re_error                        e_flux_[ClIII]5537_alpha_fit         e_disp_[OI]6300_alpha_fit            e_l_flux_[NII]6583_Hb_alpha_fit
# alpha_Age_LW_lRe_fit                 NH_R_ALL_mean                        flux_OI5554_Re_fit                   disp_[SIII]6312_Re_fit               l_flux_[NII]6548_Hb_Re_fit
# e_alpha_Age_LW_lRe_fit               NH_R_ALL_error                       e_flux_OI5554_Re_fit                 e_disp_[SIII]6312_Re_fit             e_l_flux_[NII]6548_Hb_Re_fit
# Age_MW_Re_fit                        redshift                             flux_OI5554_alpha_fit                disp_[SIII]6312_alpha_fit            l_flux_[NII]6548_Hb_alpha_fit
# e_Age_MW_Re_fit                      error_redshift                       e_flux_OI5554_alpha_fit              e_disp_[SIII]6312_alpha_fit          e_l_flux_[NII]6548_Hb_alpha_fit
# alpha_Age_MW_Re_fit                  u_band_mag                           flux_[OI]5577_Re_fit                 disp_SiII6347_Re_fit                 l_flux_HeI6677_Hb_Re_fit
# e_alpha_Age_MW_Re_fit                u_band_mag_error                     e_flux_[OI]5577_Re_fit               e_disp_SiII6347_Re_fit               e_l_flux_HeI6677_Hb_Re_fit
# ZH_LW_Re_fit_0_0.5_Gyr               u_band_abs_mag                       flux_[OI]5577_alpha_fit              disp_SiII6347_alpha_fit              l_flux_HeI6677_Hb_alpha_fit
# e_ZH_LW_Re_fit_0_0.5_Gyr             u_band_abs_mag_error                 e_flux_[OI]5577_alpha_fit            e_disp_SiII6347_alpha_fit            e_l_flux_HeI6677_Hb_alpha_fit
# alpha_ZH_LW_Re_fit_0_0.5_Gyr         g_band_mag                           flux_[NII]5754_Re_fit                disp_[OI]6363_Re_fit                 l_flux_[SII]6716_Hb_Re_fit
# e_alpha_ZH_LW_Re_fit_0_0.5_Gyr       g_band_mag_error                     e_flux_[NII]5754_Re_fit              e_disp_[OI]6363_Re_fit               e_l_flux_[SII]6716_Hb_Re_fit
# ZH_LW_Re_fit_0.5_2.0_Gyr             g_band_abs_mag                       flux_[NII]5754_alpha_fit             disp_[OI]6363_alpha_fit              l_flux_[SII]6716_Hb_alpha_fit
# e_ZH_LW_Re_fit_0.5_2.0_Gyr           g_band_abs_mag_error                 e_flux_[NII]5754_alpha_fit           e_disp_[OI]6363_alpha_fit            e_l_flux_[SII]6716_Hb_alpha_fit
# alpha_ZH_LW_Re_fit_0.5_2.0_Gyr       r_band_mag                           flux_HeI5875_Re_fit                  disp_Ha6562_Re_fit                   l_flux_[SII]6730_Hb_Re_fit
# e_alpha_ZH_LW_Re_fit_0.5_2.0_Gyr     r_band_mag_error                     e_flux_HeI5875_Re_fit                e_disp_Ha6562_Re_fit                 e_l_flux_[SII]6730_Hb_Re_fit
# ZH_LW_Re_fit2.0_14.0_Gyr             r_band_abs_mag                       flux_HeI5875_alpha_fit               disp_Ha6562_alpha_fit                l_flux_[SII]6730_Hb_alpha_fit
# e_ZH_LW_Re_fit2.0_14.0_Gyr           r_band_abs_mag_error                 e_flux_HeI5875_alpha_fit             e_disp_Ha6562_alpha_fit              e_l_flux_[SII]6730_Hb_alpha_fit
# alpha_ZH_LW_Re_fit2.0_14.0_Gyr       i_band_mag                           flux_[OI]6300_Re_fit                 disp_[NII]6583_Re_fit                l_flux_[ArIII]7136_Hb_Re_fit
# e_alpha_ZH_LW_Re_fit2.0_14.0_Gyr     i_band_mag_error                     e_flux_[OI]6300_Re_fit               e_disp_[NII]6583_Re_fit              e_l_flux_[ArIII]7136_Hb_Re_fit
# Re_arc                               i_band_abs_mag                       flux_[OI]6300_alpha_fit              disp_[NII]6583_alpha_fit             l_flux_[ArIII]7136_Hb_alpha_fit
# Re_kpc1                              i_band_abs_mag_error                 e_flux_[OI]6300_alpha_fit            e_disp_[NII]6583_alpha_fit           e_l_flux_[ArIII]7136_Hb_alpha_fit
# DL                                   B_band_mag                           flux_[SIII]6312_Re_fit               disp_[NII]6548_Re_fit                l_flux_[OII]7325_Hb_Re_fit
# DA                                   B_band_mag_error                     e_flux_[SIII]6312_Re_fit             e_disp_[NII]6548_Re_fit              e_l_flux_[OII]7325_Hb_Re_fit
# P.A.                                 B_band_abs_mag                       flux_[SIII]6312_alpha_fit            disp_[NII]6548_alpha_fit             l_flux_[OII]7325_Hb_alpha_fit
# Ellipticity_1                        B_band_abs_mag_error                 e_flux_[SIII]6312_alpha_fit          e_disp_[NII]6548_alpha_fit           e_l_flux_[OII]7325_Hb_alpha_fit
# Inclination                          V_band_mag                           flux_SiII6347_Re_fit                 disp_HeI6677_Re_fit                  l_flux_[ArIII]7751_Hb_Re_fit
# sigma_cen                            V_band_mag_error                     e_flux_SiII6347_Re_fit               e_disp_HeI6677_Re_fit                e_l_flux_[ArIII]7751_Hb_Re_fit
# e_sigma_cen                          V_band_abs_mag                       flux_SiII6347_alpha_fit              disp_HeI6677_alpha_fit               l_flux_[ArIII]7751_Hb_alpha_fit
# lambda_Re                            V_band_abs_mag_error                 e_flux_SiII6347_alpha_fit            e_disp_HeI6677_alpha_fit             e_l_flux_[ArIII]7751_Hb_alpha_fit
# e_lambda_Re                          R_band_mag                           flux_[OI]6363_Re_fit                 disp_[SII]6716_Re_fit                l_flux_[SIII]9068_Hb_Re_fit
# elip_ab                              R_band_mag_error                     e_flux_[OI]6363_Re_fit               e_disp_[SII]6716_Re_fit              e_l_flux_[SIII]9068_Hb_Re_fit
# log_Mass_gas                         R_band_abs_mag                       flux_[OI]6363_alpha_fit              disp_[SII]6716_alpha_fit             l_flux_[SIII]9068_Hb_alpha_fit
# log_Mass_gas_Re                      R_band_abs_mag_error                 e_flux_[OI]6363_alpha_fit            e_disp_[SII]6716_alpha_fit           e_l_flux_[SIII]9068_Hb_alpha_fit
# log_Mass_gas_Av_ssp_ZH               X_centroid                           flux_Ha6562_Re_fit                   disp_[SII]6730_Re_fit                l_flux_[SIII]9530_Hb_Re_fit
# log_Mass_gas_Av_ssp                  Y_centroid                           e_flux_Ha6562_Re_fit                 e_disp_[SII]6730_Re_fit              e_l_flux_[SIII]9530_Hb_Re_fit
# log_Mass_gas_Av_gas_rad              Re                                   flux_Ha6562_alpha_fit                disp_[SII]6730_alpha_fit             l_flux_[SIII]9530_Hb_alpha_fit
# log_Mass_stars_sigma                 error_Re                             e_flux_Ha6562_alpha_fit              e_disp_[SII]6730_alpha_fit           e_l_flux_[SIII]9530_Hb_alpha_fit
# log_F_Ha                             mean_S/N_at_Re                       flux_[NII]6583_Re_fit                disp_[ArIII]7136_Re_fit              l_flux0_Hb_Re_fit
# log_F_Ha_cor                         sigma_S/N_at_Re                      e_flux_[NII]6583_Re_fit              e_disp_[ArIII]7136_Re_fit            e_l_flux0_Hb_Re_fit
# log_L_Ha_cor                         ellipticy                            flux_[NII]6583_alpha_fit             disp_[ArIII]7136_alpha_fit           l_flux0_Hb_alpha_fit
# NH_Re_log                            Pa                                   e_flux_[NII]6583_alpha_fit           e_disp_[ArIII]7136_alpha_fit         e_l_flux0_Hb_alpha_fit
# NO_Re_log                            R50                                  flux_[NII]6548_Re_fit                disp_[OII]7325_Re_fit                OH_Mar13_N2_Re_fit
# sigma_cen_Ha                         error_R50                            e_flux_[NII]6548_Re_fit              e_disp_[OII]7325_Re_fit              e_OH_Mar13_N2_Re_fit
# e_sigma_cen_Ha                       R90                                  flux_[NII]6548_alpha_fit             disp_[OII]7325_alpha_fit             OH_Mar13_N2_alpha_fit
# rat_vel_sigma_1                      error_R90                            e_flux_[NII]6548_alpha_fit           e_disp_[OII]7325_alpha_fit           e_OH_Mar13_N2_alpha_fit
# e_rat_vel_sigma                      C                                    flux_HeI6677_Re_fit                  disp_[ArIII]7751_Re_fit              OH_Mar13_O3N2_Re_fit
# OH_Re_fit_pyqz                       e_C                                  e_flux_HeI6677_Re_fit                e_disp_[ArIII]7751_Re_fit            e_OH_Mar13_O3N2_Re_fit
# e_OH_Re_fit_pyqz                     SN_at_Re                             flux_HeI6677_alpha_fit               disp_[ArIII]7751_alpha_fit           OH_Mar13_O3N2_alpha_fit
# alpha_OH_Re_fit_pyqz                 error_SN_at_Re                       e_flux_HeI6677_alpha_fit             e_disp_[ArIII]7751_alpha_fit         e_OH_Mar13_O3N2_alpha_fit
# e_alpha_OH_Re_fit_pyqz               SN_integrated                        flux_[SII]6716_Re_fit                disp_[SIII]9068_Re_fit               OH_T04_Re_fit
# cc_r_OH_pyqz                         SN_at_R50                            e_flux_[SII]6716_Re_fit              e_disp_[SIII]9068_Re_fit             e_OH_T04_Re_fit
# sig_r_OH_pyqz                        error_SN_at_R50                      flux_[SII]6716_alpha_fit             disp_[SIII]9068_alpha_fit            OH_T04_alpha_fit
# OH_Re_mean_phot                      Re1                                  e_flux_[SII]6716_alpha_fit           e_disp_[SIII]9068_alpha_fit          e_OH_T04_alpha_fit
# e_OH_Re_mean_phot                    error_Re1                            flux_[SII]6730_Re_fit                disp_[SIII]9530_Re_fit               OH_Pet04_N2_lin_Re_fit
# alpha_OH_Re_mean_phot                B-V                                  e_flux_[SII]6730_Re_fit              e_disp_[SIII]9530_Re_fit             e_OH_Pet04_N2_lin_Re_fit
# e_alpha_OH_Re_mean_phot              error_B-V                            flux_[SII]6730_alpha_fit             disp_[SIII]9530_alpha_fit            OH_Pet04_N2_lin_alpha_fit
# OH_ZH_LW_Re_fit                      B-R                                  e_flux_[SII]6730_alpha_fit           e_disp_[SIII]9530_alpha_fit          e_OH_Pet04_N2_lin_alpha_fit
# OH_ZH_LW_Re_fit_0_0.5Gyr             error_B-R                            flux_[ArIII]7136_Re_fit              disp0_Re_fit                         OH_Pet04_N2_poly_Re_fit
# OH_ZH_LW_Re_fit_0.5_2Gyr             log10_Mass/Msun_phot.                e_flux_[ArIII]7136_Re_fit            e_disp0_Re_fit                       e_OH_Pet04_N2_poly_Re_fit
# OH_ZH_LW_Re_fit_more_2Gyr            error_Mass_phot.                     flux_[ArIII]7136_alpha_fit           disp0_alpha_fit                      OH_Pet04_N2_poly_alpha_fit
# XC                                   nRe                                  e_flux_[ArIII]7136_alpha_fit         e_disp0_alpha_fit                    e_OH_Pet04_N2_poly_alpha_fit
# YC                                   V-band_SB_at_Re                      flux_[OII]7325_Re_fit                l_flux_[OII]3727_Ha_Re_fit           OH_Pet04_O3N2_Re_fit
# ZH_LW_Re_fit_0_2.0_Gyr               error_V-band_SB_at_Re                e_flux_[OII]7325_Re_fit              e_l_flux_[OII]3727_Ha_Re_fit         e_OH_Pet04_O3N2_Re_fit
# e_ZH_LW_Re_fit_0_2.0_Gyr             V-band_SB_at_R_50                    flux_[OII]7325_alpha_fit             l_flux_[OII]3727_Ha_alpha_fit        OH_Pet04_O3N2_alpha_fit
# alpha_ZH_LW_Re_fit_0_2.0_Gyr         error_V-band_SB_at_R_50              e_flux_[OII]7325_alpha_fit           e_l_flux_[OII]3727_Ha_alpha_fit      e_OH_Pet04_O3N2_alpha_fit
# e_alpha_ZH_LW_Re_fit_0_2.0_Gyr       u-i                                  flux_[ArIII]7751_Re_fit              l_flux_H123750_Ha_Re_fit             OH_Kew02_N2O2_Re_fit
# OH_ZH_LW_Re_fit_0_2Gyr               nsa_sersic_n_morph                   e_flux_[ArIII]7751_Re_fit            e_l_flux_H123750_Ha_Re_fit           e_OH_Kew02_N2O2_Re_fit
# OH_ZH_MW_Re_fit                      log_Mass_corr_2                      flux_[ArIII]7751_alpha_fit           l_flux_H123750_Ha_alpha_fit          OH_Kew02_N2O2_alpha_fit
# OH_ZH_MW_Re_fit_0_2Gyr               rat_vel_sigma_2                      e_flux_[ArIII]7751_alpha_fit         e_l_flux_H123750_Ha_alpha_fit        e_OH_Kew02_N2O2_alpha_fit
# T50                                  Ellipticity_2                        flux_[SIII]9068_Re_fit               l_flux_H113771_Ha_Re_fit             OH_Pil10_ONS_Re_fit
# T80                                  u-g                                  e_flux_[SIII]9068_Re_fit             e_l_flux_H113771_Ha_Re_fit           e_OH_Pil10_ONS_Re_fit
# OH_ZH_LW_Re_fit_t50                  g-r                                  flux_[SIII]9068_alpha_fit            l_flux_H113771_Ha_alpha_fit          OH_Pil10_ONS_alpha_fit
# OH_ZH_LW_Re_fit_M_t50                r-i                                  e_flux_[SIII]9068_alpha_fit          e_l_flux_H113771_Ha_alpha_fit        e_OH_Pil10_ONS_alpha_fit
# OH_ZH_LW_Re_fit_t80                  i-z                                  flux_[SIII]9530_Re_fit               l_flux_H103798_Ha_Re_fit             OH_Pil10_ON_Re_fit
# OH_ZH_LW_Re_fit_M_t80                C (R50/R90)                          e_flux_[SIII]9530_Re_fit             e_l_flux_H103798_Ha_Re_fit           e_OH_Pil10_ON_Re_fit
# OH_Re_mean                           P(CD)                                flux_[SIII]9530_alpha_fit            l_flux_H103798_Ha_alpha_fit          OH_Pil10_ON_alpha_fit
# e_OH_Re_mean                         P(E)                                 e_flux_[SIII]9530_alpha_fit          e_l_flux_H103798_Ha_alpha_fit        e_OH_Pil10_ON_alpha_fit
# alpha_OH_Re_mean                     P(S0)                                flux0_Re_fit                         l_flux_HeI3819_Ha_Re_fit             OH_Pil11_NS_Re_fit
# e_alpha_OH_Re_mean                   P(Sa)                                e_flux0_Re_fit                       e_l_flux_HeI3819_Ha_Re_fit           e_OH_Pil11_NS_Re_fit
# OH_Re_fit_mean                       P(Sab)                               flux0_alpha_fit                      l_flux_HeI3819_Ha_alpha_fit          OH_Pil11_NS_alpha_fit
# e_OH_Re_fit_mean                     P(Sb)                                e_flux0_alpha_fit                    e_l_flux_HeI3819_Ha_alpha_fit        e_OH_Pil11_NS_alpha_fit
# alpha_OH_Re_fit_mean                 P(Sbc)                               EW_[OII]3727_Re_fit                  l_flux_H93835_Ha_Re_fit              OH_Cur20_RS32_Re_fit
# e_alpha_OH_Re_fit_mean               P(Sc)                                e_EW_[OII]3727_Re_fit                e_l_flux_H93835_Ha_Re_fit            e_OH_Cur20_RS32_Re_fit
# cc_r_OH_mean                         P(Scd)                               EW_[OII]3727_alpha_fit               l_flux_H93835_Ha_alpha_fit           OH_Cur20_RS32_alpha_fit
# sig_r_OH_mean                        P(Sd)                                e_EW_[OII]3727_alpha_fit             e_l_flux_H93835_Ha_alpha_fit         e_OH_Cur20_RS32_alpha_fit
# OH_Re_fit_t2                         P(Sdm)                               EW_H123750_Re_fit                    l_flux_[NeIII]3869_Ha_Re_fit         OH_Cur20_R3_Re_fit
# e_OH_Re_fit_t2                       P(Sm)                                e_EW_H123750_Re_fit                  e_l_flux_[NeIII]3869_Ha_Re_fit       e_OH_Cur20_R3_Re_fit
# alpha_OH_Re_fit_t2                   P(Irr)                               EW_H123750_alpha_fit                 l_flux_[NeIII]3869_Ha_alpha_fit      OH_Cur20_R3_alpha_fit
# e_alpha_OH_Re_fit_t2                 best type_n                          e_EW_H123750_alpha_fit               e_l_flux_[NeIII]3869_Ha_alpha_fit    e_OH_Cur20_R3_alpha_fit
# cc_r_OH_t2                           best type                            EW_H113771_Re_fit                    l_flux_H83889_Ha_Re_fit              OH_Cur20_O3O2_Re_fit
# sig_r_OH_t2                          plate_1                              e_EW_H113771_Re_fit                  e_l_flux_H83889_Ha_Re_fit            e_OH_Cur20_O3O2_Re_fit
# OH_ZH_LW_Re_fit_t90                  ifudsgn_1                            EW_H113771_alpha_fit                 l_flux_H83889_Ha_alpha_fit           OH_Cur20_O3O2_alpha_fit
# OH_ZH_LW_Re_fit_M_t90                plateifu_1                           e_EW_H113771_alpha_fit               e_l_flux_H83889_Ha_alpha_fit         e_OH_Cur20_O3O2_alpha_fit
# t90                                  mangaid_1                            EW_H103798_Re_fit                    l_flux_[NeIII]3967_Ha_Re_fit         OH_Cur20_S2_Re_fit
# t70                                  versdrp2                             e_EW_H103798_Re_fit                  e_l_flux_[NeIII]3967_Ha_Re_fit       e_OH_Cur20_S2_Re_fit
# t60                                  versdrp3                             EW_H103798_alpha_fit                 l_flux_[NeIII]3967_Ha_alpha_fit      OH_Cur20_S2_alpha_fit
# ZH_LW_Re_fit_M_t50                   verscore                             e_EW_H103798_alpha_fit               e_l_flux_[NeIII]3967_Ha_alpha_fit    e_OH_Cur20_S2_alpha_fit
# e_ZH_LW_Re_fit_M_t50                 versutil                             EW_HeI3819_Re_fit                    l_flux_He3970_Ha_Re_fit              OH_Cur20_R2_Re_fit
# alpha_ZH_LW_Re_fit_M_t50             versprim                             e_EW_HeI3819_Re_fit                  e_l_flux_He3970_Ha_Re_fit            e_OH_Cur20_R2_Re_fit
# e_alpha_ZH_LW_Re_fit_M_t50           platetyp                             EW_HeI3819_alpha_fit                 l_flux_He3970_Ha_alpha_fit           OH_Cur20_R2_alpha_fit
# cc_ZH_LW_Re_M_t50                    srvymode                             e_EW_HeI3819_alpha_fit               e_l_flux_He3970_Ha_alpha_fit         e_OH_Cur20_R2_alpha_fit
# sig_ZH_LW_Re_M_t50                   objra                                EW_H93835_Re_fit                     l_flux_HeI4026_Ha_Re_fit             OH_Cur20_N2_Re_fit
# ZH_LW_Re_fit_M_t60                   objdec                               e_EW_H93835_Re_fit                   e_l_flux_HeI4026_Ha_Re_fit           e_OH_Cur20_N2_Re_fit
# e_ZH_LW_Re_fit_M_t60                 ifuglon                              EW_H93835_alpha_fit                  l_flux_HeI4026_Ha_alpha_fit          OH_Cur20_N2_alpha_fit
# alpha_ZH_LW_Re_fit_M_t60             ifuglat                              e_EW_H93835_alpha_fit                e_l_flux_HeI4026_Ha_alpha_fit        e_OH_Cur20_N2_alpha_fit
# e_alpha_ZH_LW_Re_fit_M_t60           ifura                                EW_[NeIII]3869_Re_fit                l_flux_[SII]4069_Ha_Re_fit           OH_Cur20_R23_Re_fit
# cc_ZH_LW_Re_M_t60                    ifudec                               e_EW_[NeIII]3869_Re_fit              e_l_flux_[SII]4069_Ha_Re_fit         e_OH_Cur20_R23_Re_fit
# sig_ZH_LW_Re_M_t60                   ebvgal                               EW_[NeIII]3869_alpha_fit             l_flux_[SII]4069_Ha_alpha_fit        OH_Cur20_R23_alpha_fit
# ZH_LW_Re_fit_M_t70                   nexp                                 e_EW_[NeIII]3869_alpha_fit           e_l_flux_[SII]4069_Ha_alpha_fit      e_OH_Cur20_R23_alpha_fit
# e_ZH_LW_Re_fit_M_t70                 exptime                              EW_H83889_Re_fit                     l_flux_[SII]4076_Ha_Re_fit           OH_Cur20_O3N2_Re_fit
# alpha_ZH_LW_Re_fit_M_t70             drp3qual                             e_EW_H83889_Re_fit                   e_l_flux_[SII]4076_Ha_Re_fit         e_OH_Cur20_O3N2_Re_fit
# e_alpha_ZH_LW_Re_fit_M_t70           bluesn2                              EW_H83889_alpha_fit                  l_flux_[SII]4076_Ha_alpha_fit        OH_Cur20_O3N2_alpha_fit
# cc_ZH_LW_Re_M_t70                    redsn2                               e_EW_H83889_alpha_fit                e_l_flux_[SII]4076_Ha_alpha_fit      e_OH_Cur20_O3N2_alpha_fit
# sig_ZH_LW_Re_M_t70                   harname                              EW_[NeIII]3967_Re_fit                l_flux_Hd4101_Ha_Re_fit              OH_Cur20_O3S2_Re_fit
# ZH_LW_Re_fit_M_t80                   frlplug                              e_EW_[NeIII]3967_Re_fit              e_l_flux_Hd4101_Ha_Re_fit            e_OH_Cur20_O3S2_Re_fit
# e_ZH_LW_Re_fit_M_t80                 cartid                               EW_[NeIII]3967_alpha_fit             l_flux_Hd4101_Ha_alpha_fit           OH_Cur20_O3S2_alpha_fit
# alpha_ZH_LW_Re_fit_M_t80             designid                             e_EW_[NeIII]3967_alpha_fit           e_l_flux_Hd4101_Ha_alpha_fit         e_OH_Cur20_O3S2_alpha_fit
# e_alpha_ZH_LW_Re_fit_M_t80           cenra                                EW_He3970_Re_fit                     l_flux_[FeII]4276_Ha_Re_fit          OH_KK04_Re_fit
# cc_ZH_LW_Re_M_t80                    cendec                               e_EW_He3970_Re_fit                   e_l_flux_[FeII]4276_Ha_Re_fit        e_OH_KK04_Re_fit
# sig_ZH_LW_Re_M_t80                   airmsmin                             EW_He3970_alpha_fit                  l_flux_[FeII]4276_Ha_alpha_fit       OH_KK04_alpha_fit
# ZH_LW_Re_fit_M_t90                   airmsmed                             e_EW_He3970_alpha_fit                e_l_flux_[FeII]4276_Ha_alpha_fit     e_OH_KK04_alpha_fit
# e_ZH_LW_Re_fit_M_t90                 airmsmax                             EW_HeI4026_Re_fit                    l_flux_[FeII]4287_Ha_Re_fit          OH_Pil16_R_Re_fit
# alpha_ZH_LW_Re_fit_M_t90             seemin                               e_EW_HeI4026_Re_fit                  e_l_flux_[FeII]4287_Ha_Re_fit        e_OH_Pil16_R_Re_fit
# e_alpha_ZH_LW_Re_fit_M_t90           seemed                               EW_HeI4026_alpha_fit                 l_flux_[FeII]4287_Ha_alpha_fit       OH_Pil16_R_alpha_fit
# cc_ZH_LW_Re_M_t90                    seemax                               e_EW_HeI4026_alpha_fit               e_l_flux_[FeII]4287_Ha_alpha_fit     e_OH_Pil16_R_alpha_fit
# sig_ZH_LW_Re_M_t90                   transmin                             EW_[SII]4069_Re_fit                  l_flux_[FeII]4319_Ha_Re_fit          OH_Pil16_S_Re_fit
# ZH_LW_Re_fit_t50                     transmed                             e_EW_[SII]4069_Re_fit                e_l_flux_[FeII]4319_Ha_Re_fit        e_OH_Pil16_S_Re_fit
# e_ZH_LW_Re_fit_t50                   transmax                             EW_[SII]4069_alpha_fit               l_flux_[FeII]4319_Ha_alpha_fit       OH_Pil16_S_alpha_fit
# alpha_ZH_LW_Re_fit_t50               mjdmin                               e_EW_[SII]4069_alpha_fit             e_l_flux_[FeII]4319_Ha_alpha_fit     e_OH_Pil16_S_alpha_fit
# e_alpha_ZH_LW_Re_fit_t50             mjdmed                               EW_[SII]4076_Re_fit                  l_flux_Hg4340_Ha_Re_fit              OH_Ho_Re_fit
# cc_ZH_LW_Re_t50                      mjdmax                               e_EW_[SII]4076_Re_fit                e_l_flux_Hg4340_Ha_Re_fit            e_OH_Ho_Re_fit
# sig_ZH_LW_Re_t50                     gfwhm                                EW_[SII]4076_alpha_fit               l_flux_Hg4340_Ha_alpha_fit           OH_Ho_alpha_fit
# ZH_LW_Re_fit_t60                     rfwhm                                e_EW_[SII]4076_alpha_fit             e_l_flux_Hg4340_Ha_alpha_fit         e_OH_Ho_alpha_fit
# e_ZH_LW_Re_fit_t60                   ifwhm                                EW_Hd4101_Re_fit                     l_flux_[OIII]4363_Ha_Re_fit          U_Dors_O32_Re_fit
# alpha_ZH_LW_Re_fit_t60               zfwhm                                e_EW_Hd4101_Re_fit                   e_l_flux_[OIII]4363_Ha_Re_fit        e_U_Dors_O32_Re_fit
# e_alpha_ZH_LW_Re_fit_t60             mngtarg1                             EW_Hd4101_alpha_fit                  l_flux_[OIII]4363_Ha_alpha_fit       U_Dors_O32_alpha_fit
# cc_ZH_LW_Re_t60                      mngtarg2                             e_EW_Hd4101_alpha_fit                e_l_flux_[OIII]4363_Ha_alpha_fit     e_U_Dors_O32_alpha_fit
# sig_ZH_LW_Re_t60                     mngtarg3                             EW_[FeII]4276_Re_fit                 l_flux_[FeII]4413_Ha_Re_fit          U_Dors_S_Re_fit
# ZH_LW_Re_fit_t70                     catidnum                             e_EW_[FeII]4276_Re_fit               e_l_flux_[FeII]4413_Ha_Re_fit        e_U_Dors_S_Re_fit
# ...
# e_OH_R23_Re                          flux_NaI5889.95_Re_fit               EW_[NII]6548_alpha_fit               l_flux_[OII]7325_Ha_alpha_fit        SK_Ha
# OH_pyqz_Re                           e_flux_NaI5889.95_Re_fit             e_EW_[NII]6548_alpha_fit             e_l_flux_[OII]7325_Ha_alpha_fit      e_SK_Ha
# e_OH_pyqz_Re                         flux_NaI5889.95_alpha_fit            EW_HeI6677_Re_fit                    l_flux_[ArIII]7751_Ha_Re_fit         KIN_ssp
# OH_t2_Re                             e_flux_NaI5889.95_alpha_fit          e_EW_HeI6677_Re_fit                  e_l_flux_[ArIII]7751_Ha_Re_fit       e_KIN_ssp
# e_OH_t2_Re                           flux_NaI5895.92_Re_fit               EW_HeI6677_alpha_fit                 l_flux_[ArIII]7751_Ha_alpha_fit      KIN_Ha
# OH_M08_Re                            e_flux_NaI5895.92_Re_fit             e_EW_HeI6677_alpha_fit               e_l_flux_[ArIII]7751_Ha_alpha_fit    e_KIN_Ha
# e_OH_M08_Re                          flux_NaI5895.92_alpha_fit            EW_[SII]6716_Re_fit                  l_flux_[SIII]9068_Ha_Re_fit          ML
# OH_T04_Re                            e_flux_NaI5895.92_alpha_fit          e_EW_[SII]6716_Re_fit                e_l_flux_[SIII]9068_Ha_Re_fit        e_ML
# e_OH_T04_Re                          flux_[OI]6300.3_Re_fit               EW_[SII]6716_alpha_fit               l_flux_[SIII]9068_Ha_alpha_fit       Sigma_SFR_ssp
# OH_dop_Re                            e_flux_[OI]6300.3_Re_fit             e_EW_[SII]6716_alpha_fit             e_l_flux_[SIII]9068_Ha_alpha_fit     e_Sigma_SFR_ssp
# e_OH_dop_Re                          flux_[OI]6300.3_alpha_fit            EW_[SII]6730_Re_fit                  l_flux_[SIII]9530_Ha_Re_fit          Sigma_Mass_gas_rad
# OH_O3N2_EPM09_Re                     e_flux_[OI]6300.3_alpha_fit          e_EW_[SII]6730_Re_fit                e_l_flux_[SIII]9530_Ha_Re_fit        e_Sigma_Mass_gas_rad
# e_OH_O3N2_EPM09_Re                   flux_[NII]6548.05_Re_fit             EW_[SII]6730_alpha_fit               l_flux_[SIII]9530_Ha_alpha_fit       Lambda
# OH_O3N2_ALL                          e_flux_[NII]6548.05_Re_fit           e_EW_[SII]6730_alpha_fit             e_l_flux_[SIII]9530_Ha_alpha_fit     e_Lambda
# e_OH_O3N2_ALL                        flux_[NII]6548.05_alpha_fit          EW_[ArIII]7136_Re_fit                l_flux0_Ha_Re_fit                    OH_ONS
# OH_N2_ALL                            e_flux_[NII]6548.05_alpha_fit        e_EW_[ArIII]7136_Re_fit              e_l_flux0_Ha_Re_fit                  e_OH_ONS
# e_OH_N2_ALL                          flux_Halpha6562.85_Re_fit            EW_[ArIII]7136_alpha_fit             l_flux0_Ha_alpha_fit                 NO_ONS
# OH_ONS_ALL                           e_flux_Halpha6562.85_Re_fit          e_EW_[ArIII]7136_alpha_fit           e_l_flux0_Ha_alpha_fit               e_NO_ONS
# e_OH_ONS_ALL                         flux_Halpha6562.85_alpha_fit         EW_[OII]7325_Re_fit                  l_flux_[OII]3727_Hb_Re_fit           NO_N2S2
# OH_R23_ALL                           e_flux_Halpha6562.85_alpha_fit       e_EW_[OII]7325_Re_fit                e_l_flux_[OII]3727_Hb_Re_fit         e_NO_N2S2
# e_OH_R23_ALL                         flux_[NII]6583.45_Re_fit             EW_[OII]7325_alpha_fit               l_flux_[OII]3727_Hb_alpha_fit        in_Sigma_Mass_stars
# OH_pyqz_ALL                          e_flux_[NII]6583.45_Re_fit           e_EW_[OII]7325_alpha_fit             e_l_flux_[OII]3727_Hb_alpha_fit      in_e_Sigma_Mass_stars
# e_OH_pyqz_ALL                        flux_[NII]6583.45_alpha_fit          EW_[ArIII]7751_Re_fit                l_flux_H123750_Hb_Re_fit             in_Sigma_SFR
# OH_t2_ALL                            e_flux_[NII]6583.45_alpha_fit        e_EW_[ArIII]7751_Re_fit              e_l_flux_H123750_Hb_Re_fit           in_e_Sigma_SFR
# e_OH_t2_ALL                          flux_[SII]6716.44_Re_fit             EW_[ArIII]7751_alpha_fit             l_flux_H123750_Hb_alpha_fit          in_Sigma_Mass_gas
# OH_M08_ALL                           e_flux_[SII]6716.44_Re_fit           e_EW_[ArIII]7751_alpha_fit           e_l_flux_H123750_Hb_alpha_fit        in_e_Sigma_Mass_gas
# e_OH_M08_ALL                         flux_[SII]6716.44_alpha_fit          EW_[SIII]9068_Re_fit                 l_flux_H113771_Hb_Re_fit             in_Sigma_Mass_gas_ssp
# OH_T04_ALL                           e_flux_[SII]6716.44_alpha_fit        e_EW_[SIII]9068_Re_fit               e_l_flux_H113771_Hb_Re_fit           in_e_Sigma_Mass_gas_ssp
# e_OH_T04_ALL                         flux_[SII]6730.82_Re_fit             EW_[SIII]9068_alpha_fit              l_flux_H113771_Hb_alpha_fit          in_ZH_LW
# OH_dop_ALL                           e_flux_[SII]6730.82_Re_fit           e_EW_[SIII]9068_alpha_fit            e_l_flux_H113771_Hb_alpha_fit        in_e_ZH_LW
# e_OH_dop_ALL                         flux_[SII]6730.82_alpha_fit          EW_[SIII]9530_Re_fit                 l_flux_H103798_Hb_Re_fit             in_ZH_MW
# OH_O3N2_EPM09_ALL                    e_flux_[SII]6730.82_alpha_fit        e_EW_[SIII]9530_Re_fit               e_l_flux_H103798_Hb_Re_fit           in_e_ZH_MW
# e_OH_O3N2_EPM09_ALL                  flux_[ArIII]7135.8_Re_fit            EW_[SIII]9530_alpha_fit              l_flux_H103798_Hb_alpha_fit          in_Age_LW
# Sigma_Mass_cen                       e_flux_[ArIII]7135.8_Re_fit          e_EW_[SIII]9530_alpha_fit            e_l_flux_H103798_Hb_alpha_fit        in_e_Age_LW
# e_Sigma_Mass_cen                     flux_[ArIII]7135.8_alpha_fit         EW0_Re_fit                           l_flux_HeI3819_Hb_Re_fit             in_Age_MW
# Sigma_Mass_Re                        e_flux_[ArIII]7135.8_alpha_fit       e_EW0_Re_fit                         e_l_flux_HeI3819_Hb_Re_fit           in_e_Age_MW
# e_Sigma_Mass_Re                      flux_HI9014.91_Re_fit                EW0_alpha_fit                        l_flux_HeI3819_Hb_alpha_fit          in_OH_t2
# Sigma_Mass_ALL                       e_flux_HI9014.91_Re_fit              e_EW0_alpha_fit                      e_l_flux_HeI3819_Hb_alpha_fit        in_e_OH_t2
# e_Sigma_Mass_ALL                     flux_HI9014.91_alpha_fit             disp_[OII]3727_Re_fit                l_flux_H93835_Hb_Re_fit              in_OH_O3N2
# OH_Re_fit_ON                         e_flux_HI9014.91_alpha_fit           e_disp_[OII]3727_Re_fit              e_l_flux_H93835_Hb_Re_fit            in_e_OH_O3N2
# e_OH_Re_fit_ON                       flux_[SIII]9069.0_Re_fit             disp_[OII]3727_alpha_fit             l_flux_H93835_Hb_alpha_fit           in_Av_gas
# alpha_OH_Re_fit_ON                   e_flux_[SIII]9069.0_Re_fit           e_disp_[OII]3727_alpha_fit           e_l_flux_H93835_Hb_alpha_fit         in_e_Av_gas
# e_alpha_OH_Re_fit_ON                 flux_[SIII]9069.0_alpha_fit          disp_H123750_Re_fit                  l_flux_[NeIII]3869_Hb_Re_fit         in_Av_ssp
# cc_r_OH_ON                           e_flux_[SIII]9069.0_alpha_fit        e_disp_H123750_Re_fit                e_l_flux_[NeIII]3869_Hb_Re_fit       in_e_Av_ssp
# sig_r_OH_ON                          flux_[FeII]9470.93_Re_fit            disp_H123750_alpha_fit               l_flux_[NeIII]3869_Hb_alpha_fit      in_disp_ssp
# OH_ON_Re                             e_flux_[FeII]9470.93_Re_fit          e_disp_H123750_alpha_fit             e_l_flux_[NeIII]3869_Hb_alpha_fit    in_e_disp_ssp
# e_OH_ON_Re                           flux_[FeII]9470.93_alpha_fit         disp_H113771_Re_fit                  l_flux_H83889_Hb_Re_fit              in_disp_Ha
# OH_ON_cen                            e_flux_[FeII]9470.93_alpha_fit       e_disp_H113771_Re_fit                e_l_flux_H83889_Hb_Re_fit            in_e_disp_Ha
# e_OH_ON_cen                          flux_[SIII]9531.1_Re_fit             disp_H113771_alpha_fit               l_flux_H83889_Hb_alpha_fit           in_vel_Ha
# OH_ON_ALL                            e_flux_[SIII]9531.1_Re_fit           e_disp_H113771_alpha_fit             e_l_flux_H83889_Hb_alpha_fit         in_e_vel_Ha
# e_OH_ON_ALL                          flux_[SIII]9531.1_alpha_fit          disp_H103798_Re_fit                  l_flux_[NeIII]3967_Hb_Re_fit         in_vel_ssp
# T30                                  e_flux_[SIII]9531.1_alpha_fit        e_disp_H103798_Re_fit                e_l_flux_[NeIII]3967_Hb_Re_fit       in_e_vel_ssp
# ZH_T30                               nsa_redshift                         disp_H103798_alpha_fit               l_flux_[NeIII]3967_Hb_alpha_fit      in_SK_ssp
# ZH_Re_T30                            nsa_u_absmag                         e_disp_H103798_alpha_fit             e_l_flux_[NeIII]3967_Hb_alpha_fit    in_e_SK_ssp
# a_ZH_T30                             nsa_z_absmag                         disp_HeI3819_Re_fit                  l_flux_He3970_Hb_Re_fit              in_SK_Ha
# T40                                  nsa_u_z_absmag                       e_disp_HeI3819_Re_fit                e_l_flux_He3970_Hb_Re_fit            in_e_SK_Ha
# ZH_T40                               nsa_mstar                            disp_HeI3819_alpha_fit               l_flux_He3970_Hb_alpha_fit           in_KIN_ssp
# ZH_Re_T40                            nsa_inclination                      e_disp_HeI3819_alpha_fit             e_l_flux_He3970_Hb_alpha_fit         in_e_KIN_ssp
# a_ZH_T40                             flux_[OII]3727_Re_fit                disp_H93835_Re_fit                   l_flux_HeI4026_Hb_Re_fit             in_KIN_Ha
# T501                                 e_flux_[OII]3727_Re_fit              e_disp_H93835_Re_fit                 e_l_flux_HeI4026_Hb_Re_fit           in_e_KIN_Ha
# ZH_T50                               flux_[OII]3727_alpha_fit             disp_H93835_alpha_fit                l_flux_HeI4026_Hb_alpha_fit          in_ML
# ZH_Re_T50                            e_flux_[OII]3727_alpha_fit           e_disp_H93835_alpha_fit              e_l_flux_HeI4026_Hb_alpha_fit        in_e_ML
# a_ZH_T50                             flux_H123750_Re_fit                  disp_[NeIII]3869_Re_fit              l_flux_[SII]4069_Hb_Re_fit           in_Sigma_SFR_ssp
# T60                                  e_flux_H123750_Re_fit                e_disp_[NeIII]3869_Re_fit            e_l_flux_[SII]4069_Hb_Re_fit         in_e_Sigma_SFR_ssp
# ZH_T60                               flux_H123750_alpha_fit               disp_[NeIII]3869_alpha_fit           l_flux_[SII]4069_Hb_alpha_fit        in_Sigma_Mass_gas_rad
# ZH_Re_T60                            e_flux_H123750_alpha_fit             e_disp_[NeIII]3869_alpha_fit         e_l_flux_[SII]4069_Hb_alpha_fit      in_e_Sigma_Mass_gas_rad
# a_ZH_T60                             flux_H113771_Re_fit                  disp_H83889_Re_fit                   l_flux_[SII]4076_Hb_Re_fit           in_Lambda
# T70                                  e_flux_H113771_Re_fit                e_disp_H83889_Re_fit                 e_l_flux_[SII]4076_Hb_Re_fit         in_e_Lambda
# ZH_T70                               flux_H113771_alpha_fit               disp_H83889_alpha_fit                l_flux_[SII]4076_Hb_alpha_fit        in_OH_ONS
# ZH_Re_T70                            e_flux_H113771_alpha_fit             e_disp_H83889_alpha_fit              e_l_flux_[SII]4076_Hb_alpha_fit      in_e_OH_ONS
# a_ZH_T70                             flux_H103798_Re_fit                  disp_[NeIII]3967_Re_fit              l_flux_Hd4101_Hb_Re_fit              in_NO_ONS
# T801                                 e_flux_H103798_Re_fit                e_disp_[NeIII]3967_Re_fit            e_l_flux_Hd4101_Hb_Re_fit            in_e_NO_ONS
# ZH_T80                               flux_H103798_alpha_fit               disp_[NeIII]3967_alpha_fit           l_flux_Hd4101_Hb_alpha_fit           in_NO_N2S2
# ZH_Re_T80                            e_flux_H103798_alpha_fit             e_disp_[NeIII]3967_alpha_fit         e_l_flux_Hd4101_Hb_alpha_fit         in_e_NO_N2S2
# a_ZH_T80                             flux_HeI3819_Re_fit                  disp_He3970_Re_fit                   l_flux_[FeII]4276_Hb_Re_fit          plate_2
# T90                                  e_flux_HeI3819_Re_fit                e_disp_He3970_Re_fit                 e_l_flux_[FeII]4276_Hb_Re_fit        ifudsgn_2
# ZH_T90                               flux_HeI3819_alpha_fit               disp_He3970_alpha_fit                l_flux_[FeII]4276_Hb_alpha_fit       plateifu_2
# ZH_Re_T90                            e_flux_HeI3819_alpha_fit             e_disp_He3970_alpha_fit              e_l_flux_[FeII]4276_Hb_alpha_fit     mangaid_2
# a_ZH_T90                             flux_H93835_Re_fit                   disp_HeI4026_Re_fit                  l_flux_[FeII]4287_Hb_Re_fit          nsa_nsaid_2
# T95                                  e_flux_H93835_Re_fit                 e_disp_HeI4026_Re_fit                e_l_flux_[FeII]4287_Hb_Re_fit        nsaid
# ZH_T95                               flux_H93835_alpha_fit                disp_HeI4026_alpha_fit               l_flux_[FeII]4287_Hb_alpha_fit       logMs_nsa
# ZH_Re_T95                            e_flux_H93835_alpha_fit              e_disp_HeI4026_alpha_fit             e_l_flux_[FeII]4287_Hb_alpha_fit     z_obs_nsa
# a_ZH_T95                             flux_[NeIII]3869_Re_fit              disp_[SII]4069_Re_fit                l_flux_[FeII]4319_Hb_Re_fit          Vmax_w
# T99                                  e_flux_[NeIII]3869_Re_fit            e_disp_[SII]4069_Re_fit              e_l_flux_[FeII]4319_Hb_Re_fit        Num_w
# ZH_T99                               flux_[NeIII]3869_alpha_fit           disp_[SII]4069_alpha_fit             l_flux_[FeII]4319_Hb_alpha_fit
# ZH_Re_T99                            e_flux_[NeIII]3869_alpha_fit         e_disp_[SII]4069_alpha_fit           e_l_flux_[FeII]4319_Hb_alpha_fit

# %%
print(len(tab_all.columns))
# Out:
# 2378

# %%
#
# Defining some new variables
#
tab_all['Fe']=np.sqrt(tab_all['Fe5270']*tab_all['Fe5335'])
tab_all['OZ_Ho']=tab_all['OH_Ho_Re_fit']-8.67-tab_all['ZH_LW_Re']
tab_all['Mg_Fe']=np.log10(tab_all['Mgb']/tab_all['Fe'])
tab_all['FUV-z']=tab_all['nsa_elpetro_absmag'][:,0]-tab_all['nsa_elpetro_absmag'][:,6]
tab_all['z abs']=tab_all['nsa_elpetro_absmag'][:,6]
tab_all['NUV-z']=tab_all['nsa_elpetro_absmag'][:,1]-tab_all['nsa_elpetro_absmag'][:,6]
tab_all['u-z']=tab_all['nsa_elpetro_absmag'][:,2]-tab_all['nsa_elpetro_absmag'][:,6]
tab_all['u-i nsa']=tab_all['nsa_elpetro_absmag'][:,2]-tab_all['nsa_elpetro_absmag'][:,5]
tab_all['FUV-i']=tab_all['nsa_elpetro_absmag'][:,0]-tab_all['nsa_elpetro_absmag'][:,5]
tab_all['i_abs']=tab_all['nsa_elpetro_absmag'][:,5]
print(tab_all['nsa_elpetro_absmag'][0])
#print(tab_all['nsa_elpetro_absmag'][:,0])
#tab_all.rename_column('z_abs','z abs')
print(np.nanmean(tab_all['z abs']))
# Out:
# [-16.2321 -16.7716 -17.9054 -18.7874 -19.2112 -19.3438 -19.5522]
# -20.592398188357635

# %%
def my_contour(ax,x_cont,y_cont,x_min,x_max,y_min,y_max,c_color='red', title='', nbins=30, zorder=1, linewidths=2,alpha=0.75):
    N_min=2
    Delta=0.3
#    nbins=30
    mask_cont = (x_cont>x_min) & (x_cont<x_max) & (y_cont>y_min) & (y_cont<y_max)  
    x_plt, y_plt = x_cont[mask_cont], y_cont[mask_cont]
    counts, xbins, ybins = np.histogram2d(x_plt, y_plt, bins=nbins,
        normed=True,range=[[x_min,x_max],[y_min,y_max]])
    counts=ndimage.gaussian_filter(counts, sigma=1, order=0)
    counts /= counts.max()
    sum_total=counts.sum()
    vals=[]
    levels=[]
    for idx,cuts in enumerate(np.arange(0.00,1.0,0.01)):
        mask_now= counts>cuts
        levels.append(cuts)
        vals.append(counts[mask_now].sum()/sum_total)
    vals_cont=np.array([0.95,0.65,0.40])
    levels_cont=np.interp(vals_cont,np.array(levels),np.array(vals))
    counts_rot=np.rot90(counts,3)
    xbins=xbins+0.5*(x_max-x_min)/nbins
    ybins=ybins+0.5*(y_max-y_min)/nbins
    flip_counts_rot=np.fliplr(counts_rot)
    p_cont=ax.contour(xbins[0:nbins],ybins[0:nbins],flip_counts_rot,levels_cont,\
                      colors=c_color,alpha=alpha,linewidths=linewidths,zorder=zorder)
#    labels = ['Div Neg', 'Div Pos', 'Rot Neg', 'Rot Pos']
    if (len(title)>0):
        p_cont.collections[0].set_label(title)
    #    h_cont,l_cont = p_cont.legend_elements(title)
#    ax.legend(h_cont, l_cont)

def biweight_midvariance(par):
    val=np.nanstd(par)/np.sqrt(2)
    return val

def my_scatter(ax,x_par,y_par,c_par,x_cont,y_cont,x_min,x_max,y_min,y_max,c_min,c_max,x_label,y_label,xf_min=0.0,yf_min=0.0,den_par_min=0.85,bin_size=0.3,bin_number=2,c_color="black",c_color2="darksalmon",error=0.05,MC=10, Delta=0.15):
    cm = califa_vel_r
    if (xf_min==0.0):
        xf_min=x_min
    if (yf_min==0.0):
        yf_min=y_min
#    MC=5
#    error=0.05
    N_min=2
#    Delta=0.15
#    den_par_min=0.9
    nbins=30
    lEW_cut=0.78 #0.78
    n_obj_org=len(x_par)
#    print("# N.OBJ = ",n_obj_org)
#    mask = (x_par>x_min) & (x_par<x_max) & (y_par>y_min) & (y_par<y_max)  
    mask = x_par>-20
    n_obj=len(x_par[mask])
#    print(x_par[~mask])
#    print("# N.Obj = ",n_obj,x_min,x_max,y_min,y_max)
    mask_SFGs = mask & (c_par>lEW_cut)
    mask_cont = (x_cont>x_min) & (x_cont<x_max) & (y_cont>y_min) & (y_cont<y_max)  
#
# Density to plot!
#
    x_plt, y_plt = x_cont[mask_cont], y_cont[mask_cont]
#    nbins=40
    counts, xbins, ybins = np.histogram2d(x_plt, y_plt, bins=nbins,
        normed=True,range=[[x_min,x_max],[y_min,y_max]])
#        range=[[np.nanmin(x_plt),np.nanmax(x_plt)],[np.nanmin(y_plt),np.nanmax(y_plt)]])
                                            #    counts /= counts.max()

    counts=ndimage.gaussian_filter(counts, sigma=1, order=0)
    counts /= counts.max()
    sum_total=counts.sum()
    vals=[]
    levels=[]
    for idx,cuts in enumerate(np.arange(0.00,1.0,0.01)):
        mask_now= counts>cuts
        levels.append(cuts)
        vals.append(counts[mask_now].sum()/sum_total)
        #print(idx,levels[idx],vals[idx])
    vals_cont=np.array([0.95,0.80,0.40])
    levels_cont=np.interp(vals_cont,np.array(levels),np.array(vals))
    figure=ax.scatter(x_par, y_par, c=c_par, vmin=c_min,vmax=c_max,alpha=0.4,edgecolor='none',\
                      rasterized=True,cmap=cm)
    counts_rot=np.rot90(counts,3)
    xbins=xbins+0.5*(x_max-x_min)/nbins
    ybins=ybins+0.5*(y_max-y_min)/nbins
    flip_counts_rot=np.fliplr(counts_rot)
    p_cont=ax.contour(xbins[0:nbins],ybins[0:nbins],flip_counts_rot,levels_cont,colors=c_color)

    #
    # Density near a point
    #
    x_plt, y_plt = x_par[mask_SFGs], y_par[mask_SFGs]
    n_sf=len(x_par[mask_SFGs])
    #    nbins=40
    counts, xbins, ybins = np.histogram2d(x_plt, y_plt, bins=nbins,
        normed=True,
        range=[[np.nanmin(x_plt),np.nanmax(x_plt)],[np.nanmin(y_plt),np.nanmax(y_plt)]])
                                            #    counts /= counts.max()
#    print(xbins,ybins)
    counts=ndimage.gaussian_filter(counts, sigma=1, order=0)
    counts /= counts.max()
    sum_total=counts.sum()
    vals_new=[]
    levels_new=[]
    for idx,cuts in enumerate(np.arange(0.00,1.0,0.01)):
        mask_now= counts>cuts
        levels_new.append(cuts)
        vals_new.append(counts[mask_now].sum()/sum_total)
        #print(idx,levels[idx],vals[idx])
    vals_cont=np.array([0.95,0.80,0.40])
    levels_cont=np.interp(vals_cont,np.array(levels_new),np.array(vals))
    
#    figure=ax.scatter(x_par, y_par, c=c_par, vmin=c_min,vmax=c_max,alpha=0.4,edgecolor='none',cmap=cm)
    counts_rot=np.rot90(counts,3)
    xbins=xbins+0.5*(x_max-x_min)/nbins
    ybins=ybins+0.5*(y_max-y_min)/nbins
    flip_counts_rot=np.fliplr(counts_rot)
    
  
    den_par=np.zeros(len(x_par))
    for i in range(len(x_par)):
        if ((np.isfinite(x_par[i])) and (np.isfinite(y_par[i]))):
            i_x=np.argmin(np.abs(xbins-x_par[i]))
            i_y=np.argmin(np.abs(ybins-y_par[i]))
            if ((i_x>0) and (i_x<nbins) and (i_y>0) and (i_y<nbins)):
                den_par[i]=np.interp(counts[i_x,i_y],np.array(levels_new),np.array(vals_new))

# Density plot!
#    figure=ax.scatter(x_par, y_par, c=den_par, vmin=0,vmax=1,alpha=0.4,edgecolor='none',cmap=cm)
    p_cont2=ax.contour(xbins[0:nbins],ybins[0:nbins],flip_counts_rot,levels_cont,colors=c_color2)
#
# We mask low density points
#
#    print("# den_par_min=",den_par_min)
    mask_SFGs = mask_SFGs & (den_par<den_par_min) & \
    np.logical_not(np.isnan(x_par)) & np.isfinite(x_par) & \
    np.logical_not(np.isnan(y_par)) & np.isfinite(y_par)  

    x_sf=x_par[mask_SFGs]
    y_sf=y_par[mask_SFGs]
    
#    figure=ax.scatter(x_par, y_par, c=den_par, vmin=0,vmax=1,alpha=0.4,edgecolor='none',cmap=cm)
    
    bin1 , min1 , max1= Delta,x_min,x_max
    m1, sM1, sD1 = binning_M(x_sf, y_sf, bin1 , min1 , max1, N_min, bin_size, bin_number )
    p1 = ax.errorbar(m1, sM1, yerr= sD1, markersize = 9, markerfacecolor =c_color2, markeredgecolor = 'black', fmt = 'o', ecolor='black', elinewidth = 1, label = '', zorder=2, alpha=0.7)


#    x_sf=x_par[mask_SFGs]
#    y_sf=y_par[mask_SFGs]
    bin1 , min1 , max1= Delta,xf_min,x_max
    funct    = lambda x,a,b: a + b * x
    START=[-1,1.0]
    pa1=np.zeros(2)
    ea1=np.zeros(2)
#    print('#vals to fit =',m1,sM1,sD1)
    if m1.size > 2:
        m1, sM1, sD1 = binning_M(x_sf, y_sf, bin1 , min1 , max1, N_min, 0.3,2 )
        mean_sD1=np.nanmean(sD1)
        sD1=sD1+mean_sD1
        np.clip(sD1,0.5*mean_sD1,1.5*mean_sD1)
        pa1, ea1  = optimize.curve_fit(funct, m1, sM1, sigma=np.sqrt(sD1), p0 = START )
        a_pa=np.zeros((MC,2))
        a_ea=np.zeros((MC,2,2))
        a_rc=np.zeros((MC,2,2))
        for iMC in range(MC):
            e_x_sf=np.abs(2*error-error*(x_sf-x_min)/(x_max-x_min))
            e_y_sf=np.abs(2*error-error*(y_sf-y_min)/(y_max-y_min))
            
#            print('e_y=',e_y_sf,len(e_y_sf))
#            print('e-x=',e_x_sf,len(e_x_sf))
            x_sf_now=x_sf+np.random.normal(loc=0.0,scale=e_x_sf,size=len(e_x_sf))
            y_sf_now=y_sf+np.random.normal(loc=0.0,scale=e_y_sf,size=len(e_y_sf))
            mNOW, sMNOW, sDNOW = binning_M(x_sf_now, y_sf_now, bin1 , min1 , max1, N_min, 0.3,2 )
            rcNOW=np.corrcoef(x_sf_now, y_sf_now)
            #for i in range(len(sDNOW)):
            #    i_x=np.argmin(np.abs(xbins-mNOW[i]))
            #    i_y=np.argmin(np.abs(ybins-sMNOW[i]))
            #    if ((i_x>0) and (i_x<nbins) and (i_y>0) and (i_y<nbins)):
            #        sDNOW[i]=0.5*sDNOW[i]+\
            #        0.1*np.interp(counts[i_x,i_y],np.array(levels_new),np.array(vals_new))
#                    if (iMC==0):
#                        print(mNOW[i],sDNOW[i])
            sDNOW=0.001/sDNOW
    
#            np.clip(sDNOW,0.05,0.2)
            paNOW, eaNOW  = optimize.curve_fit(funct, mNOW, sMNOW, sigma=np.sqrt(sDNOW), p0 = START )
#            print('Coeffs lin fit: ',round(paNOW[0],3),round(np.sqrt(np.diag(eaNOW))[0],3),round(paNOW[1],3),round(np.sqrt(np.diag(eaNOW))[1],3),round(rcNOW[0,1],3))    
            a_pa[iMC,:]=paNOW
            a_ea[iMC,:,:]=eaNOW
            a_rc[iMC,:,:]=rcNOW
#        print(pa1,ea1)
#        test=np.mean(a_pa,axis=(0,1))
#        print(test)
        np.mean(a_pa, axis=(0), out=pa1)
        np.mean(a_ea, axis=(0), out=ea1)
        e_pa1=np.std(a_pa, axis=(0))
        rc=np.mean(a_rc, axis=(0))
        ea1[0,0]=ea1[0,0]+e_pa1[0]
        ea1[1,1]=ea1[1,1]+e_pa1[1]
        
        
        #        pa1=a_pa.mean(axis=(1,2))
#        ea1=a_ea.mean(axis=(1,2))
#        ea1=np.mean(a_ea,axis=2)
        
#        pa1, ea1  = optimize.curve_fit(funct, m1, sM1, sigma=sD1, p0 = START )
#round(pa1[0],3),round(np.sqrt(np.diag(ea1))[0],3),round(pa1[1],3),round(np.sqrt(np.diag(ea1))[1],3),round(rc[0,1],3)

        if (xf_min!=x_min):
            yl_plot=np.linspace(y_min,y_max,10)
            xl_plot=xf_min+0.0*yl_plot
            rect=patches.Rectangle((x_min, y_min), xf_min-x_min, y_max-y_min, facecolor="black", alpha=0.2,zorder=3)
            ax.add_patch(rect)
        x_plot=np.linspace(np.min(m1)-1.5*bin1, np.max(m1)+1.5*bin1, 10)
        y_plot=funct(x_plot,pa1[0],pa1[1])
        p_fit=ax.plot(x_plot, y_plot, '-.', linewidth = 3, markerfacecolor ='black'  , color ='black', zorder=3,label='This work')
#        p_fit=ax.plot(xl_plot, yl_plot, '-', linewidth = 2, markerfacecolor ='grey'  , color ='grey', zorder=2)        
#        print("PASO")

    mask_SFGs = mask_SFGs & (den_par<0.85) & \
    np.logical_not(np.isnan(x_par)) & np.isfinite(x_par) & \
    np.logical_not(np.isnan(y_par)) & np.isfinite(y_par)  

    x_sf=x_par[mask_SFGs]
    y_sf=y_par[mask_SFGs]

    mask_x_sf=x_sf>xf_min
    x_sf=x_sf[mask_x_sf]
    y_sf=y_sf[mask_x_sf]
    rc=np.corrcoef(x_sf, y_sf)
    delta_y_par=y_sf-(pa1[0]+pa1[1]*x_sf)
    s_y_par = biweight_midvariance(y_sf[np.isfinite(y_sf)])
    s_dy_par = biweight_midvariance(delta_y_par[np.isfinite(delta_y_par)])

#    s_y_par = np.std(y_sf[np.isfinite(y_sf)])
#    s_dy_par = np.std(delta_y_par[np.isfinite(delta_y_par)])

    print('Mean Coeff.: ',round(pa1[0],3),round(np.sqrt(np.diag(ea1))[0],3),round(pa1[1],3),round(np.sqrt(np.diag(ea1))[1],3),round(rc[0,1],3),round(s_y_par,3),round(s_dy_par,3),n_obj,n_sf)
    #    print('Stddev: ',round(s_y_par,3),round(s_dy_par,3))
        
    ax.set_xlim([x_min,x_max])
    ax.set_ylim([y_min,y_max])    
    ax.set_xlabel(x_label)
    ax.set_ylabel(y_label)
    ax.minorticks_on()
    ax.xaxis.set_ticks_position('both')
    ax.yaxis.set_ticks_position('both')
    ax.tick_params(which='both',direction="in")
    ax.spines['right'].set_visible(False)
    ax.spines['top'].set_visible(False)
    ax.yaxis.set_ticks_position('left')
    ax.xaxis.set_ticks_position('bottom')

    return pa1,ea1,s_y_par,s_dy_par,rc

def my_hist(ax,x_par,y_par,x_min,x_max,c_x,c_y,x_label,y_label):
    mask_x = (x_par > x_min) & (x_par < x_max) 
    mask_y = (y_par > x_min) & (y_par < x_max) 
    p1=sns.distplot(x_par[mask_x],bins=40,ax=ax,hist=False,color=c_x)
    p2=sns.distplot(y_par[mask_y],bins=40,ax=ax,hist=False,color=c_y)
    ax.set_xlim([x_min,x_max])
    ax.set_xlabel(x_label)
    ax.set_ylabel(y_label)
    return p1,p2

#

# %%
#
# Mass Luminosity Function
#
#logMs_nsa    Num_w        
#ifudsgn      nsa_nsaid    z_obs_nsa    name         
#plateifu     nsaid        Vmax_w            


x_min=7
x_max=12.5
x_par=tab_all['log_Mass'][tab_all['best type_n']>3]
x_w=tab_all['Vmax_w'][tab_all['best type_n']>3]#*len(tab_vol)#[tab_all['Vmax_w']>0]
#x_w=x_w.filled(0)
print(np.mean(x_w))
#print(x_w)
c_main='black'
alpha=1.0
n_bins=50
xx = np.linspace(x_min, x_max,n_bins)
kde_xx=stats.gaussian_kde(x_par,weights=x_w)
kde_xx.set_bandwidth(bw_method=kde_xx.factor/3)
max_kde_xx=np.max(kde_xx(xx))
yy=kde_xx(xx)/(2*np.sqrt(np.pi))#/n_bins

hy=np.histogram(x_par,bins=xx,weights=x_w)
hy=np.array(hy)
hy[0]=hy[0]*(n_bins-1)
hx=np.zeros(len(xx)-1)
for indx in range(0,len(hx),1):
    hx[indx]=0.5*(xx[indx]+xx[indx+1])
plt.plot(xx-0.25,log10(yy),color='blue',linewidth=3,alpha=alpha)
plt.plot(hx-0.25,np.log10(hy[0]),color=c_main,linewidth=3,alpha=alpha)
plt.ylim(-6,0)
plt.xlim(7.8,12.2)



#    ax_histx.set_ylim(0,1.1*np.max(kde_xx(xx)))   
#print(np.median(hy[0]))
#print(np.median(yy))
#a=np.median(yy)/np.median(hy[0])
#print(a)
# Out:
# 8.699223698746299e-06
# (7.8, 12.2)

# %%
def plot_2Dhist(x_par=tab_all['z abs'],y_par=tab_all['u-z'],z_par=tab_all['best type_n'],\
                x_min=-25,x_max=-16,y_min=0,y_max=4.5,z_min=-2,z_max=10,c_main='grey',label='MPL-11',\
                x_label='NSA z-band abs mag',y_label='u-z mag',figname='CMD_diag',alpha=0.75,\
                   size_scatter=5.0,n_zbins=11,labels_zbins=None,color_cm_now='coolwarm_r',z_lim=80,\
               x_loc=0.02,y_loc=0.03,z_label='',reverse=0, xscale='linear', yscale='linear'):

    fig = plt.figure(figsize=(9,7))
    left, width = 0.1, 0.75
    bottom, height = 0.1, 0.75
    spacing = 0.00
    rect_scatter = [left, bottom, width, height]
    rect_histx = [left, bottom + height + spacing, width, 1-(bottom+height)]
    rect_histy = [left + width + spacing, bottom, 1-(left+width), height]
    ax = fig.add_axes(rect_scatter)
    ax_histx = fig.add_axes(rect_histx, sharex=ax)
    ax_histy = fig.add_axes(rect_histy, sharey=ax)
    if (color_cm_now is None):
        color_cm_now = vel_map()
        if (reverse==1):
            color_cm_now=color_cm_now.reversed()
    colormap=cm.get_cmap(color_cm_now)


#    colormap = plt.cm(color_cm_now)
    ax.scatter(x_par, y_par, s=size_scatter*3, c=z_par,\
               vmin=z_min,vmax=z_max,alpha=alpha,edgecolor='none',cmap=color_cm_now,\
               rasterized=True,label=label)
    my_contour(ax,x_par,y_par,x_min,x_max,y_min,y_max,c_color=c_main,\
               nbins=50,title=label,linewidths=3,alpha=alpha)
#
# X-histogram 
#
    
    
    xx = np.linspace(x_min, x_max, 1000)
    kde_xx=stats.gaussian_kde(x_par)
    kde_xx.set_bandwidth(bw_method=kde_xx.factor / 5.)
    max_kde_xx=np.max(kde_xx(xx))
    
    delta_z=(z_max-z_min)/n_zbins
    Ncolors = min(colormap.N,n_zbins)
    mapcolors = [colormap(int(x*colormap.N/Ncolors)) for x in range(Ncolors)]
    if (labels_zbins==None):
        labels_zbins=np.zeros(n_zbins)
    for indx,z_bins in enumerate(np.linspace(z_min,z_max,n_zbins)):
        z_bin_min = z_bins-0.5*delta_z
        z_bin_max = z_bins+0.5*delta_z
        if (labels_zbins[indx]==0):
            labels_zbins[indx]=z_bins
        xx = np.linspace(x_min, x_max, 1000)
        mask_z_par = (z_par>z_bin_min) & (z_par<=z_bin_max)
        if (len(x_par[mask_z_par])>0):
            kde=stats.gaussian_kde(x_par[mask_z_par])
            kde.set_bandwidth(bw_method=kde.factor / 1.)
            if(len(x_par[mask_z_par])>z_lim):
                ax_histx.plot(xx,max_kde_xx*(kde(xx)/np.max(kde(xx))),\
                              color=mapcolors[indx],linewidth=3,alpha=alpha,\
                              label=labels_zbins[indx])
    ax_histx.plot(xx,kde_xx(xx),color=c_main,linewidth=3,alpha=alpha)
    ax_histx.set_ylim(0,1.1*np.max(kde_xx(xx)))    
#
# Y-histogram 
#

    yy = np.linspace(y_min, y_max, 1000)
    kde_yy=stats.gaussian_kde(y_par)
    kde_yy.set_bandwidth(bw_method=kde_yy.factor / 2.)
    max_kde_yy=np.max(kde_yy(yy))
    for indx,z_bins in enumerate(np.linspace(z_min,z_max,n_zbins)):
        z_bin_min = z_bins-0.5*delta_z
        z_bin_max = z_bins+0.5*delta_z
        if (labels_zbins[indx]==0):
            labels_zbins[indx]=z_bins
        mask_z_par = (z_par>z_bin_min) & (z_par<=z_bin_max)
        #print(z_bins,len(x_par[mask_z_par]))
        if (len(y_par[mask_z_par])>0):
            kde=stats.gaussian_kde(y_par[mask_z_par])
            kde.set_bandwidth(bw_method=kde.factor / 1.)
            if(len(y_par[mask_z_par])>z_lim):
                ax_histy.plot(max_kde_yy*(kde(yy)/np.max(kde(yy))),yy,\
                              color=mapcolors[indx],linewidth=3,alpha=alpha,\
                              label=labels_zbins[indx])
    
    
    ax_histy.plot(kde_yy(yy),yy,color=c_main,linewidth=3,alpha=alpha)
    ax_histy.set_xlim(0,1.1*np.max(kde_yy(yy)))

    ax_histx.spines['right'].set_visible(False)
    ax_histx.spines['top'].set_visible(False)
    ax_histx.spines['bottom'].set_visible(False)
    ax_histx.spines['left'].set_visible(False)
    ax_histx.get_xaxis().set_visible(False)
    ax_histx.get_yaxis().set_visible(False)

    ax_histy.spines['right'].set_visible(False)
    ax_histy.spines['top'].set_visible(False)
    ax_histy.spines['bottom'].set_visible(False)
    ax_histy.spines['left'].set_visible(False)
    ax_histy.get_xaxis().set_visible(False)
    ax_histy.get_yaxis().set_visible(False)

    ax.set_xlabel(x_label, fontsize=23)
    ax.set_ylabel(y_label, fontsize=23)

    ax.set_xlim(x_min,x_max)
    ax.set_ylim(y_min,y_max)

    handles, labels = ax_histx.get_legend_handles_labels()
    ax.legend(handles, labels,loc=(x_loc,y_loc),frameon=True,\
              handlelength=1.5,ncol=3,columnspacing=0.15,title=z_label)
    ax.set_xscale(xscale)
    ax.set_yscale(yscale)
    fig.tight_layout()
    fig.savefig(figname+".pdf", transparent=False, facecolor='white', edgecolor='white')#.pdf")

morph_list=[]
for key, value in morph.items():
    temp = value
    morph_list.append(temp)
    
plot_2Dhist(x_par=tab_all['z abs'],y_par=tab_all['u-z'],z_par=tab_all['best type_n'],\
            x_min=-25,x_max=-16,y_min=-0.25,y_max=4.5,z_min=-2,z_max=10,c_main='black',label='MPL-11',\
            x_label='NSA z-band abs mag',y_label='u-z mag',figname='CMD_diag',alpha=0.85,\
            size_scatter=5.0,n_zbins=13,z_lim=80,labels_zbins=morph_list,color_cm_now=None,\
            reverse=1)#'Spectral_r')

# %%
mask = tab_all['z_stars']
x_par=tab_all['z abs'][mask]
y_par=tab_all['u-z'][mask]
z_par=tab_all['nsa_sersic_n_morph'][mask]
plot_2Dhist(x_par=x_par,y_par=y_par,z_par=z_par,\
            x_min=-25,x_max=-16,y_min=-0.25,y_max=4.5,z_min=0,z_max=6,c_main='black',label='MPL-11',\
            x_label='NSA z-band abs mag',y_label='u-z mag',figname='CMD_nSersic',alpha=0.85,\
            size_scatter=5.0,n_zbins=7,z_lim=80,labels_zbins=None,color_cm_now=None,\
           z_label=r'n$_{\rm sersic}$')#'Spectral_r')
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-24-ce5ce6d60df7> in <module>
#       1 mask = tab_all['z_stars']
# ----> 2 x_par=tab_all['z abs'][mask]
#       3 y_par=tab_all['u-z'][mask]
#       4 z_par=tab_all['nsa_sersic_n_morph'][mask]
#       5 plot_2Dhist(x_par=x_par,y_par=y_par,z_par=z_par,\
#
# astropy/table/_column_mixins.pyx in astropy.table._column_mixins._MaskedColumnGetitemShim.__getitem__()
#
# astropy/table/_column_mixins.pyx in astropy.table._column_mixins.base_getitem()
#
# astropy/table/_column_mixins.pyx in astropy.table._column_mixins.masked_column_getitem()
#
# ~/.local/lib/python3.8/site-packages/numpy/ma/core.py in __getitem__(self, indx)
#    3223         # mask of being reshaped if it hasn't been set up properly yet
#    3224         # So it's easier to stick to the current version
# -> 3225         dout = self.data[indx]
#    3226         _mask = self._mask
#    3227
#
# ~/.local/lib/python3.8/site-packages/numpy/ma/core.py in __getitem__(self, indx)
#    3223         # mask of being reshaped if it hasn't been set up properly yet
#    3224         # So it's easier to stick to the current version
# -> 3225         dout = self.data[indx]
#    3226         _mask = self._mask
#    3227
#
# IndexError: arrays used as indices must be of integer (or boolean) type

# %%
plot_2Dhist(x_par=tab_all['z_stars'],y_par=tab_all['u-z'],z_par=tab_all['nsa_sersic_n_morph'],\
            x_min=0.0045,x_max=0.17,y_min=-0.25,y_max=4.5,z_min=0,z_max=6,c_main='black',label='MPL-11',\
            x_label='redshift',y_label='u-z mag',figname='abs_z_nSersic',alpha=0.85,\
            size_scatter=5.0,n_zbins=7,z_lim=80,labels_zbins=None,color_cm_now=None,\
           z_label=r'n$_{\rm sersic}$',xscale='log',x_loc=0.55)#'Spectral_r')

# %%
#tab_all['log_Mass'],tab_all['OH_Ho_Re_fit']
x_par=tab_all['log_Mass']
y_par=tab_all['OH_Ho_Re_fit']
z_par=tab_all['best type_n']
mask_par = (x_par>8) & (x_par<13) & (y_par>7.8) & (y_par<9.1)
plot_2Dhist(x_par=x_par[mask_par],y_par=y_par[mask_par],z_par=z_par[mask_par],\
            x_min=8.5,x_max=12.5,y_min=7.8,y_max=9.1,z_min=-2,z_max=10,c_main='black',label='MPL-11',\
            x_label=r'log(M$_\odot$)',y_label='12+log(O/H) Ho',figname='MZR_Ho',alpha=0.85,\
            size_scatter=5.0,n_zbins=13,z_lim=80,labels_zbins=morph_list,color_cm_now=None,x_loc=0.5)

# %%
#tab_all['log_Mass'],tab_all['OH_Ho_Re_fit']
x_par=tab_all['ZH_LW_Re']
y_par=tab_all['OZ_Ho']
z_par=tab_all['best type_n']
mask_par = (x_par>-2) & (x_par<0.5) & (y_par>-2) & (y_par<2)
plot_2Dhist(x_par=x_par[mask_par],y_par=y_par[mask_par],z_par=z_par[mask_par],\
            x_min=-1.25,x_max=0.3,y_min=-0.5,y_max=0.85,z_min=-2,z_max=10,c_main='black',label='MPL-11',\
            x_label=r'[Z/H]',y_label=r'[O/Z]',figname='OZ_Ho',alpha=0.85,\
            size_scatter=5.0,n_zbins=13,z_lim=80,labels_zbins=morph_list,color_cm_now=None, reverse=1)

# %%
#tab_all['log_Mass'],tab_all['OH_Ho_Re_fit']
#tab_all['Fe'],tab_all['Mgb']/tab_all['Fe']
x_par=np.log10(tab_all['Fe'])
y_par=np.log10(tab_all['Mgb']/tab_all['Fe'])
z_par=tab_all['best type_n']
mask_par = (x_par>-0.5) & (x_par<0.75) & (y_par>-0.7) & (y_par<1)
plot_2Dhist(x_par=x_par[mask_par],y_par=y_par[mask_par],z_par=z_par[mask_par],\
            x_min=-0.5,x_max=0.75,y_min=-0.5,y_max=0.85,z_min=-2,z_max=10,c_main='black',label='MPL-11',\
            x_label=r'log(W$_{Fe}$)',y_label=r'log(W$_{Mgb}$/W$_{Fe}$)',figname='Mg_Fe',alpha=0.85,\
            size_scatter=5.0,n_zbins=13,z_lim=80,labels_zbins=morph_list,color_cm_now=None)

# %%
#tab_all['log_Mass'],tab_all['OH_Ho_Re_fit']
#tab_all['Fe'],tab_all['Mgb']/tab_all['Fe']
x_par=np.log10(tab_all['Fe'])
y_par=np.log10(tab_all['Mgb']/tab_all['Fe'])
z_par=tab_all['ZH_LW_Re']
mask_par = (x_par>-0.5) & (x_par<0.75) & (y_par>-0.7) & (y_par<1)
plot_2Dhist(x_par=x_par[mask_par],y_par=y_par[mask_par],z_par=z_par[mask_par],\
            x_min=-0.5,x_max=0.75,y_min=-0.5,y_max=0.85,z_min=-1.2,z_max=0.3,c_main='black',label='MPL-11',\
            x_label=r'log(W$_{Fe}$)',y_label=r'log(W$_{Mgb}$/W$_{Fe}$)',figname='Mgb_Fe_Z',alpha=0.85,\
            size_scatter=5.0,n_zbins=13,z_lim=80,labels_zbins=None,color_cm_now=None)

# %%
#in_Sigma_Mass_stars  
#plt.scatter(tab_all['i_abs'],tab_all['u-i nsa'],c=tab_all['Age_LW_Re'],alpha=0.01) #flux_Ha6562_Re_fit
#plt.xlim(-25,-13)
#plt.ylim(0,4)
#plt.xlim(8,13)
#rc("text", usetex=False)
#tab_all.rename_column('z_abs','z abs')

#tab_plot=Table([tab_all['name'],tab_all['z abs'],tab_all['u-z'], tab_all['best type_n']])
#df_plot = tab_plot.to_pandas()
#ax=sns.jointplot(data=df_plot,x='log_Mass',y='u-z', xlim=[-0.5,5], ylim=[-0.5,5])
#plt.scatter(x=tab_all['z abs'],y=tab_all['u-z'])#, xlim=[-25,-13], ylim=[-0.5,5],\
#                 alpha=0.01)#
#ax.plot_joint(sns.kdeplot, color="r", zorder=0, levels=6)
#g.plot_joint(sns.kdeplot, color="r", zorder=0, levels=6)

xx = np.linspace(-25, -15, 1000)

#kde.set_bandwidth(bw_method='silverman')
kde=stats.gaussian_kde(tab_all['z abs'])
kde.set_bandwidth(bw_method=kde.factor / 10.)
#ax=plt.hist(tab_all['z abs'],range=(-23,-15))
plt.plot(xx,kde(xx),color='r')
#print(kde(xx))
#plt.plot(tab_all['z abs'],stats.gaussian_kde(tab_all['z abs']))
#ax.set_xlim(-30,-10)
#ax.set_axis_labels('x','y')

# %%
#ax=sns.jointplot(x=tab_all['log_Mass'],y=tab_all['u-z'], xlim=[8,13], ylim=[-0.5,5],\
#                 alpha=0.01)#
#ax.plot_joint(sns.kdeplot, color="r", zorder=0, levels=6)

# %%
#in_Sigma_Mass_stars  
plt.scatter(tab_all['z abs'],tab_all['FUV-z'],c=tab_all['z_stars'],alpha=0.1) #flux_Ha6562_Re_fit
plt.xlim(-25,-13)
plt.ylim(0,10)
#plt.xlim(8,13)
# Out:
# (0.0, 10.0)

# %%
#in_Sigma_Mass_stars  
plt.scatter(tab_all['z abs'],tab_all['u-z'],c=tab_all['Age_LW_Re'],alpha=0.01) #flux_Ha6562_Re_fit
plt.xlim(-25,-16)
plt.ylim(0.5,4)
#plt.xlim(8,13)
# Out:
# (0.5, 4.0)

# %%
#in_Sigma_Mass_stars  
plt.scatter(tab_all['i_abs'],tab_all['u-i nsa'],c=tab_all['Age_LW_Re'],alpha=0.01) #flux_Ha6562_Re_fit
plt.xlim(-25,-13)
plt.ylim(0,4)
#plt.xlim(8,13)
# Out:
# (0.0, 4.0)

# %%
#in_Sigma_Mass_stars  
plt.scatter(tab_all['u-i nsa'],tab_all['u-i'],c=tab_all['z_stars'],alpha=0.1,edgecolor='None') #flux_Ha6562_Re_fit
#plt.xlim(-25,-13)
plt.xlim(0,4)
plt.ylim(0,4)
ax = plt.gca()
ax.set_aspect('equal', adjustable='box')
#plt.xlim(8,13)

# %%
#in_Sigma_Mass_stars  tab_mag['i_band_mag']
plt.scatter(tab_all['i_abs'],tab_all['i_band_abs_mag'],c=tab_all['z_stars'],alpha=0.1,edgecolor='None') #flux_Ha6562_Re_fit
plt.xlim(-25,-13)
plt.ylim(-25,-13)
#plt.xlim(0,4)
#plt.ylim(0,4)
ax = plt.gca()
ax.set_aspect('equal', adjustable='box')
#plt.xlim(8,13)

# %%
#in_Sigma_Mass_stars  
plt.scatter(tab_all['log_Mass'],tab_all['in_Sigma_Mass_stars'],c=tab_all['z_stars'],alpha=0.1) #flux_Ha6562_Re_fit
plt.xlim(8,13)
# Out:
# (8.0, 13.0)

# %%
#list_columns(tab_all.columns)
plt.scatter(tab_all['flux_Halpha6562.85_Re_fit'],tab_all['flux_Ha6562_Re_fit']) #flux_Ha6562_Re_fit

# %%
#list_columns(tab_all.columns) #OH_Pet04_O3N2_alpha_fit
plt.scatter(tab_all['log_Mass'],tab_all['OH_Mar13_O3N2_alpha_fit'],alpha=0.1) #flux_Ha6562_Re_fit
plt.xlim(8,13)
print(np.nanmean(tab_all['OH_Pet04_O3N2_alpha_fit']))
# Out:
# -0.02549977462888914

# %%
#list_columns(tab_all.columns) #OH_Pet04_O3N2_alpha_fit
plt.scatter(tab_all['log_Mass'],tab_all['OH_Ho_Re_fit'],c=tab_all['z_stars'],alpha=0.1) #flux_Ha6562_Re_fit
plt.xlim(8,13)
print(np.nanmean(tab_all['OH_Pet04_O3N2_alpha_fit']))
# Out:
# -0.02549977462888914

# %%
#list_columns(tab_all.columns) #OH_Pet04_O3N2_alpha_fit
plt.scatter(tab_all['log_Mass'],tab_all['D4000_Re_fit'],alpha=0.01) #flux_Ha6562_Re_fit
plt.xlim(8,13)
#print(np.nanmean(tab_all['OH_Pet04_O3N2_alpha_fit']))
# Out:
# (8.0, 13.0)

# %%
#list_columns(tab_all.columns) #OH_Pet04_O3N2_alpha_fit
plt.scatter(tab_all['log_Mass'],tab_all['Mgb_Re_fit'],alpha=0.1) #flux_Ha6562_Re_fit
plt.xlim(8,13)
#print(np.nanmean(tab_all['OH_Pet04_O3N2_alpha_fit']))
# Out:
# (8.0, 13.0)

# %%
#list_columns(tab_all.columns) #OH_Pet04_O3N2_alpha_fit
plt.scatter(tab_all['Mgb'],tab_all['Mgb_Re_fit'],alpha=0.1) #flux_Ha6562_Re_fit
plt.xlim(-5,15)
plt.ylim(-5,15)

#print(np.nanmean(tab_all['OH_Pet04_O3N2_alpha_fit']))
# Out:
# (-5.0, 15.0)

# %%
#list_columns(tab_all.columns) #OH_Pet04_O3N2_alpha_fit
plt.scatter(tab_all['ZH_LW_Re'],tab_all['Mgb'],alpha=0.1) #flux_Ha6562_Re_fit
#plt.xlim(-2,0.5)
plt.ylim(-5,10)
#print(np.nanmean(tab_all['OH_Pet04_O3N2_alpha_fit']))
# Out:
# (-5.0, 10.0)

# %%
#e_Hd        Fe5270      e_e4000     SN          
#Hb          e_Fe5270    Hdmod       e_SN        
#e_Hb        Fe5335      e_Hdmod           

#list_columns(tab_all.columns) #OH_Pet04_O3N2_alpha_fit
tab_all['Fe']=np.sqrt(tab_all['Fe5270']*tab_all['Fe5335'])
plt.scatter(tab_all['ZH_LW_Re'],tab_all['Fe'],alpha=0.01) #flux_Ha6562_Re_fit
#plt.xlim(-2,0.5)
plt.ylim(-1,5)
#print(np.nanmean(tab_all['OH_Pet04_O3N2_alpha_fit']))
# Out:
# (-1.0, 5.0)

# %%
plt.scatter(tab_all['ZH_MW_Re_fit'],tab_all['Fe'],alpha=0.1) #flux_Ha6562_Re_fit
plt.ylim(-1,5)
# Out:
# (-1.0, 5.0)

# %%
plt.scatter(tab_all['D4000'],tab_all['Age_LW_Re'],alpha=0.1) #flux_Ha6562_Re_fit
plt.xlim(-0.2,2)
plt.ylim(7.25,10.3)
# Out:
# (7.25, 10.3)

# %%
plt.scatter(tab_all['Fe'],tab_all['Mgb']/tab_all['Fe'],alpha=0.05) #flux_Ha6562_Re_fit
plt.xlim(-1,5)
plt.ylim(-3,10)
# Out:
# (-3.0, 10.0)

# %%
cs=plt.scatter(np.log10(tab_all['Fe']),np.log10(tab_all['Mgb']/tab_all['Fe']),\
            c=tab_all['Age_LW_Re'],alpha=0.3,vmin=7,vmax=10.5) 
#flux_Ha6562_Re_fit
plt.xlim(-1,1)
plt.ylim(-1,1)
plt.xlabel(r'log(EW Fe)')
plt.ylabel(r'log(EW Mbg/EW Fe)')
plt.colorbar(cs,label='log LW Age')

# %%
tab_all['OZ_Ho']=tab_all['OH_Ho_Re_fit']-8.67-tab_all['ZH_LW_Re']
tab_all['Mg_Fe']=np.log10(tab_all['Mgb']/tab_all['Fe'])
plt.scatter(tab_all['Mg_Fe'],tab_all['OZ_Ho'],alpha=0.01)
plt.xlim(-0.5,1)
plt.ylim(-0.5,1)
# Out:
# (-0.5, 1.0)

# %%
cs=plt.scatter(tab_all['ZH_LW_Re'],tab_all['OZ_Ho'],\
            c=tab_all['Age_LW_Re'],alpha=0.3,vmin=7,vmax=10.5) 
#flux_Ha6562_Re_fit
plt.xlim(-1.5,1)
plt.ylim(-1,1)
plt.xlabel(r'[Z/H] LW')
plt.ylabel(r'[O/Z]')
plt.colorbar(cs,label='log LW Age')

# %%
print(tab_all['nsa_sersic_n_morph'])
# Out:
# nsa_sersic_n_morph
# ------------------
#           0.741845
#            1.44272
#            2.18084
#           0.869326
#            1.25046
#           0.715437
#             4.9523
#             5.9563
#                6.0
#            1.86687
#                ...
#           0.889317
#            2.25223
#             2.1025
#            4.55335
#            4.66327
#            4.81856
#           0.922933
#            1.36054
#            2.21669
#                6.0
#            1.26898
# Length = 9347 rows

# %%
plt.scatter(tab_all['i_band_abs_mag'],tab_all['u-i'],alpha=0.1,edgecolor=None)
plt.xlim(-25.5,-15)
plt.ylim(-0.5,3.5)
print(len(tab_all))
#print(len(tab_mag))
# Out:
# 9347

# %%
plt.scatter(tab_all['best type_n'],tab_all['u-i'],alpha=0.1,edgecolor=None)
print(np.min(tab_all['best type_n']))
print(np.max(tab_all['best type_n']))
#print(tab_all['best type_n'])
#plt.xlim(-25.5,-15)
#plt.ylim(-0.5,3.5)
#print(len(tab_all))
#print(len(tab_mag))
# Out:
# -2
# 10

# %%
plt.scatter(tab_all['best type_n'],tab_all['nsa_sersic_n_morph'],alpha=0.1,edgecolor=None)
#print(np.min(tab_all['best type_n']))
#print(np.max(tab_all['best type_n']))
#print(tab_all['best type_n'])
#plt.xlim(-25.5,-15)
#plt.ylim(-0.5,3.5)
#print(len(tab_all))
#print(len(tab_mag))
#print(tab_all['nsa_sersic_n'])

# %%
plt.scatter(tab_all['best type_n'],tab_all['lSFR']-tab_all['log_Mass'],alpha=0.1,edgecolor=None)
#print(np.mean(tab_all['log_Mass']))
