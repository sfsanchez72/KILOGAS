# %%
from astropy.io import fits
import numpy as np
from typing import Tuple
import math

# %%
def create_circular_mask(h: int, w: int, center: Tuple[int, int], radius: int) -> np.ndarray:
    """Create a boolean mask for a circle centered at `center` with given `radius`."""
    Y, X = np.ogrid[:h, :w]
    dist_from_center = np.sqrt((X - center[0])**2 + (Y - center[1])**2)
    return dist_from_center <= radius

def extract_values_from_cube(fits_path: str, x: int, y: int, radius: int) -> np.ndarray:
    """Extract average values (or quadratic average for errors) from FITS datacube slice-by-slice."""
    
    with fits.open(fits_path) as hdul:
        data = hdul[0].data  # shape: (z, y, x)
        header = hdul[0].header
    desc_entries = extract_desc_entries(header)
    
    if data.ndim != 3:
        raise ValueError("Input FITS file must contain a 3D datacube.")

    nz, ny, nx = data.shape

    if not (0 <= x < nx and 0 <= y < ny):
        x = int(nx/2.0)
        y = int(ny/2.0)
#        raise ValueError("Provided (x, y) coordinates are outside the image bounds.")

#    print(x,y)
    mask = create_circular_mask(ny, nx, center=(x, y), radius=radius)

    result = []

    for z in range(nz):
        desc_key = f'DESC{z}'
        desc = header.get(desc_key, '')

        slice_data = data[z, :, :]
        values = slice_data[mask]

        if values.size == 0:
            result.append(np.nan)
            continue

        if desc.startswith('e_'):
            quadratic_mean = math.sqrt(np.mean(values ** 2))
            result.append(quadratic_mean)
        else:
            simple_mean = np.mean(values)
            result.append(simple_mean)

    return np.array(result),desc_entries

def extract_desc_entries(header):
    """Extract DESC# entries from FITS header as an array sorted by slice index."""
    desc_entries = []
    z_indices = []

    for key in header.keys():
        if key.startswith('DESC') and key[4:].isdigit():
            z_indices.append(int(key[4:]))

    z_indices.sort()

    for z in z_indices:
        desc_key = f'DESC{z}'
        desc_entries.append(header.get(desc_key, ''))

    return desc_entries

# %%
HP_dir = 'data'
x_pixel = -1
y_pixel = -1
radius = 2.5
I = 0
for tab_pe_now in tab_pe:
    kgas_id = tab_pe_now['KGAS_ID']
    cubename = tab_pe_now['cubename']
    fits_file = f'{HP_dir}/{cubename}.OH.cube.fits.gz'
    PE_fits_file = f'{HP_dir}/{cubename}.P_E.cube.fits.gz'

    try:
        extracted_values,keys = extract_values_from_cube(fits_file, x_pixel, y_pixel, radius)    
        if (I==0):
            tab_keys = []
            tab_keys.append('KGAS_ID')
            tab_keys.append('cubename')
            for key in keys:
                tab_keys.append(key)
            tab_keys = np.array(tab_keys)
            tab_OH_cen = Table(names=tab_keys)
            tab_OH_cen['KGAS_ID'] = tab_OH_cen['KGAS_ID'].astype('str')
            tab_OH_cen['cubename'] = tab_OH_cen['cubename'].astype('str')
        tab_values = []
        tab_values.append(kgas_id)
        tab_values.append(cubename)
        for vals in extracted_values:
            tab_values.append(vals)         
        tab_values = np.array(tab_values)
        tab_OH_cen.add_row(tab_values)
        I = I+1
    except:
        print(f'file {fits_file} not found')
# Out:
# file data/KG-MaNGA-1-178894.OH.cube.fits.gz not found
# file data/KG-MaNGA-1-178894.OH.cube.fits.gz not found
# file data/KG-MaNGA-1-179173.OH.cube.fits.gz not found
# file data/KG-MaNGA-1-179071.OH.cube.fits.gz not found
# file data/KG-MaNGA-1-179071.OH.cube.fits.gz not found
# file data/KG-MaNGA-1-178794.OH.cube.fits.gz not found
# file data/KG-MaNGA-1-54940.OH.cube.fits.gz not found
# file data/KG-MaNGA-1-277.OH.cube.fits.gz not found
# file data/KG-MaNGA-1-55227.OH.cube.fits.gz not found
# file data/KG-MaNGA-1-954.OH.cube.fits.gz not found
# file data/KG-MaNGA-1-383.OH.cube.fits.gz not found
# file data/KG-MaNGA-1-55178.OH.cube.fits.gz not found
# file data/KG-MaNGA-1-78155.OH.cube.fits.gz not found
# file data/KG-MaNGA-1
OH.cube.fits.gz not found
# file data/KG-MaNGA-1-83451.OH.cube.fits.gz not found
# file data/KG-SAMI-321146.OH.cube.fits.gz not found
# file data/KG-SAMI-298612.OH.cube.fits.gz not found
# file data/KG-SAMI-298590.OH.cube.fits.gz not found
# file data/KG-SAMI-229163.OH.cube.fits.gz not found
# file data/KG-SAMI-252021.OH.cube.fits.gz not found
# file data/KG-SAMI-252005.OH.cube.fits.gz not found
# file data/KG-SAMI-240227.OH.cube.fits.gz not found
# file data/KG-SAMI-229167.OH.cube.fits.gz not found
# file data/KG-MaNGA-1-40883.OH.cube.fits.gz not found
# file data/KG-MaNGA-1-41260.OH.cube.fits.gz not found
# file data/KG-MaNGA-1-41133.OH.cube.fits.gz not found
# file data/KG-MaNGA-1-601909.OH.cube.fits.gz not found
# file data/KG-MaNGA-1-40796.OH.cube.fits.gz not found
# file data/KG-MaNGA-1-41030.OH.cube.fits.gz not found
# file data/KG-MaNGA-1-39946.OH.cube.fits.gz not found
# file data/KG-MaNGA-1-39922.OH.cube.fits.gz not found
# file data/KG-MaNGA-1-41257.OH.cube.fits.gz not found
# file data/KG-MaNGA-1-41258.OH.cube.fits.gz not found
# file data/KG-MaNGA-1-229070.OH.cube.fits.gz not found
# file data/KG-MaNGA-1-229064.OH.cube.fits.gz not found
# file data/KG-MaNGA-1-202091.OH.cube.fits.gz not found
# file data/KG-MaNGA-1-289864.OH.cube.fits.gz not found
# file data/KG-MaNGA-1-550945.OH.cube.fits.gz not found
# file data/KG-MaNGA-1-289865.OH.cube.fits.gz not found
# file data/KG-MaNGA-1-180172.OH.cube.fits.gz not found
# file data/KG-MaNGA-1-180614.OH.cube.fits.gz not found
# file data/KG-MaNGA-1-180623.OH.cube.fits.gz not found
# file data/KG-MaNGA-1-180540.OH.cube.fits.gz not found
# file data/KG-MaNGA-1-180472.OH.cube.fits.gz not found
# file data/KG-MaNGA-1-180513.OH.cube.fits.gz not found
# file data/KG-MaNGA-1-180886.OH.cube.fits.gz not found
# file data/KG-MaNGA-1-35957.OH.cube.fits.gz not found
# file data/KG-MaNGA-1-35334.OH.cube.fits.gz not found
# file data/KG-MaNGA-1-35530.OH.cube.fits.gz not found
# file data/KG-MaNGA-1-35371.OH.cube.fits.gz not found
# file data/KG-MaNGA-1-138167.OH.cube.fits.gz not found
# file data/KG-MaNGA-1-138401.OH.cube.fits.gz not found
# file data/KG-MaNGA-1-81110.OH.cube.fits.gz not found
# file data/KG-MaNGA-1-62037.OH.cube.fits.gz not found
# file data/KG-MaNGA-1-4036.OH.cube.fits.gz not found
# file data/KG-MaNGA-1-613941.OH.cube.fits.gz not found
# file data/KG-MaNGA-1-138298.OH.cube.fits.gz not found
# file data/KG-SAMI-592863.OH.cube.fits.gz not found
# file data/KG-SAMI-63027.OH.cube.fits.gz not found
# file data/KG-SAMI-463264.OH.cube.fits.gz not found
# file data/KG-MaNGA-1-38470.OH.cube.fits.gz not found
# file data/KG-MaNGA-1-38299.OH.cube.fits.gz not found
# file data/KG-MaNGA-1-604037.OH.cube.fits.gz not found
# file data/KG-MaNGA-1-139929.OH.cube.fits.gz not found
# file data/KG-SAMI-220332.OH.cube.fits.gz not found
# file data/KG-SAMI-230793.OH.cube.fits.gz not found
# file data/KG-SAMI-287827.OH.cube.fits.gz not found
# file data/KG-SAMI-609396.OH.cube.fits.gz not found
# file data/KG-SAMI-289197.OH.cube.fits.gz not found
# file data/KG-SAMI-289097.OH.cube.fits.gz not found
# file data/KG-SAMI-289089.OH.cube.fits.gz not found
# file data/KG-SAMI-220396.OH.cube.fits.gz not found
# file data/KG-SAMI-220502.OH.cube.fits.gz not found
# file data/KG-SAMI-230634.OH.cube.fits.gz not found
# file data/KG-SAMI-396833.OH.cube.fits.gz not found
# file data/KG-MaNGA-1-144455.OH.cube.fits.gz not found
# file data/KG-MaNGA-1-144884.OH.cube.fits.gz not found
# file data/KG-MaNGA-1-144889.OH.cube.fits.gz not found
# file data/KG-MaNGA-1-627461.OH.cube.fits.gz not found
# file data/KG-MaNGA-1-627411.OH.cube.fits.gz not found
# file data/KG-MaNGA-1-144478.OH.cube.fits.gz not found
# file data/KG-MaNGA-1-480.OH.cube.fits.gz not found
# file data/KG-MaNGA-1-1037.OH.cube.fits.gz not found
# file data/KG-MaNGA-1-245.OH.cube.fits.gz not found
# file data/KG-SAMI-545986.OH.cube.fits.gz not found
# file data/KG-MaNGA-1-83058.OH.cube.fits.gz not found
# file data/KG-SAMI-492690.OH.cube.fits.gz not found
# file data/KG-SAMI-487019.OH.cube.fits.gz not found
# file data/KG-SAMI-487027.OH.cube.fits.gz not found
# file data/KG-SAMI-239560.OH.cube.fits.gz not found
# file data/KG-MaNGA-1-82684.OH.cube.fits.gz not found
# file data/KG-MaNGA-1-83063.OH.cube.fits.gz not found
# file data/KG-MaNGA-1-82687.OH.cube.fits.gz not found
# file data/KG-SAMI-298666.OH.cube.fits.gz not found
# file data/KG-SAMI-298980.OH.cube.fits.gz not found
# file data/KG-MaNGA-1-70172.OH.cube.fits.gz not found
# file data/KG-MaNGA-1-83002.OH.cube.fits.gz not found
# file data/KG-MaNGA-1-82991.OH.cube.fits.gz not found
# file data/KG-MaNGA-1-412631.OH.cube.fits.gz not found
# file data/KG-MaNGA-1-383589.OH.cube.fits.gz not found
# file data/KG-MaNGA-1-460434.OH.cube.fits.gz not found
# file data/KG-MaNGA-1-383612.OH.cube.fits.gz not found
# file data/KG-MaNGA-1-383608.OH.cube.fits.gz not found
# file data/KG-MaNGA-1-383040.OH.cube.fits.gz not found
# file data/KG-MaNGA-1-383050.OH.cube.fits.gz not found
# file data/KG-MaNGA-1-412207.OH.cube.fits.gz not found

# %%
tab_OH_cen
# Out:
# <Table length=2>
# KGAS_ID    cubename       OH_Mar13_N2       e_OH_Mar13_N2       OH_Mar13_O3N2   ...   e_NO_Pil16_Ho_R      NO_Pil16_N2_R2     e_NO_Pil16_N2_R2      Ne_Oster_S        e_Ne_Oster_S
#  str32      str32           float64            float64             float64      ...       float64             float64             float64            float64            float64
# ------- -------------- ----------------- -------------------- ----------------- ... -------------------- ------------------ ------------------- ------------------ ------------------
#      12 KG-MaNGA-1-207   8.5753632379292 0.003549391259805714 8.572184857925178 ... 0.027729003813181167 0.8052649519396551 0.01869716238570224                nan                nan
#      88 KG-SAMI-107214 8.565644451565905 0.031703663404094966 8.530244578009965 ...  0.29479985836312406 0.8792875051699577  0.2634338492250751 2.8800643684284783 0.5572222891383989

# %%
tab_OH_cen.write('tables/tab_OH_cen_test.ecsv',overwrite=True,delimiter=',')

# %%
tab_
